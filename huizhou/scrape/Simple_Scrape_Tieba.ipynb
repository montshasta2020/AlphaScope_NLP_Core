# %%
import string, urllib2

# %%
url = 'http://tieba.baidu.com/f?kw=%BB%D5%D6%DD&pn='
i = 1000

# %%
m = urllib2.urlopen(url + str(i)).read()

# %%
print m
# Out:
# <!DOCTYPE html>
# <!--STATUS OK-->
# <html>
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="keywords" content="贴吧,tieba,徽州,徽州吧,地区,安徽"/>
# <meta name="description" content="贴吧徽州吧，有18735个吧友关注，共发布283311条贴子。百度徽州吧是徽州六县（歙县、休宁、婺源、黟县、祁门、绩溪）及徽文化辐射地区（如严州、浮梁、德兴、旌德、太平、石台等地吧友的心灵家园，同时也是热爱徽文化，热爱徽州自然风光的非徽州籍吧友的网络交流平台。"/>
#     <link rel="search" type="application/opensearchdescription+xml" href="/tb/cms/content-search.xml" title="百度贴吧" />
#     <title>
#         徽州吧_百度贴吧    </title>
#
#     <script >
# ...
