# %%
import pandas as pd
from selenium import webdriver 
from bs4 import BeautifulSoup
import time
import re

# %%
from datetime import date, timedelta, datetime
import os.path

# %%
t0 =  date.today()

# %%
fname1 = '../data/segments/solr/segment-100.csv'

# %%
def get_columns():
    return ('dt', 'source', 'domain', 'url', 'title', 'summary', 'image', 'brief', 'body', 'raw_page', 'from') 
def get_empty_columns():
    return ('', '', '', '', '', '', '', '', '', '', '') 
def get_empty_columns1():
    return ('', '', '', '', '', '', '', '', '', '', '','')

# %%
browser = webdriver.Firefox() 
#browser = webdriver.Chrome('/Users/nhu2000/Downloads/Chromedriver')

# %%
if os.path.isfile(fname1): 
    df = pd.read_csv(fname1)
    idx = len(df.index)
else:
    df = pd.DataFrame(columns = get_columns())
    idx = 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1066 entries, 0 to 1065
# Data columns (total 2 columns):
# url         1066 non-null object
# segments    1066 non-null object
# dtypes: object(2)
# memory usage: 25.0+ KB

# %% [markdown]
# if os.path.isfile(fname2):
#     df_0 = pd.read_csv(fname2)
# else:
#     df_0 = pd.DataFrame(columns = get_columns())

# %% [markdown]
# soup = BeautifulSoup(browser.page_source)
# sub_text = soup.findAll('div', {'class':'content'})
#
# for item in sub_text:
#     print item.text

# %%
if '_2.html' in '2358_2.html':
    print 'true'
else:
    print 'false'
# Out:
# true

# %% [markdown]
# view = soup.find('div', {'class':'viewbox'})
# print view.div.text

# %%
new_df = pd.DataFrame(columns = get_columns())
idx = 0

# %%
for i in range(758, len(df)):
    url_0 = df.loc[i]['url']
    
    if '_2.html' in url_0:
        print title

    title = df.loc[i]['segments']   

    print i, url_0
    browser.get(url_0)
    time.sleep(10)

    soup = BeautifulSoup(browser.page_source)
    sub_text = soup.findAll('div', {'class':'content'})

    for item in sub_text:
        new_df.loc[i] = get_empty_columns()        
        new_df.loc[i]['url'] = url_0
        new_df.loc[i]['title'] = title
        new_df.loc[i]['body'] = item.text        
        new_df.loc[i]['source'] = '安徽文化网'
# Out:
# 758 http://www.ahage.net/photo/13054_8.html
# 759 http://www.ahage.net/html/culpic/23181.html
# 歙县 风光 —— 狮 石 云雾 （ 高 清 组图 ）
# 760 http://www.ahage.net/html/culpic/23181_2.html
# 761 http://www.ahage.net/html/culpic/23181_3.html
# 762 http://www.ahage.net/html/culpic/23181_4.html
# 763 http://www.ahage.net/html/culpic/23181_5.html
# 764 http://www.ahage.net/html/culpic/23181_6.html
# 765 http://www.ahage.net/html/culpic/23181_7.html
# 766 http://www.ahage.net/huangshan/22380.html
# 徽州 历史 上 的 才媛
# 767 http://www.ahage.net/huangshan/22380_2.html
# 768 http://www.ahage.net/huangshan/22380_3.html
# 769 http://www.ahage.net/huangshan/22380_4.html
# 770 http://www.ahage.net/huangshan/22380_5.html
# 771 http://www.ahage.net/huangshan/22380_6.html
# 772 http://www.ahage.net/huangshan/22380_7.html
# 773 http://www.ahage.net/huangshan/6941.html
# 歙县 籍 主要 人物 介绍
# 774 http://www.ahage.net/huangshan/6941_2.html
# 775 http://www.ahage.net/huangshan/6941_3.html
# ...

# %%
idx = 937

# %%
print idx
# Out:
# 1031

# %%
if 'image' in 'http://www.ahage.net/image/26396_20.html':
    print 'true'
# Out:
# true

# %%
for i in range(0, len(df)):
    url_0 = df.loc[i]['url']
    title = df.loc[i]['segments']
    
    if 'photo' in url_0:
        print idx, title
        new_df.loc[idx] = get_empty_columns()        
        new_df.loc[idx]['url'] = url_0
        new_df.loc[idx]['title'] = title
        new_df.loc[idx]['source'] = '安徽文化网'
        idx += 1
# Out:
# 1031 明代 徽州 土地 产权 变动 和 管理 文书 （ 图片 ）
# 1032 明代 徽州 土地 产权 变动 和 管理 文书 （ 图片 ） ( 2 )
# 1033 明代 徽州 土地 产权 变动 和 管理 文书 （ 图片 ） ( 3 )
# 1034 明代 徽州 土地 产权 变动 和 管理 文书 （ 图片 ） ( 4 )
# 1035 明代 徽州 土地 产权 变动 和 管理 文书 （ 图片 ） ( 5 )
# 1036 明代 徽州 土地 产权 变动 和 管理 文书 （ 图片 ） ( 6 )
# 1037 明代 徽州 土地 产权 变动 和 管理 文书 （ 图片 ） ( 7 )
# 1038 明代 徽州 土地 产权 变动 和 管理 文书 （ 图片 ） ( 8 )
# 1039  一 组 珍贵 的 屯溪 老 照片 （ 组图 ）
# 1040  一 组 珍贵 的 屯溪 老 照片 （ 组图 ） ( 2 )
# 1041  一 组 珍贵 的 屯溪 老 照片 （ 组图 ） ( 3 )
# 1042  一 组 珍贵 的 屯溪 老 照片 （ 组图 ） ( 4 )
# 1043 屯溪 老 照片 一 组 （ 组图 ）
# 1044 屯溪 老 照片 一 组 （ 组图 ） ( 2 )
# 1045 屯溪 老 照片 一 组 （ 组图 ） ( 3 )
# 1046 屯溪 老 照片 一 组 （ 组图 ） ( 4 )
# 1047 屯溪 老 照片 一 组 （ 组图 ） ( 5 )
# 1048 屯溪 老 照片 一 组 （ 组图 ） ( 6 )
# 1049 屯溪 老 照片 一 组 （ 组图 ） ( 7 )
# 1050 屯溪 老 照片 一 组 （ 组图 ） ( 8 )
# 1051 屯溪 老 照片 一 组 （ 组图 ） ( 9 )
# 1052 屯溪 老 照片 一 组 （ 组图 ） ( 10 )
# 1053 屯溪 老 照片 一 组 （ 组图 ） ( 11 )
# 1054 宣城 一 组 珍贵 的 老 照片
# 1055 宣城 一 组 珍贵 的 老 照片 ( 2 )
# 1056 宣城 一 组 珍贵 的 老 照片 ( 3 )
# 1057 宣城 一 组 珍贵 的 老 照片 ( 4 )
# 1058 宣城 一 组 珍贵 的 老 照片 ( 5 )
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1066 entries, 0 to 1065
# Data columns (total 11 columns):
# dt          129 non-null object
# source      1066 non-null object
# domain      129 non-null object
# url         1066 non-null object
# title       1066 non-null object
# summary     129 non-null object
# image       129 non-null object
# brief       129 non-null object
# body        1066 non-null object
# raw_page    129 non-null object
# from        129 non-null object
# dtypes: object(11)
# memory usage: 99.9+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1066 entries, 0 to 1065
# Data columns (total 2 columns):
# url         1066 non-null object
# segments    1066 non-null object
# dtypes: object(2)
# memory usage: 25.0+ KB

# %%
new_df.head(100)
# Out:
#    dt source domain                                         url  \
# 0      安徽文化网               http://www.ahage.net/news/29365.html
# 1      安徽文化网             http://www.ahage.net/news/29365_2.html
# 2      安徽文化网             http://www.ahage.net/news/29365_3.html
# 3      安徽文化网             http://www.ahage.net/news/29365_4.html
# 4      安徽文化网             http://www.ahage.net/news/29365_5.html
# 5      安徽文化网             http://www.ahage.net/fengsu/22238.html
# 6      安徽文化网           http://www.ahage.net/fengsu/22238_2.html
# 7      安徽文化网           http://www.ahage.net/fengsu/22238_3.html
# 8      安徽文化网           http://www.ahage.net/fengsu/22238_4.html
# 9      安徽文化网           http://www.ahage.net/fengsu/22238_5.html
# 10     安徽文化网           http://www.ahage.net/fengsu/22238_6.html
# 11     安徽文化网           http://www.ahage.net/fengsu/22238_7.html
# 12     安徽文化网             http://www.ahage.net/fengsu/22359.html
# 13     安徽文化网           http://www.ahage.net/fengsu/22359_2.html
# ...

# %%
new_df.to_csv('temp100.csv', encoding='utf-8', index=False)

# %%
new_df = pd.read_csv('temp01.csv')
