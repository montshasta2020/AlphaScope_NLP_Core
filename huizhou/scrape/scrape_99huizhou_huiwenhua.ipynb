# %%
import pandas as pd
from selenium import webdriver 
from bs4 import BeautifulSoup
import time
import re

# %%
from datetime import date, timedelta, datetime
import os.path

# %%
t0 =  date.today()

# %%
news_url='http://www.99huizhou.com/forum.php?mod=forumdisplay&fid=78&filter=typeid&typeid=162'

datetime_str = t0
fname1 = './data/general/temp/' + '99huizhou-huiwenhua' + '.csv'
fname2 = './data/general/' + '99huizhou-huiwenhua' + '.csv'

# %%
def get_columns():
    return ('dt', 'source', 'domain', 'url', 'title', 'summary', 'image', 'brief', 'body', 'raw_page', 'from') 
def get_empty_columns():
    return ('', '', '', '', '', '', '', '', '', '', '') 
def get_empty_columns1():
    return ('', '', '', '', '', '', '', '', '', '', '','')

# %%
browser = webdriver.Firefox() 
#browser = webdriver.Chrome('/Users/nhu2000/Downloads/Chromedriver')

# %%
if os.path.isfile(fname1): 
    df = pd.read_csv(fname1)
    idx = len(df.index)
else:
    df = pd.DataFrame(columns = get_columns())
    idx = 0

# %%
if os.path.isfile(fname2): 
    df_check = pd.read_csv(fname2)
    idx = len(df.index)
else:
    df_check = pd.DataFrame(columns = get_columns())
    idx = 0

# %% [markdown]
# if os.path.isfile(fname2):
#     df_0 = pd.read_csv(fname2)
# else:
#     df_0 = pd.DataFrame(columns = get_columns())

# %%
print len(df_check)
# Out:
# 0

# %%
print len(df)
# Out:
# 0

# %% [markdown]
# browser.get(news_url)
# time.sleep(5)

# %%
url_0 = news_url
print url_0
browser.get(url_0)
time.sleep(5)
# Out:
# http://www.99huizhou.com/forum.php?mod=forumdisplay&fid=78&filter=typeid&typeid=162

# %%
idx = 0
not_existed = True
df = pd.DataFrame(columns = get_columns())

# %%
soup = BeautifulSoup(browser.page_source)
#sub_text = soup.findAll('tr', {'class':'eis_bd'})
#sub_text = soup.findAll('tr', {'class':'fl_row'})
#sub_text = soup.findAll('div', {'id':'threadlist'})
sub_text = soup.findAll('tbody', {'id': lambda L: L and L.startswith('normalthread_')})

for item in sub_text:
    #print 'www.hzwh.com/' + item.a['href']
    #print t1.text
    #print item.text

    t1 = item.find('a', {'class':'s xst'})    
    t2 = item.find('td', {'class':'by'})    
    #t0 = item.find('td', {'class':'eis_fl_forum'})    
    #if t0 != None:
    #    t1 = t0.h2.a
    #print t1.text
    #print t1['href']
    #print t2.em.text
    
    if not_existed == True and t1 != None:   
        print "-------- add", 
        print t1.text
        #print t1['href']
        df.loc[idx] = get_empty_columns()        
        df.loc[idx]['url'] = 'http://www.99huizhou.com/' + t1['href']
        df.loc[idx]['title'] = t1.text
        df.loc[idx]['source'] = '故园徽州'
        df.loc[idx]['dt'] = t2.em.text
        idx += 1
# Out:
# -------- add 谁说15号的活动没有意义,
# -------- add 德国建筑专家在樘樾
# -------- add 史墅老匾
# -------- add 宏村承志堂的木雕的艺术为什么没有隔壁的艺术高
# -------- add 德国建筑专家在木坑竹海
# -------- add 德国建筑专家在宏村
# -------- add 张脉贤在<中国龙川 胡氏宗祠木雕解读>一书中的序言
# -------- add 德国建筑专家参观徽博录象1
# -------- add 隆重推出徽州木雕的一本好书《中国龙川　胡氏宗祠木雕解读》
# -------- add 这是什么玩意?
# -------- add 徽州三雕群是21434021欢乐你的加入
# -------- add 老外眼中的徽州雕刻
# -------- add 徽州建筑木雕什么时候出现雕刻人物
# -------- add 徽州木雕的标志性是什么？
# -------- add 《徽州明清雀替读解》一书木雕图片脚本
# -------- add 徽州九狮一对
# -------- add 【喜讯】祝贺老土徽州三雕版今日开盘！

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67 entries, 0 to 66
# Data columns (total 11 columns):
# dt          67 non-null object
# source      67 non-null object
# domain      67 non-null object
# url         67 non-null object
# title       67 non-null object
# summary     67 non-null object
# image       67 non-null object
# brief       67 non-null object
# body        67 non-null object
# raw_page    67 non-null object
# from        67 non-null object
# dtypes: object(11)
# memory usage: 6.3+ KB

# %%
df.head()
# Out:
#            dt source domain  \
# 0    2017-2-9   故园徽州
# 1    2017-1-1   故园徽州
# 2  2016-11-23   故园徽州
# 3  2016-10-25   故园徽州
# 4  2016-10-17   故园徽州
#
#                                                  url  \
# 0  forum.php?mod=viewthread&tid=195025&extra=page...
# 1  forum.php?mod=viewthread&tid=194254&extra=page...
# 2  forum.php?mod=viewthread&tid=192264&extra=page...
# 3  forum.php?mod=viewthread&tid=189658&extra=page...
# 4  forum.php?mod=viewthread&tid=189555&extra=page...
#
#                         title summary image brief body raw_page from
# 0  【春节民俗活动预告】——中云镇桃溪坑头“抬汪公”民俗
# 1               2017.01.01的早上
# 2                       上学去喽！
# 3        流淌的登源河（29）：老造反成了普通看客
# 4                    沙溪“淩”姓来由

# %%
if(len(df) != 0):
    df.to_csv('../data/topics/100/110/99huizhou.csv', encoding='utf-8', index=False)
#    df.to_csv('../data/topics/400/420/99huizhou.csv', encoding='utf-8', index=False)

# %%
for i in range(0, len(df)):
    url = 'http://www.99huizhou.com/' + df.loc[i]['url']
    browser.get(url)
    time.sleep(15)
    
    soup = BeautifulSoup(browser.page_source)
    sub_text = soup.findAll('div', {'class':'t_fsz'})
    
    fst = 0
    for item in sub_text:
        if fst == 0:
            #print item.text
            print i, df.loc[i]['title']
            #print 'add --', item.text
            df.loc[i]['body'] = item.text
            df.loc[i]['raw_page'] = browser.page_source    
            fst = 1
# Out:
# 0 【春节民俗活动预告】——中云镇桃溪坑头“抬汪公”民俗
# 1 2017.01.01的早上
# 2 上学去喽！
# 3 流淌的登源河（29）：老造反成了普通看客
# 4 沙溪“淩”姓来由
# 5 流淌的登源河（25）：一月风暴刮到绩溪
# 6 流淌的登源河（24）：文革号角悄然吹响
# 7 流淌的登源河（22）：和苏村的亲密接触
# 8 流淌的登源河（20）：反右倾是第一位的
# 9 流淌的登源河（18）：农民的软抗高招
# 10 流淌的登源河（16）：龙丛源里的农家
# 11 流淌的登源河（14）：十三号公寓
# 12 流淌的登源河（12）：饭票和钞票的困扰
# 13 流淌的登源河（10）：头一回当工作组
# 14 流淌的登源河（6）
# 15 流淌的登源河（8）
# 16 流淌的登源河（4）
# 17 流淌的登源河（2）
# 18 流淌的登源河（寄语与目录）
# 19 养生福地，美食天堂——绩溪
# 20 母亲们节日快乐
# 21 阳春三月祭汪王（3月31日修改版）
# 22 阳春三月祭汪王
# 23 丙申清明汪王祭活动公告
# 24 开门红
# 25 绩溪文承堂章氏家训展馆
# 26 《徽州往事》再登国家大剧院
# 27 故园旗帜在婺源飘扬
# 28 婺源：“傩娃”踩春传承非遗 人花相融天人合一
# 29 徽州剪纸
# 30 上花轿
# 31 两本剪纸
# 32 茶仙子鲍丽丽在祁门演绎一场关于红茶的饕餮盛宴
# 33 新安程氏乙未年清明篁墩公祭
# 34 歙县南乡民间的两篇“汪公大帝祭文”
# 35 请徽友们关注：3月29日   清明汪王祭    首届中国黄山汪华文化节
# 36 迄今描述"歙县蜈蚣岭村"最为精彩的一篇文章，家乡人请转起
# 37 解板
# 38 羊年   汪华文化短讯五则
# 39 绩溪余川将举办"汪王祭祀和抬汪公"大型民俗活动
# 40 祁门县文堂村举行乡约家法宣讲仪式
# 41 追寻徽州的淳朴印迹
# 42 过年习俗完整版
# 43 【历史上的今天】十八年前的“6·30”洪水
# 44 绩溪民间禁忌趣谈
# 45 “老家的味道”在歙县拍摄 央视7套小年播出
# 46 邑小士多,名儒辈出——徽州绩溪
# 47 狮子
# 48 好文阅读 斜阳残照徽州梦
# 49 戏曲表演乐市民
# 50 捉知了_-----高高的窜天杨
# 51 齐云山进香记
# 52 大姐头发有点长
# 53 祠堂的血与泪
# 54 前两个字什么意思
# 55 历史传奇故事： 苏小妹 三 难  新 郎
# 56 未见屯溪面十里闻茶香.........忆屯溪古缜茶季
# 57 俺滴师弟又打篮了
# 58 【徽州往事口述】那一晚是屯溪最欢腾的一晚！——孙思诚
# 59 祝天下母亲节日快乐
# 60 上世纪五十年代的祁门榨油厂一瞥
# 61 大周山漫记
# 62 小荷又露尖尖角
# 63 婺源近年来兴建的村名坊
# 64 清明节的旧帖，徽州歙县斩尾龙的故事
# 65 【说鳖】寒食上坟，烧纸钱，老祖宗收不到！
# 66 【乌龙精挂纸】年羹尧婺源奇遇
# 67 清明上坟纸角写法？
# 68 四十多年前的歙县徽城镇
# 69 救命之方，请收藏起来广为流传，不要失传
# 70 【历史】抗战中的屯溪往事
# 71 名教——听听胡适说鳖
# 72 歙县雄村：“钟馗”骑车送五福
# 73 婺源过年前在＂吃＂上要忙的三件大事
# 74 百岁老人吴灶茂仙逝
# 75 山茶花开正当时
# 76 方氏的师兄手艺
# 77 淳安县朱家村“猪头大赛”祭祀祖先朱熹
# 78 回徽州过大年
# 79 休宁元宵活动多
# 80 央视12频道讲李坑申明亭
# 81 编修绩溪县《瀛洲章氏宗谱（外迁卷）》的公告
# 82 开门大吉
# 83 歙县山村打秋千 祈福四季丰
# 84 柯村乡翠林村龙等会
# 85 黟县宏潭乡马年春节龙狮会
# 86 沉痛悼念我的岳父不幸逝世
# 87 烛影摇红·过年
# 88 许琦和你聊聊古徽州春节传统祭祀
# 89 为什么叫“顶市酥”
# 90 【黟县民间故事】红船出港  九连桥护
# 91 “桂馥庭”改梁换柱
# 92 大星村的由来
# 93 休宁民间传奇故事——
# 94 休宁民间传奇故事
# 95 休宁民间传奇故事
# 96 过年--舌尖上的黄柏山村 （金川乡柏川村）
# 97 和尚偷“荤”【黟县民间故事】
# 98 《凤鸣宏村》剧本获奖
# 99 关帝庙里的海瑞像
# 100 钓鱼岭（吊愚山）【黟县民间故事】
# 101 打鼓岭地名二说
# 102 程家街传说【黟县民间故事】
# 103 “程公墓道”的由来
# 104 百户村【黟县民间故事】
# 105 “八仙抬鼓”的传说
# 106 柏川黄柏山，枞毛豆腐干
# 107 今天冬至
# 108 徽州民歌《牧牛花鼓》《十二月花》亮相央视戏曲频道
# 109 徽风徽韵二省三地京剧票友大赛在屯溪水街开幕
# 110 绩溪第五届中国徽菜之乡美食文化旅游节花絮之一（手机拍）
# 111 绩溪第五届中国徽菜之乡美食文化旅游节花絮之二（手机拍）
# 112 徽州的阴柔之美
# 113 歙县群艺戏曲演唱团将登上CCTV《一鸣惊人》的舞台
# 114 岩寺古镇古街又添新花样---青年旅社迎来试营业
# 115 与族父老书－－汪由敦
# 116 徽州恋
# 117 许勤任广东省委常委、深圳市委书记
# 118 大家来投票
# 119 请大家都来投票
# 120 胡锦涛特殊家世曝光
# 121 汪昌博：登上世界音樂聖殿的徽州人  &  汪昌博：勇攀世界音乐圣殿的黄山人
# 122 绩溪人在上海开埠后经商活动之成就调查
# 123 《徽州汪华》在我市举行首发式
# 124 钱穆与胡适
# 125 胡适生前题墨宝：“努力做徽骆驼”
# 126 瞧，上中央台了哦，真棒！
# 127 越国公汪华创建徽州古城
# 128 我带着兰花草，在大路旁等你——纪念胡适与曹诚英
# 129 纪录片《徽州魂》喊你来做制片人
# 130 胡适眼中的毛泽东
# 131 “急先锋”与“乘势英雄”——胡适与鲁迅
# 132 再提筹建胡适纪念馆—献给胡适先生诞辰124周年--胡成业
# 133 胡适：差不多先生传
# 134 标明钓鱼岛是中国的第一人——胡宗宪
# 135 纪念末代“状元”、抗日烈士吴承仕先生
# 136 请为徽州甲酒投一票
# 137 晏文娟：劳模丰采亮窗口
# 138 胡峤：历史上第一个吃西瓜的歙州人
# 139 詹世钗：通晓多国语言的清代徽州世界第一巨人
# 140 关于举办胡近仁研讨会公告
# 141 胡适批评蒋介石的“新生活运动”
# 142 为我国古典名著加标点符号的第一人----绩溪汪原放
# 143 鹅是老五是徽州人吗
# 144 白衬衫--邓小平登临黄山
# 145 胡适的一篇祝寿文章
# 146 马达：“上海王”柯庆施是个什么样的人?
# 147 初入北大的胡适
# 148 關於城東許氏和許國的問題
# 149 接上
# 150 余彝伯是何人？
# 151 【 每日古黟】西递胡学梓（胡贯三）
# 152 围棋国手过旭初、过惕生
# 153 有哪位知道老徽州时代鲍怡山、程绮堂资料的？
# 154 古徽州第一伟人”汪华
# 155 汪公路是否汪道昆的孙子？
# 156 徽州来的媳妇荣获“全国孝亲敬老之星”奖
# 157 共识网读书会：我们要借胡适来清理骨子里的文革血液
# 158 俺曾经生活战斗过的地方
# 159 三阳90多岁方姓老阿婆
# 160 从此徽州是故乡　我市举办纪念黄炎培考察徽州100周年学术座谈会
# 161 纪念著名出版家汪孟邹先生
# 162 吴兆民著书《春风时雨--黄澍传》出版发行
# 163 婺源回皖联
# 164 林建刚：蒋经国对胡适的批判
# 165 “一叶知秋”的来源
# 166 1958年台湾有人建议：把胡适空投到大陆去祸害大陆人
# 167 舒绣文故居【风水村—黟县屏山村】
# 168 中国围棋两宗师----过惕生丶过旭初（转贴）
# 169 徽州帐房先生和绍兴师爷的博弈
# 170 名妓赛金花惨死之谜
# 171 医文兼通大儒医 ——缅怀新安王氏医学第五代传人王乐匋
# 172 晚年胡适的“率性”与“做圣”
# 173 胡适《沁园春•新俄万岁》
# 174 我奶奶章笑如
# 175 游黄山记（明·潘旦）
# 176 赛金花：常穿男装 曾会见八国联军司令
# 177 欣赏下农民的画作
# 178 曹寅诗题渐江画
# 179 胡宗宪、王直、蒋洲——被遗忘的悲剧
# 180 绩溪名绅胡钟吾             作者:hzwh
# 181 罗志田：文学革命的社会功能与社会反响
# 182 胡适——从绩溪上庄走出的国学大师(组图)
# 183 程门雪生平及其学术传承渊源
# 184 曾官候选布政司理问——这句话怎么解？
# 185 历史上徽州祁门名人
# 186 请问胡适指挥过战争吗？ 为什么毛把胡适定为战犯？
# 187 《歙县志》中的鲍氏名人
# 188 历史上徽州黟县名人
# 189 历史上徽州休宁名人
# 190 清乾隆时期“两淮八大总商”之首、歙县江春
# 191 怀念秦老
# 192 清著名藏书家、文学家祁门人马曰琯、马曰璐兄弟
# 193 许家朋——黄继光式的英雄人物
# 194 民国时期政治家国务总理汪大燮
# 195 令胡适念念不忘的周鲠生
# 196 才思敏捷程敏政
# 197 《回归本意》：似洪？又似程？
# 198 胡适眼中的山东督军田中玉
# 199 韩国“发明”金属活字印刷之说不符史实
# 200 她们的秘密
# 201 清状元休宁黄轩和苏州狮子林的前世今生
# 202 胡适之楹联欣赏              【楹联百科】
# 203 赋春：汉长沙王吴芮后裔望郡
# 204 胡适著作及其研究出版书讯
# 205 胡适与北大旁听生、偷听生-----胡成业
# 206 《才女曹诚英》正式出版发行
# 207 谁挽救了浪荡子胡适？
# 208 程氏中医馆将举办休宁名医汪昂400周年诞辰纪念活动
# 209 天下程姓聚徽州 纪念程灵洗诞生1500周年
# 210 【每日古黟】渔亭名人——金邦正
# 211 新安程氏纪念忠壮公灵洗 诞辰1500周年暨甲午清明篁墩祭祖活动
# 212 徽州先贤：民国交通纺织业、金融业奠基人之一休宁人汪晴江先生
# 213 央视(四套)2月25日晚播出《跨越海峡的大师--胡适》
# 214 1962年2月24日，胡适逝世
# 215 求助：《白际岭下即目》的注释和诗人汪若楫的更多详细
# 216 苏州博物馆的徽州贵潘藏书
# 217 【每日古黟】黟县著名学者俞正燮
# 218 【每日古黟】黟县钟灵毓秀，是人文荟萃之乡。
# 219 血浓于水 绩溪 曹健
# 220 痛悼方氏岳父不幸近世
# 221 同绘黄岳，共话宾翁——徽婺两地开展书画交流
# 222 胡适最生气的时刻
# 223 感谢黄山社科联杨主席一行上门看望   -----   章 亚 光
# 224 山寨鼻祖，民族英雄——汪鋐（转）
# 225 “模范丈夫”詹天佑一生拒绝纳妾
# 226 朱元璋采纳了他的意见，取得了胜利
# 227 转发一篇介绍曹诚英的文章
# 228 转方利山文：上庄朝圣记
# 229 转方利山文：深深的徽州情-----胡适为戴东原洗冤
# 230 转方利山文：上庄朝圣记
# 231 转方利山文：        纪念胡适诞辰122周年
# 232 请教：吕碧城和胡适有过交往吗？
# 233 2013年胡适先生诞辰日纪念活动方案
# 234 锦涛回乡记
# 235 汪由敦因为恩师张廷玉通风报信而被乾隆解除职务
# 236 章铁民,民国时期绩溪的另一位作家
# 237 曹振镛为何成了“庸庸碌碌曹丞相”？？？
# 238 李仲谋又论胡适，各位怎么看？
# 239 故乡活在衣萍心中
# 240 歙县徽墨传承父子兵
# 241 又请教一下各位老师
# 242 又请教一下各位老师
# 243 徽州的
# 244 俺的老本行
# 245 打草鞋
# 246 《人民日报》再次刊文讨论地名问题：不妨恢复“徽州”这样重要的历史地名。
# 247 （转载）徽州之“徽”或名自“徽城”
# 248 怎样学历史——严耕望谈治史
# 249 生僻字相对大全
# 250 一剑行医手札之七 衷中参西治胃病
# 251 徽州古建筑掠影
# 252 开封网：记者万里寻访茶叶路：黄山毛峰 古徽翠香
# 253 经学与朴学
# 254 清明
# 255 苞芦是安庆人带入徽州的，造成徽州水土流失。此文是人民大学张全海的博客上的
# 256 求清代道光和咸丰年间徽州府历代知府和六县各县令名单
# 257 指尖上的传承--歙砚
# 258 中国教育电视台 ：文房四宝——徽墨   歙砚
# 259 徽州民谣----十八摸
# 260 《远方的家》江河万里行 第267集 钱塘江 徽州文化出新安
# 261 《远方的家》江河万里行 第268集 钱塘江 新安江畔古韵长
# 262 宏村
# 263 汪由敦和纪晓岚的情谊
# 264 一个被抹去的徽州人独创汉字
# 265 《胡建华临证治验录》精读
# 266 登临浙岭沿古驿道体验徽州古文化
# 267 “吴楚分源”探寻【作者:詹丹宁/文】
# 268 新安医学传人谈雾霾
# 269 【每日古黟】鼎盛期的西递
# 270 【每日古黟】西递追慕堂
# 271 【每日古黟】西递“追慕堂”
# 272 这碑刻年代上有错！
# 273 八月三日，星期天，徽州文博馆参观记
# 274 齐云山香风茶
# 275 热烈祝贺黄山新职工国旅旅游联盟隆重成立!
# 276 西递敬爱堂
# 277 休宁----中国第一状元县
# 278 王振忠教授著《明清徽商与淮扬社会变迁》（修订版）出版
# 279 关于徽州书籍
# 280 徽州六县图腾的含义
# 281 汉口与徽商
# 282 徽州民谣与徽州人民价值观
# 283 《徽商大典》图录
# 284 新安医学的鲜明特色
# 285 昨夜，你睡得好吗？
# 286 徽商百科全书《徽商大典》面市
# 287 徽商百科全书《徽商大典》面市
# 288 桐城派姚鼐写黟县南屏：万松桥记
# 289 徽州传统宗族的慈善救助与现代慈善救助的比较？
# 290 徽州唐氏三先生（唐元字長孺、唐桂芳字仲實、唐文鳳字子儀）生平介紹
# 291 湖北沙市最早的电灯公司为徽商所开
# 292 徽茶的前世今生
# 293 　子宫肌瘤切莫轻易开刀
# 294 如何正确服用三七
# 295 重修上坞总祠诒荫堂纪略（桂馥）
# 296 稼研会向市图书馆赠书
# 297 休宁名医汪昂《勿药元诠》
# 298 徽州古村发现明代大书法家董其昌临摩的《兰亭序》碑刻
# 299 图说新安医学之古方剂量
# 300 《徐霞客游记》之游黄山日记后
# 301 婺源沱川篁村和罗汉松的由来（转）
# 302 徽语
# 303 与徽州有缘
# 304 2014北京公务员真题涉及到我们徽州文化
# 305 【每日古黟】太白垂钓——浔阳台
# 306 年尚未艾
# 307 【每日古黟】“七省通衢”——渔亭镇
# 308 【每日古黟】秀美宏村
# 309 【每日古黟】西递镇的前世今生
# 310 黟县古筑富春郡孙氏得姓【摘自《族谱》】
# 311 黟县建制的前世今生
# 312 【每日古黟】人文荟萃，风光秀丽的碧阳镇
# 313 【每日古黟】碧阳镇的前世今生
# 314 【每日古黟】黟县北街社区
# 315 【每日古黟】宋朝的黟县行政区划
# 316 鲁迅与沈从文为何老死不相往来？
# 317 【每日古黟】黟县的红色印记
# 318 和大家一起来凑凑徽州文化中的“马”
# 319 漫长的时间里马一直作为战争装备
# 320 绩溪县伏岭下村“纹川舞犭回”，“犭回”字怎么读？
# 321 方静先生在新安医学论坛中作学术报告
# 322 猜猜这是谁的大作？
# 323 “求索上下，震烁古今——纪念戴震诞辰290周年广场文化活动”隆重登场
# 324 2010年7月，黄山学院就已建立徽州文书博物馆
# 325 《徽州上下两千年》由黄山书社出版
# 326 《徽州楹联通览》出版
# 327 地名与徽州区域社会——以婺源县为例
# 328 求许承尧《歙事闲谈》一书
# 329 辑部分论徽商语摘
# 330 一首诗的出处
# 331 [视频]文化观察：《徽州》用影响凝固徽派文化之魂
# 332 汪直？王直？
# 333 王（汪）直真冤    被骂大汉奸
# 334 婺源的中秋（摄影：胡红平）
# 335 [旌德乡贤] 淞沪抗战時的淞沪警备司令戴戟
# 336 叠罗汉
# 337 一剑行医手札之六-----难言之痛
# 338 胡适致陈独秀的一封信
# 339 台灣公視紀錄片-大師胡適[完整版]
# 340 读《阅微草堂笔记》里的徽州鬼事
# 341 读《阅微草堂笔记》——徽州的打虎英雄唐打猎
# 342 读《阅微草堂笔记》之 砚铭
# 343 凤凰卫视看扬州盐商
# 344 徽州满顶床
# 345 1923年胡适闹离婚江冬秀并未称要杀掉儿子？
# 346 商籍
# 347 徽州各县人口比例——按康熙徽州府志
# 348 八年磨一剑   千载汇两帙——新版《黄山市屯溪区志》读后
# 349 祭医神
# 350 梅葛遗制，橘井流香怎么解释？
# 351 遥远的记忆——图说严州淳安、遂安
# 352 上海最大徽州饭店：大富贵
# 353 视频: 【徽州文化】中华楷模
# 354 何为道
# 355 求教：黄山风景区摩崖时刻“祁西王启邦造”由来
# 356 武当淮河派武功医学之二
# 357 何为“武当正宗”
# 358 战胜禽流感
# 359 （3月20日至5月21日）：
# 360 武当六和神功
# 361 纪连海说元宵节
# 362 【分享】珍贵屯溪老照片
# 363 万安寻碑
# 364 发现碑帖，陈版看看
# 365 戴主席讲授徽学知识
# 366 清代徽州府县行政等级（嘉庆时期）
# 367 【分享】徽州武艺
# 368 徽州文书的“再发现”
# 369 原创徽州地区地图
# 370 从秦至清的徽州区域地图
# 371 【转帖】南社与徽州人
# 372 【分享】徽州文化系列谈
# 373 祁门风光之徽州丧事
# 374 【分享】非物质文化遗产：在抢救基础上保护 在保护基础上发展
# 375 【原创】看图说话：“紫阳揽胜”佳联赏析
# 376 【转帖《婺源风俗通观》出版发行
# 377 【原创】徽州文化知识问答·“一科同郡两元”指什么
# 378 【转帖】关于徽学的一些重磅文章
# 379 【原创】方增威的山水画
# 380 【新闻】“中国徽菜之乡”花落黄山
# 381 【原创】徽州名点——渔亭糕
# 382 【转帖】有关学术消息
# 383 【转帖】祁门“猴子”谑称的由来
# 384 【分享】家谱知识讲座
# 385 【转贴】明清时期徽州地区官府士绅的禁奢活动
# 386 【转贴】《徽州文献综录》
# 387 如来佛祖曾到过徽州此处？
# 388 黄山市徽州区文物古迹·趣联集锦
# 389 张潮的梦与影
# 390 徽州大事记
# 391 视频明清时期徽州的家庭与宗族。卞利 教授
# 392 惊现清末徽州“休宁教案”档案文书史料手抄本
# 393 【资料】婺源唐代清代进士榜
# 394 请教：岩寺洪坑洪氏在明清时期的都图？
# 395 新安画派庄家宝先生《新安五月农家忙》欣赏
# 396 安徽省历史上的省界纠纷（统计16起）(转安徽文化网)
# 397 【分享】古歙民谣
# 398 “休阳”何时改称为“休宁”
# 399 徽商起源于何时？
# 400 转帖：徽州古村落——歙南洪琴学徒习俗
# 401 徽学专家张脉贤论汪华
# 402 转帖：徽州古村落——歙南洪琴丧葬习俗
# 403 新安画派“枇杷王”庄家宝先生央视展风采(首发）
# 404 【徽州百草丛谈】：金银花
# 405 歙砚徽墨----《光明日报》
# 406 图解太平猴魁的制作方法
# 407 （原创）【徽州百草丛谈】：凤尾草
# 408 【求助】求以徽州特别是婺源为背景的文学作品
# 409 （原创）【徽州本草丛谈】：薏苡仁
# 410 【转帖】徽菜的特色
# 411 （原创）【徽州本草丛谈】：海金沙
# 412 （原创）【徽州野菜】：话竹菇
# 413 (原创)：说蕨
# 414 请教高手；是茶商信扎还是。。。。。。。。。。。
# 415 “九龙十八龟”巨砚亮相
# 416 秋日小诗
# 417 文学作品中的徽商形象一例
# 418 祁门县祁红乡方氏祠堂的“方字赞”和“祖豆”
# 419 古老村庄体现风水文化
# 420 明清时期扬州的徽商及其后裔述略
# 421 【徽州名人】站上西方讲台上的第一人- 休宁人戈鲲化
# 422 少林武术与徽商及明清以还的徽州社会（王振忠）
# 423 何为“片茶”？
# 424 祁门风光之降上
# 425 皖南"花山谜窟"景区20万巨奖征湖北游客解千年之谜
# 426 徽州的历史和文化习俗
# 427 祠堂的血与泪
# 428 徽州古村落--洪琴<3> （本文转自http://zghssxhq.bokee.com)
# 429 【求助】关于明清时期徽州境内的市镇资料
# 430 晒一晒我的藏书
# 431 新安江成就徽商的同时请不要忘了昌江、青弋江
# 432 笠原仲二说“徽”
# 433 明清徽州戏曲文化
# 434 太极拳鼻祖——歙人许宣平
# 435 此仙人诗也
# 436 《歙风俗礼教考》
# 437 民国芜湖芜关中学徽州分校招生  广告
# 438 清光绪泾县寿民百岁旌表册
# 439 徽州道教思想研究
# 440 倪瓒吴镇谁为真高士
# 441 《图述龙川》书稿内文版式已完成设计请指正
# 442 徽州建筑传统技艺简介（转）
# 443 祁门   徽州文书   徽学
# 444 【珍贵资料】87版徽州地区 地图
# 445 请教！
# 446 【推荐】徽州古村落的演化过程及其机理
# 447 新安医存
# 448 我家有张古代留下来的木床
# 449 象牙朝笏
# 450 2008徽州学动态--方利山
# 451 （鉴赏）清状元殿试试卷原件
# 452 安徽确定30位“非遗”传承人
# 453 新PP......新手试发帖了
# 454 个人想重新恢复百鸟亭（汉威远镇）的扁．大家给点意见
# 455 [分享]少林武术与徽商及明清以还的徽州社会—王振忠
# 456 王振忠：山中兰花草
# 457 【原创】有关安徽清代“盐票”的几件东西
# 458 【转帖】文化传承与儿童教育
# 459 【推荐】中国27处世界文化遗产
# 461 【讨论】徽文化的“力”学命题
# 462 【原创】中医治疗之三因制宜
# 463 【原创】历溪村舞龙风俗
# 464 【原创】徽州文化知识问答·“一镇四状元”在哪个镇
# 465 【分享】古徽州丧事习俗
# 466 【转帖】汪昂汤头歌诀全文
# 467 【原创】我所石雕大师方师傅的作品
# 468 【原创】关注徽州
# 469 【介绍】新安画派——徽州的骄傲
# 470 【原创】【徽州印象·闻正汉字艺术展】
# 471 【原创】棚民与船户
# 472 【推荐】盛世修谱
# 473 【转帖】印刷术的发明
# 474 【原创】徽州文化知识问答·“纸衣”是怎么回事
# 475 【分享】徽商 《日暮乡关》
# 476 【分享】徽商－－日暮乡关（二）
# 477 【分享】徽商 之六《日暮乡关》
# 478 【原创】天上徽州
# 479 【原创】<魅力绩溪>后记
# 480 【原创】徽州文化知识问答·明代徽墨有哪些主要流派
# 481 【原创】徽州文化知识问答·“明代徽州四大墨谱”指哪四部墨谱
# 482 【原创】徽州文化知识问答·什么叫“新安四宝”
# 483 【转帖】评“徽州烈妇”之冤死
# 484 【原创】徽州文化知识问答·“一门八进士，两朝十举人”说的是哪个家族
# 485 【原创】徽州文化知识问答·徽州有哪些教育名家
# 486 【原创】徽州文化知识问答·“父子尚书”是哪两位父子
# 487 【原创】徽州文化知识问答·什么叫“学田”
# 488 【原创】徽州文化知识问答·什么是文会
# 489 【原创】徽州文化知识问答·徽州为什么被称为“东南邹鲁”
# 490 【新闻】万安罗盘物语
# 491 行摄白鹿洞书院
# 492 【新闻】《天上徽州——徽州文化十大流派》首发式即将举行
# 493 【讨论】大家来看看这两个罗盘哪个是徽州产的？
# 494 【推荐】[探索•发现]无徽不成镇 [视频]
# 495 【转帖】徽学与徽州（汪柏树教授）
# 496 【转帖】璀璨的徽州文化
# 497 【转帖】績溪與徽學
# 498 【转帖】明清时期徽州府刻书业
# 499 【转帖】徽州建筑的特色
# 500 【转帖】民风古朴的潭川村(程良奎)
# 501 【转帖】古建民居系列——古黟民居
# 502 【转帖】徽州历史上的数学研究成果
# 503 《天然去雕饰　清水出芙蓉──瞻淇的古村古建》这篇论文谁找得到
# 504 【求助】有谁知道黄海遗民是谁的号？？？？？？？？？？
# 505 【转帖】徽州建筑的特色（马恒）
# 506 【转帖】徽州建筑的特色
# 507 徽州新秀--汪庆誉
# 508 【分享】朱熹理学在徽州的流传与影响（汪 银 辉）
# 509 【转帖】汤显祖的徽州情结
# 510 转贴-- 朱熹的沉浮人生
# 511 新安--歙州--徽州--黄山建置沿革
# 512 【转贴】徽州宗族研究论文索引（1994--2004）
# 513 【转贴】《黄山市旅游业可持续发展研究》
# 514 【原创】在婺源收到的一只（毛瓷）壶
# 515 金庸入选语文读本 2005年教科书之年终解读
# 516 【转帖】徽州文化世家的形成及其特征（史向前 ）
# 517 西秀区吉昌屯：正月十八“抬汪公” 全域旅游新亮点
# 518 这个繁体字不认得，求助一下
# 519 致贵州安顺2016“屯堡学”国际学术研讨会贺信
# 520 首届隆阜戴氏后裔交流会在徽州东原故里举行
# 521 致贵州2016屯堡文化学术研讨会贺信
# 522 屯安东：“两座黟山”之困惑
# 523 方利山：  屯堡“抬汪公”源自徽州文化  ——兼与陈训明商榷
# 524 方利山文：屯堡与徽州
# 525 有谁知道设置在屯溪的茶业公所是这么回事吗？是指咸丰年间的，不是同光的哦！
# 526 关于举办“胡适与绩溪民国史研究”学术研讨会公告
# 527 方利山：有关汪王墓“唐宋诰敕”碑再考
# 528 浅谈商业WiFi的几大潜力市场
# 529 绩溪胡适研究第六期
# 530 民国年代曹锟就任巨额买来的大总统
# 531 明清以降歙县闺阁诗
# 532 婺源有个何如宠！一块很有价值的碑！
# 533 戏人看戏  说班论剧
# 534 “悦”读徽州——《阅读徽州》读后
# 535 绩溪徽学通讯目录（第24期）
# 536 那一段往事,绩溪划归宣城的历史片段
# 537 “海峡两岸朱子齐家思想与当代家庭建设学术研讨会”在武夷召开
# 538 《源的守望——徽州文化生态保护研究》正式出版
# 539 菲元：黄山轩辕黄帝文化   安徽珍贵文化资源
# 540 【转载】先锋书店第八家书店位于安徽黟县碧山村的碧山书局
# 541 黄山雨后云海气势磅礴
# 542 向“故园徽州论坛”表示歉意
# 543 一篇关于“君子文化”的文章，从新视角研探徽州文化
# 544 关于这个“luo”字，转一篇文章
# 545 痛风患者的日常调护
# 546 《樹蘐草堂诗词》《蘭蔭山房诗集》家印本
# 547 一曲大美徽州的赞歌
# 548 【徽州大论坛】徽州人的茶道
# 549 徽学研究延入美学方法
# 550 《审美徽州》序
# 551 屯溪老在哪里？----胡宁
# 552 安徽省徽州学会第四次理事代表大会暨2014年学术年会在合肥召开
# 553 袁枚与地域诗人交游交往实证研究——以徽州婺源诗人为中心的考察
# 554 文艺家下基层
# 555 汪华文化研究新推进------“汪华文化高端论坛 ”在合肥安大顺利举办
# 556 致“汪华文化高端论坛”贺信
# 557 徽州方志名家罗愿、戴震、洪亮吉引人注目------古代方志名家学术研讨会在马鞍山召开
# 558 木与刀的艺术：徽州传统木雕浅析
# 559 吕蒙不读书40章,第四十章林历山--完美星空
# 560 从《福熙自述》透视民国时期徽商的命运
# 561 历史中的江南文化
# 562 胡鹏池：为什么说胡耀邦是当代中国第一人？
# 563 绩溪徽学通讯第二十一期
# 564 《新安医学文化博览》读后感
# 565 270多件清代徽商家族文书面世
# 566 方利山：朱熹与当代教育在朱子教育思想与当代教育学术研讨会上的演讲（摘要）
# 567 纪念甲午战争120周年：维新派对甲午中日战争的反思
# 568 屯溪 的历史上的几个问题（没有答案）（抛砖引玉）
# 569 绩溪胡氏探秘                             黄来生
# 570 消失的古越王国-------屯溪地区在公元前1000前的历史
# 571 方腊被谁所擒
# 572 新安名医世家临床学术传承高级研讨班花絮
# 573 国家统计局公布全国前20大姓氏
# 574 一史：明清以降徽州闺阁诗述略（上）
# 575 给故园徽州十周年送  喜
# 576 论徽商兴衰的原因
# 577 关于举办现代著名出版家汪孟邹学术研讨会公告
# 578 绩溪徽学通讯十九期目录
# 579 方金福先生的广州来信
# 580 朱熹理学在徽州的普世化---方利山
# 581 转方利山文：收拾遗痕零落后——贺《程灵洗与徽州社会》出版发行
# 582 肾结石克星——核桃仁
# 583 转方利山：纪念陈荣捷先生逝世20周年-----陈荣捷先生书信十二通
# 584 徽州官宦世家的仕宦、交际、侨寓与公益事业实证研究 ——以婺源漳溪王氏为例
# 585 赠送三本个人文章-----章 亚 光
# 586 历史上短命的广德王国【一段尘封的徽州前世】
# 587 绩溪徽学通讯第二十期目录
# 588 多看看（中国政治的变局：党政关系的新走向）
# 589 《审美徽州》目录（暂定）
# 590 甲午年五运六气与气候及疾病防治
# 591 婺源虹关“立交桥”
# 592 程家街（秦桧街）的传说
# 593 探讨“伏龙乡”的相关史实--------章  亚  光
# 594 (转贴)600年的海宁查家
# 595 与你走近戴东原(九)------戴震论治学            方利山
# 596 与你走近戴东原(七)------戴学的人民性             方利山
# 597 方利山：与你走近戴东原（五）——戴震“好名心甚”吗
# 598 与你走近戴东原(四)------戴震不好为人师              方利山
# 599 沛隆堂医话 甘温除大热
# 600 与你走近戴东原(二)------人们对戴学的反应        方利山
# 601 转方利山文：与你走近戴东原(一)------谈戴震对中华文化的主要贡献
# 602 话说《德智堂抄本》----《瀛洲钩沉》跋
# 603 徽学家王世华呼唤“徽州”
# 604 汤老师“痴绝”苦了自己
# 605 千年徽州文书    学术大厦基石（二）
# 606 千年徽州文书    学术大厦基石（三）
# 607 中国现代作家章衣萍学术研讨会在 章衣萍的家乡 绩溪伏岭顺利举行
# 608 11月徽州文化研究新信息
# 609 揭秘中国十大商帮经营之道：徽商势力最大影响最深远
# 610 嵇康--竹林七贤人物之一，其墓在休宁谁知道？
# 611 清代徽州人入籍兰溪事件 -------- 以《郑三乐堂请入籍案簿》为例
# 612 戴震研究会将组织理事赴婺源江永故里江湾学术考察
# 613 汤显祖的徽州友人
# 614 思想实验之一（猴子和打字机）（Monkeys and Typewriters）
# 615 是废弃皇陵还是史前文明？安徽花山谜窟猜想（图）
# 616 此句是否汤翁所说---“吴序怜予乏绝，劝为黄山白岳之游，不果”
# 617 绩溪西关章氏宗谱发现章衣萍
# 618 大话农夫第二问：打秋风岂是门客和坐馆先生？
# 619 《明史》对汤老师评价很高
# 620 转菲元文：对徽商的几点品读（一）
# 621 耿云志：胡适在香港讲演引起的风波
# 622 转菲元文：对徽商的几点品读（七）
# 623 转菲元文：对徽商的几点品读（五）
# 624 转菲元文：对徽商的几点品读（三）
# 625 大话农夫第一问：1601年，汤显祖如何见得到许国？
# 626 （转贴）朱熹是历史上一位有相当成就的自然科学家
# 627 转菲元文：          徽商与中华慈善
# 628 “徽商与徽州文化”学术研讨会月底在合肥召开
# 629 徽州文化的自然美学特色
# 630 蹯溪真有女祠吗？
# 631 晚清民国徽州基层社会问题管窥——以档案资料“詹礼恭演戏聚赌案”为例
# 632 看徽州文书的先进性！
# 633 杭州汪庄汪裕泰茶号之徽州茶商传奇
# 634 有谁知道这段---------
# 635 发今天第一帖
# 636 徽州才女写的一首诗
# 637 台湾作家交流访问团来古城歙县采风
# 638 俞晓群：一位备受争议的文化奇人王云五
# 639 旌德舒雅是状元【2013版】
# 640 一剑行医小札之八  针药并施治头痛
# 641 大家一起来下载_金瓶梅相关研究资料
# 642 （转载）杨建民：胡适读毛泽东诗词
# 643 金瓶梅作者有可能是汪道昆再考
# 644 转：黄老与徽州文化             方利山
# 645 绩溪徽学通讯目录（18期）
# 646 乡村习俗，樟树上挂刀
# 647 刘伯山再访汪足意聊“徽学”
# 648 沈卫威：大河之旁必有大城——胡适与五四新文化运动
# 649 乾隆吧
# 650 《婺源十二都庆源詹氏文书》寻获记
# 651 转:周质平谈胡适
# 652 何仁勇：一言难尽道朱熹
# 653 非常支持徽州文化研究的一个新开掘                菲   元
# 654 说“说鳖”
# 655 转菲  元文：徽州抬汪公民俗的价值及利用前景
# 656 转方利山文：徽州宗族祠堂的逾制和功能转换--朱熹理学与徽州宗族祠堂（二）
# 657 转菲元文：从朱为弼不当“蝗虫”说起——徽州廉政文化初识
# 658 海峡两岸四地“朱子学与地域文化研究”学术研讨会2013年7月10日在徽州婺源..
# 659 访问明代建筑大夫第的后人
# 660 历史镜鉴---古徽州的清官廉吏      (菲  元   徐小剑)
# 661 我的徽州文书缘（作者，王振忠，原载中国档案）
# 662 《徽州抬汪公 》一书近日印行
# 663 转方利山-----《徽州大讲堂》文字稿:  徽州的太阳汪华
# 664 读“三精成一毒”有感！
# 665 【建议】黄山市应主动出击：成立中国徽学院
# 666 文会条约
# 667 新年到了 晒点东东（二）
# 668 【推荐】确认篁墩在中国移民史上的地位
# 669 【徽学文摘】唐末五代徽州的北方移民与经济开发（张宪华）
# 670 【转帖】徽语中的几个本字（２００２）
# 671 清咸丰年未刊手稿本《梦仙诗草》（鄙藏徽人著作之三）
# 672 请问有谁知道马曰琯、马曰璐的故乡在祁门什么地方？
# 673 “汪华现象与徽州社会学术研讨会”，2012年12月29日在安徽合肥召开
# 674 徽剧的发源地究竟在哪里
# 675 王振忠新著《千山夕阳：明清社会与文化十题》，
# 676 [原创]胡氏支谱（我家的）
# 677 【原创】徽人的店铺招牌
# 678 【原创】《安徽贡卷》
# 679 【原创】清末徽州民间宗谱纂修活动初探
# 680 【原创】祁门县新发现的两通宋代阴契
# 681 【转帖】（有些音标无法显示，删了或有所改动）
# 682 【原创】浅谈“诗中有画”与“画中有诗”
# 683 【新闻】150多名中外专家安徽研讨黄山民间文献
# 684 【分享】“新安大好山水”之出处
# 685 【求助】请各位网友帮忙!!!!!!!!!!!!!!
# 686 【原创】黄山市程朱理学研究会  文公厥里考察座谈会  召开
# 687 [原创]抗战期间日军对歙县轰炸的暴行（整理稿）
# 688 摇曳多姿的《黟山竹枝词》
# 689 歙县人名的怪异称呼
# 690 寄籍苏州的徽州人影像资料
# 691 【原创】：尽信谱不如无谱
# 692 朱熹理学与徽州祠堂
# 693 求潘氏排辈字...................
# 694 （转小雯报道）朱子学与文化建设学术研讨会在福州召开
# 695 求解两块砖雕图意
# 696 试论俞正燮对俄罗斯研究的贡献
# 697 石桌韭菜惊捻头  智圆村落平安梦
# 698 老木雕
# 700 [学术会议] 第二届两岸历史文化研习营——徽州
# 701 帽兄：给您“鲍康”
# 702 良医常从“意会”中来
# 703 徽州民间中医药文化漫谈
# 704 香港中文大学在婺源考察历史文化
# 705 【建议】关于征集徽州民谣的倡议
# 706 馆展珍品：嘉庆十九年十二月万庆堂墨商詹南金立遗嘱文书
# 707 王振忠<徽州与衢州:江南城乡的片断记忆>
# 708 从徽雕看徽文化的敛与放
# 709 大清乾隆59年徽班义顺班班众立约文书
# 710 一份徽商之妻的借银契约
# 711 [大讨论]：高湖山的“湖”哪去了？
# 713 祥龙舞中秋
# 714 无徽不成镇的出处？(找到同治年间的)
# 715 转方利山文：徽剧的徽州土壤
# 716 徽商楹联
# 717 朱升与晋商
# 718 珍 贵 的 茶 商 信 札
# 719 [求助]谁有“前世不修，生在徽州”民谣的比较完全的版本？
# 720 河里寻到一个古建筑石头
# 721 宁波海上丝绸之路和徽帮贸易
# 722 讨论：这里的“全区”是指“二市七县”还是指“一府六县”
# 723 徽州文化还会有现在时和将来时吗？
# 724 征集徽州历史组织名称
# 725 徽州宗教史上的重大发现——休宁教案
# 726 浅议《新安名族志》中有关“章姓”的差错-- 章 亚 光
# 727 唐模许翁散财试说--汪大白
# 728 徽商之文化解读---方利山
# 729 程霖生：近代最大徽商的破产
# 730 《我的故乡绩溪》出版发行了
# 731 （原创）徽州饮食中禁忌初探
# 732 请教版主
# 733 800年徽州社会到底是什么社会形态？
# 734 徽州文化中的生命关怀--方利山
# 735 绩溪胡氏探秘
# 736 徽州“抬汪公”民俗及价值---方利山
# 737 讨教土族、农夫、村人诸兄“萼庾”为何意？
# 738 歙县人名的怪异称呼
# 739 【原创】为什么合肥房子是这样的？
# 740 徽语介绍帖，不断更新
# 741 黄之隽《黄墩辨诬》
# 742 2009’安徽省徽学学会学术年会会场
# 743 徽州民间租田契约
# 744 曹寅诗题渐江画
# 745 偶在偶村搞了个讲座，宣传徽文化（花絮）
# 746 大清光绪31年立押会(股)票
# 747 新安医家汪昂成功之道探析
# 748 董小宛曾游黄山
# 749 旅游发展背景下的徽州文化遗产保护模式研究
# 750 刘大槐与徽州学术文化——兼为吴孟复《刘大櫆简谱》作补正
# 751 张謇为婺源江湾永思堂所撰《重建宗祠记》
# 752 清代<吃茶经>再现江湖
# 753 求助：哪位大侠知道歙县雄村曹氏“行第诗”？
# 754 【推荐】说说徽学
# 755 视觉化的思考：藏医唐卡对徽文化传播的启示
# 756 "一生痴绝处，无梦到徽州。"
# 757 从徽州古建筑看徽州文化--徽州古民居
# 758 从徽州古建筑看徽州文化---徽州古牌坊
# 759 从徽州古建筑看徽州文化---徽州古祠堂
# 760 【原创】新安医学发展的思考（一）
# 761 祁门县历溪目连戏遗存田野调查及其研究
# 762 热烈祝贺徽州女子、程老虫新当选为第三届徽学学会理事
# 763 郑之珍与目连戏的几个问题
# 764 【徽学文摘】徽州宗族研究综述（任志强）
# 765 【讨论】这个建筑能否代表新徽派建筑作品?
# 766 【思维在先】新安医学研究必要的资料参考！
# 767 徽州民居是徽州文化的结晶？（转）
# 768 王仲奇用药精义初探
# 769 象牙酒牌
# 770 什么是儒商
# 771 徽州“踏果”和墨西哥“TACO”
# 772 民国《新安归厚堂》收据
# 773 爷爷留下的东西~~~
# 774 复旦大学文史研究院院长葛兆光教授为王振忠教授整理的《我之小史》所作的序文
# 775 婺源端午习俗初探
# 776 一份旅外徽州人的金兰谱
# 777 《民国徽州名师》序言（聂圣哲）
# 778 徽州“嬷米”习俗初探
# 779 【原创】水口园林
# 780 黄山市社科联主持召开金瓶梅与徽文化研讨会
# 781 汪华研究—徽州学的新拓展
# 782 【分享】徽州文书研究十年回顾（阿风）
# 783 [转帖]徽商的儒学气质
# 784 强调保护徽州文书，不应走向偏差
# 785 [转帖]徽州人与徽州文化的关系之审美解读====洪玉良
# 786 淮北盐业中的集团博弈与利益分配(1700—1932)
# 787 史实考证龙川胡氏迁自婺源
# 788 【原创】新安医学的概念
# 789 【分享】胡氏宗祠木雕与金华火腿
# 790 【转贴】胡 锦 涛同志家谱考
# 791 【原创】请赐教这些是什么字
# 792 【转帖】古徽州牌坊的背后
# 793 【原创】徽文化的精神是什么?
# 794 【求助】首届中国传统木雕（花板）研讨会主题---徽州木雕
# 795 【讨论】谈谈黟县的"黟字"的由来
# 796 何为新徽派建筑?
# 797 【原创】徽州民居保护----一个沉重困惑的难题
# 798 【求助】谁能帮忙把这几篇文章内容转贴到这里，谢谢了
# 799 【转帖】姓氏 胡 的由来(探讨+转帖+欢迎补充)
# 800 【原创】浅谈继承“固本培元”学术思想的重大意义
# 801 【讨论】黄山积极规划申报首批国家文化生态保护区
# 802 【转帖】汪氏古村和其传承一千三百余年的祭祖风俗
# 803 【原创】关于明代中后期契约上“税明”二字的新发现
# 804 【转帖】 安徽祁门县的《游太阳》
# 805 【新闻】“徽州文化与和谐社会”研讨会召开
# 806 【原创】瞎子摸象与徽州研究
# 807 【原创】徽州文化是当时代治理社会的最优秀的文化
# 808 【讨论】徽==皖?肯德鸡==麦当劳?
# 809 【讨论】徽州及临域，古道资料征集
# 810 【原创】徽州文化的批判与发展
# 811 【原创】《走近徽文化》后记
# 812 【分享】徽  菜  发  源  绩  溪  考
# 813 【原创】徽州学研究对象及学科体系的构建
# 814 【原创】一一关于绩溪县申报国家历史文化名城的几点思考
# 815 【讨论】为何我们不可以创造新的徽州文化
# 816 【转帖】徽商的辉煌业绩源自高文化素质与创新精神（叶显恩）
# 817 [转贴]徽语的特点和分区（再续）
# 818 [转贴]徽语的特点和分区
# 819 【原创】徽州书院起始何时？
# 820 【原创】昔日徽州的穷与富
# 821 【转帖】太平天国战争中的徽州与徽州人
# 822 【转帖】徽剧：完美的唱念做打
# 823 【原创】建设新农村可以借监徽州古代农村建设的经验
# 824 【转帖】清代徽州土地与商业投资回报率的比较（汪崇筼）
# 825 【讨论】为什么删我的帖?
# 826 【转贴】南通近代史上的三位婺源人
# 827 【讨论】努力做"徽骆驼"
# 828 【讨论】【原创】徽州古代农业的科学性、生态性值得今人借监
# 829 【转帖】官方提倡“和谐社会”民间推动“儒学复兴”
# 830 【转帖】少林武术与徽商及明清以还的徽州社会
# 831 【求助】扪心自问，你对程朱理学的了解究竟有多少？
# 832 【转帖】徽州地名考
# 833 “万世师表”耀后人
# 834 【转帖】徽学工作者的责任
# 835 【推荐】三国志中和徽州有关的人物传
# 836 雄村曹氏与曹雪芹家族出自徽州黄墩考
# 837 中国近1000年历史与徽州的紧密接轨（2）------慈禧当太后与徽人损银300两有关
# 838 【转贴】论明清徽州书院的社会功能——一种社会学视角
# 839 『 徽学殿堂 』 大家来讨论一下徽州在抗战期间为何没有沦陷？
# 840 给古建筑穿上隐形的铠甲
# 841 徽州
# 842 老屋
# 843 彩虹桥古徽州人的信仰之桥
# 844 中国在海外唯一完整古宅被卖18年 日参观人数上万
# 845 顺其自然，这个什么派？
# 846 龙
# 847 文承堂附属屋完整修复
# 848 清代前期徽州民间的日常生活
# 849 徽州彩绘壁画走进铜陵
# 850 20140310发现《黄山志》没有记载的摩崖石刻
# 851 徽山徽水徽文化 寻梦古徽州歙县行
# 852 张建平  摄影师从徽州乡村捕捉生动片刻
# 853 许琦  徽州庆贺性民俗不一般
# 854 细读【与董思白书】
# 855 剧作引起轰动 徽州才女吴藻的感情人生
# 856 三亚学院外国语分院院长汪士彬
# 857 一剑行医手札之二 千古之秘
# 858 【转帖】季羡林：站在胡适之先生墓前(转载)
# 859 求教
# 860 【分享】百件皇家秘档将在休宁展出
# 861 【注意】荧屏再现徽商传奇
# 862 【转帖】我的“徽学”情结（鲍义来）
# 863 【讨论】《金瓶梅》与徽州旅游关系非比一般
# 864 【转贴】徽州文化中的烟文化
# 865 平民学校，生活即教育。
# 866 对“徽州文学”几个基本问题的思考（吴兆民）
# 867 关于申报安徽省第三批省级非物质文化遗产名录项目有关事项的通知
# 868 状元文化登上国家名片 弘扬徽州状元文化
# 869 努力推动传统徽州文化的新繁荣
# 870 《徽州文化全书》各卷作者名单
# 871 【公告】“徽商银行”杯徽州文化百题知识竞赛奖项设置
# 872 【新闻】安徽省"非物质文化遗产"成果展 9日缤纷启幕
# 873 【新闻】黄山市首批非物质文化遗产名录公示
# 874 【推荐】  推介方利山先生3部书  [可以购买]
# 875 旌德方言到底是不是徽语呢?大家意见呢?
# 876 【新闻】《焦点·风土中国》推出徽州专辑
# 877 【转帖】文化遗产：保护重要还是申报重要？
# 878 【转帖】儒學在當今中國有什麽用
# 879 【原创】胡总向工人鞠躬---在青藏铁路通车典礼上
# 880 【推荐】专论徽州女人（一）
# 881 要把徽学研究提高到徽州五百年文明和谐社会的高度上来讨论研究
# 882 [转帖]市委党校升为大专体制
# 883 古籍基础知识
# 884 【求助】寻徽学研究方面的老师参与《徽学》系列节目制作
# 885 【转贴】关于我国人文生态环境保护问题及其产生原因与对策
# 886 【转贴】祁门清代诉讼档案解读
# 887 小型盆景的制作及养护
# 888 树桩盆景与盆栽植物的区别
# 889 徽刻版画欣赏作者：苍生皆偶然
# 890 过几天到婺源去收破烂
# 891 【原创】光绪刻本《涤华馆诗集》
# 892 【讨论】婺州、婺源与婺江何关系
# 893 【讨论】【求助】请求
# 894 【求助】关于徽州文化及茶文化的诗篇
# 895 【求助】因收集资料，暂借有关徽州书籍，望相助
# 896 【推荐】中国海南的徽文化研究会
# 897 【求助】[求助]

# %%
print url
# Out:
# forum.php?mod=viewthread&tid=195025&extra=page%3D1%26filter%3Dtypeid%26typeid%3D162

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 899 entries, 0 to 898
# Data columns (total 11 columns):
# dt          899 non-null object
# source      899 non-null object
# domain      899 non-null object
# url         899 non-null object
# title       899 non-null object
# summary     899 non-null object
# image       899 non-null object
# brief       899 non-null object
# body        899 non-null object
# raw_page    899 non-null object
# from        899 non-null object
# dtypes: object(11)
# memory usage: 84.3+ KB

# %%
for i in range(0, 1):
    url_0 = news_url
    print url_0
    browser.get(url_0)
    time.sleep(5)

    soup = BeautifulSoup(browser.page_source)
    sub_text = soup.findAll('div', {'class':'listA_title'})

    for item in sub_text:
        t1 = item.find('div', {'class':'listA_Time'})
        #print 'www.hzwh.com/' + item.a['href']
        #print t1.text
        print item.a.text
        url = 'www.hzwh.com/' + item.a['href']
        
        not_existed = True
        #check if in cleaned set
        if t1 != None and len(df_check) != 0:
            t0 = abs(sum(df_check['url'].str.find(url))) 
            if t0 != len(df_check):
                not_existed = False

        #check if in dynamic set
        if t1 != None and len(df) != 0 and not_existed == True:
            t0 = abs(sum(df['url'].str.find(str(url)))) 
            if t0 != len(df):
                not_existed = False

        #print t0, len(df), t1

        if not_existed == True and t1 != None:   
            print "-------- add"
            df.loc[idx] = get_empty_columns()        
            df.loc[idx]['url'] = url
            df.loc[idx]['title'] = item.a.text
            df.loc[idx]['source'] = '徽州文化网'
            df.loc[idx]['dt'] = t1.text
            idx += 1
# Out:
# http://www.hzwh.com/toplistb.asp?id=229&page=0
# 传统徽州仁商义贾践行商君子之道的历史启示
# 《阅读徽州》第七编“徽州科技”
# 传统徽商的诚信为本和仁义向善
# 传统徽商的诚信为本和仁义向善
# 黟县古城改造重要的是务须保住文教根脉
# 推动徽州传统文化的普及宣传
# 徽学与当代学术
# “儒学与地域文化：徽学国际学术研讨会”综述
# 洪经纶墓葬地点的疏证
# 徽州乡镇志中所见明清民间救荒措施
# 徽州文化全书
# 论文化生产力与中部地区的经济发展
# 徽州书院的讲会
# 明代海上徽帮与宁波海上丝绸之路
# 徽州昌溪周氏家族与宁波近代商业发展史
# 徽商历史的文化价值批判
# 徽商
# 徽商文化及特点
# 婺源徽剧音乐研究
# 古徽州和谐乡村社会建设的经验
# /usr/local/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 162 of the file /usr/local/Cellar/python/2.7.10_2/Frameworks/Python.framework/Versions/2.7/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html5lib")
#
#   markup_type=markup_type))

# %%
print len(df)
# Out:
# 0

# %%
df.head(50)
# Out:
#             dt source domain                              url  \
# 0   2004-03-03  徽州文化网         www.hzwh.com/article.asp?id=533
# 1   2004-03-03  徽州文化网         www.hzwh.com/article.asp?id=532
# 2   2004-03-09  徽州文化网         www.hzwh.com/article.asp?id=530
# 3   2004-03-22  徽州文化网         www.hzwh.com/article.asp?id=528
# 4   2004-03-31  徽州文化网         www.hzwh.com/article.asp?id=527
# 5   2004-04-02  徽州文化网         www.hzwh.com/article.asp?id=525
# 6   2004-04-11  徽州文化网         www.hzwh.com/article.asp?id=523
# 7   2004-04-12  徽州文化网         www.hzwh.com/article.asp?id=521
# 8   2004-04-15  徽州文化网         www.hzwh.com/article.asp?id=520
# 9   2004-04-15  徽州文化网         www.hzwh.com/article.asp?id=518
# 10  2004-05-11  徽州文化网         www.hzwh.com/article.asp?id=517
# 11  2004-05-13  徽州文化网         www.hzwh.com/article.asp?id=516
# 12  2009-04-28  徽州文化网         www.hzwh.com/article.asp?id=505
#
#                   title summary image brief body raw_page from
# 0            旧时徽州税票名称种种
# 1           小小大阜村 爷孙宰相俩
# 2            李良春与《惯痴文集》
# 3                 古老的石林
# 4                 洪钧行书联
# 5            万安“中国罗盘之乡”
# 6                   吕仙宫
# 7               溪 头 探 古
# 8        五绝《小桃源》中否李白所作？
# 9               解读戴震诗一首
# 10        安徽休宁——中国第一状元县
# 11           独树一帜的徽州税文化
# 12  扬弃古徽州廉政文化 促进新黄山廉政建设

# %%
print len(df)
# Out:
# 0

# %%
def url_get(url):
    browser.get(url)
    print url
    time.sleep(5)
    return browser.page_source

# %%
df['dt'] = df_check['dt']
df['source'] = df_check['source']
df['url'] = df_check['url']
df['title'] = df_check['title']
df['raw_page'] = df_check.url.map(lambda x: url_get('http://' + x) )
# Out:
# http://www.hzwh.com/article.asp?id=2538
# http://www.hzwh.com/article.asp?id=2537
# http://www.hzwh.com/article.asp?id=2536
# http://www.hzwh.com/article.asp?id=2535
# http://www.hzwh.com/article.asp?id=2534
# http://www.hzwh.com/article.asp?id=2533
# http://www.hzwh.com/article.asp?id=2099
# http://www.hzwh.com/article.asp?id=2098
# http://www.hzwh.com/article.asp?id=1848
# http://www.hzwh.com/article.asp?id=1847
# http://www.hzwh.com/article.asp?id=1846
# http://www.hzwh.com/article.asp?id=1794
# http://www.hzwh.com/article.asp?id=1695
# http://www.hzwh.com/article.asp?id=1694
# http://www.hzwh.com/article.asp?id=1693
# http://www.hzwh.com/article.asp?id=1624
# http://www.hzwh.com/article.asp?id=1623
# http://www.hzwh.com/article.asp?id=1622
# http://www.hzwh.com/article.asp?id=1455
# http://www.hzwh.com/article.asp?id=1418
# http://www.hzwh.com/article.asp?id=1417
# http://www.hzwh.com/article.asp?id=1416
# http://www.hzwh.com/article.asp?id=1415
# http://www.hzwh.com/article.asp?id=1414
# http://www.hzwh.com/article.asp?id=1347
# http://www.hzwh.com/article.asp?id=1346
# http://www.hzwh.com/article.asp?id=1342
# http://www.hzwh.com/article.asp?id=1341
# http://www.hzwh.com/article.asp?id=1337
# http://www.hzwh.com/article.asp?id=1336
# http://www.hzwh.com/article.asp?id=1335
# http://www.hzwh.com/article.asp?id=1334
# http://www.hzwh.com/article.asp?id=1333
# http://www.hzwh.com/article.asp?id=1331
# http://www.hzwh.com/article.asp?id=1330
# http://www.hzwh.com/article.asp?id=1329
# http://www.hzwh.com/article.asp?id=1328
# http://www.hzwh.com/article.asp?id=1327
# http://www.hzwh.com/article.asp?id=1326
# http://www.hzwh.com/article.asp?id=1325
# http://www.hzwh.com/article.asp?id=1323
# http://www.hzwh.com/article.asp?id=1322
# http://www.hzwh.com/article.asp?id=1321
# http://www.hzwh.com/article.asp?id=1320
# http://www.hzwh.com/article.asp?id=1319
# http://www.hzwh.com/article.asp?id=1318
# http://www.hzwh.com/article.asp?id=1317
# http://www.hzwh.com/article.asp?id=1316
# http://www.hzwh.com/article.asp?id=1315
# http://www.hzwh.com/article.asp?id=1314
# http://www.hzwh.com/article.asp?id=1313
# http://www.hzwh.com/article.asp?id=1312
# http://www.hzwh.com/article.asp?id=1311
# http://www.hzwh.com/article.asp?id=1310
# http://www.hzwh.com/article.asp?id=1309
# http://www.hzwh.com/article.asp?id=1308
# http://www.hzwh.com/article.asp?id=1307
# http://www.hzwh.com/article.asp?id=1306
# http://www.hzwh.com/article.asp?id=1305
# http://www.hzwh.com/article.asp?id=1304
# http://www.hzwh.com/article.asp?id=1303
# http://www.hzwh.com/article.asp?id=1302
# http://www.hzwh.com/article.asp?id=1301
# http://www.hzwh.com/article.asp?id=1300
# http://www.hzwh.com/article.asp?id=1299
# http://www.hzwh.com/article.asp?id=1298
# http://www.hzwh.com/article.asp?id=1297
# http://www.hzwh.com/article.asp?id=1271
# http://www.hzwh.com/article.asp?id=1270
# http://www.hzwh.com/article.asp?id=1267
# http://www.hzwh.com/article.asp?id=1264
# http://www.hzwh.com/article.asp?id=1263
# http://www.hzwh.com/article.asp?id=1261
# http://www.hzwh.com/article.asp?id=1260
# http://www.hzwh.com/article.asp?id=1259
# http://www.hzwh.com/article.asp?id=1258
# http://www.hzwh.com/article.asp?id=1257
# http://www.hzwh.com/article.asp?id=1256
# http://www.hzwh.com/article.asp?id=1255
# http://www.hzwh.com/article.asp?id=1254
# http://www.hzwh.com/article.asp?id=1253
# http://www.hzwh.com/article.asp?id=1252
# http://www.hzwh.com/article.asp?id=1251
# http://www.hzwh.com/article.asp?id=1250
# http://www.hzwh.com/article.asp?id=1249
# http://www.hzwh.com/article.asp?id=1248
# http://www.hzwh.com/article.asp?id=1247
# http://www.hzwh.com/article.asp?id=1246
# http://www.hzwh.com/article.asp?id=1245
# http://www.hzwh.com/article.asp?id=1244
# http://www.hzwh.com/article.asp?id=1243
# http://www.hzwh.com/article.asp?id=1242
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-164-358563e4bc3a> in <module>()
#       3 df['url'] = df_check['url']
#       4 df['title'] = df_check['title']
# ----> 5 df['raw_page'] = df_check.url.map(lambda x: url_get('http://' + x) )
#
# /Library/Python/2.7/site-packages/pandas/core/series.pyc in map(self, arg, na_action)
#    2043                                      index=self.index).__finalize__(self)
#    2044         else:
# -> 2045             mapped = map_f(values, arg)
#    2046             return self._constructor(mapped,
#    2047                                      index=self.index).__finalize__(self)
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62187)()
#
# <ipython-input-164-358563e4bc3a> in <lambda>(x)
#       3 df['url'] = df_check['url']
#       4 df['title'] = df_check['title']
# ----> 5 df['raw_page'] = df_check.url.map(lambda x: url_get('http://' + x) )
#
# <ipython-input-163-99c375afb9a4> in url_get(url)
#       1 def url_get(url):
# ----> 2     browser.get(url)
#       3     print url
#       4     time.sleep(5)
#       5     return browser.page_source
#
# /usr/local/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in get(self, url)
#     246         Loads a web page in the current browser session.
#     247         """
# --> 248         self.execute(Command.GET, {'url': url})
#     249
#     250     @property
#
# /usr/local/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in execute(self, driver_command, params)
#     234         response = self.command_executor.execute(driver_command, params)
#     235         if response:
# --> 236             self.error_handler.check_response(response)
#     237             response['value'] = self._unwrap_value(
#     238                 response.get('value', None))
#
# /usr/local/lib/python2.7/site-packages/selenium/webdriver/remote/errorhandler.pyc in check_response(self, response)
#     190         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     191             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 192         raise exception_class(message, screen, stacktrace)
#     193
#     194     def _value_or_default(self, obj, key, default):
#
# TimeoutException: Message: Error loading page, timed out (onDOMContentLoaded)

# %%
df['url'] = 'http://' + df['url']

# %%
df.head()
# Out:
#            dt source domain  \
# 0    2017-2-9   故园徽州
# 1    2017-1-1   故园徽州
# 2  2016-11-23   故园徽州
# 3  2016-10-25   故园徽州
# 4  2016-10-17   故园徽州
#
#                                                  url  \
# 0  forum.php?mod=viewthread&tid=195025&extra=page...
# 1  forum.php?mod=viewthread&tid=194254&extra=page...
# 2  forum.php?mod=viewthread&tid=192264&extra=page...
# 3  forum.php?mod=viewthread&tid=189658&extra=page...
# 4  forum.php?mod=viewthread&tid=189555&extra=page...
#
#                         title summary image brief  \
# 0  【春节民俗活动预告】——中云镇桃溪坑头“抬汪公”民俗
# 1               2017.01.01的早上
# 2                       上学去喽！
# 3        流淌的登源河（29）：老造反成了普通看客
# 4                    沙溪“淩”姓来由
#
#                                                 body  \
# 0  \n\n\n\n\n马上注册成为会员，享用更多功能，让你轻松玩转徽州\n您需要 登录 才可以...
# 1  \n\n\n\n\n马上注册成为会员，享用更多功能，让你轻松玩转徽州\n您需要 登录 才可以...
# 2  \n\n\n\n\n马上注册成为会员，享用更多功能，让你轻松玩转徽州\n您需要 登录 才可以...
# 3  \n\n\n\n\n马上注册成为会员，享用更多功能，让你轻松玩转徽州\n您需要 登录 才可以...
# 4  \n\n\n\n\n马上注册成为会员，享用更多功能，让你轻松玩转徽州\n您需要 登录 才可以...
#
#                                             raw_page from
# 0  <html xmlns="http://www.w3.org/1999/xhtml"><he...
# 1  <html xmlns="http://www.w3.org/1999/xhtml"><he...
# 2  <html xmlns="http://www.w3.org/1999/xhtml"><he...
# 3  <html xmlns="http://www.w3.org/1999/xhtml"><he...
# 4  <html xmlns="http://www.w3.org/1999/xhtml"><he...

# %%
characters_num = 40
def get_brief(txt):
    soup = BeautifulSoup(txt)
    sub_text = soup.findAll('div', {'class':'article_contents'})
    for item in sub_text:
        t20 = item.text

    idx = 2
    t30 = t20.split(u'\n')
    
    cnt = 0
    tt = ''
    idx = 0
    for k in range(0, len(t30)):
        if (len(t30[k]) > 40 and len(tt) < 40):
            idx = k
            tt = t30[k].strip()
    
    if len(tt) == 0:
        tt = t20.strip()
                
    #print idx

    t40 = tt[0:characters_num]
    t50 = t40.encode('utf-8') + '..'
    #print idx, t40
    return t50

# %%
df['brief'] = df.raw_page.map(lambda x: get_brief(x) )

# %%
def get_body(txt):
    soup = BeautifulSoup(txt)
    sub_text = soup.findAll('div', {'class':'article_contents'})
    for item in sub_text:
        t20 = item.text

    return t20

# %%
df['body'] = df.raw_page.map(lambda x: get_body(x) )

# %% [markdown]
# cnt = 0
# for item in df['brief']:
#     print cnt, item
#     cnt += 1

# %% [markdown]
# cnt = 0
# for item in df['body']:
#     print cnt, item
#     cnt += 1

# %% [markdown]
# soup = BeautifulSoup(df.loc[527]['raw_page'])
# sub_text = soup.findAll('div', {'class':'article_contents'})
# for item in sub_text:
#     t20 = item.text
# t30 = t20.split(u'\n')
#
# tt = t20.strip()
# print len(t30), tt[0:40], t20

# %%
df.head()
# Out:
#            dt source domain                               url  \
# 0  2016-04-08  徽州文化网    NaN  www.hzwh.com/article.asp?id=2538
# 1  2016-04-08  徽州文化网    NaN  www.hzwh.com/article.asp?id=2537
# 2  2016-04-08  徽州文化网    NaN  www.hzwh.com/article.asp?id=2536
# 3  2016-04-08  徽州文化网    NaN  www.hzwh.com/article.asp?id=2535
# 4  2016-04-08  徽州文化网    NaN  www.hzwh.com/article.asp?id=2534
#
#                   title summary image  \
# 0  传统徽州仁商义贾践行商君子之道的历史启示     NaN   NaN
# 1       《阅读徽州》第七编“徽州科技”     NaN   NaN
# 2        传统徽商的诚信为本和仁义向善     NaN   NaN
# 3        传统徽商的诚信为本和仁义向善     NaN   NaN
# 4    黟县古城改造重要的是务须保住文教根脉     NaN   NaN
#
#                                         brief  \
# 0  全国人大代表、民盟安徽省委副主委、安徽省文联副主席钱念孙先生在《光明日报》201..
# 1  长期以来，得益于灵山秀水自然环境的滋养、兴学重教社会风气的熏染、经世致用治学风格..
# 2  徽州古楹联云“仁中取利真君子/义内求财大丈夫”。这是对传统徽商群体中那些仁商义贾..
# 3  徽州古楹联云“仁中取利真君子/义内求财大丈夫”。这是对传统徽商群体中那些仁商义贾..
# 4  黟县进行古城改造并申报国家级历史文化名城总体方案正在逐步完善，各项工作正在有条不..
#
#                                                 body  \
# 0  传统徽州仁商义贾践行商君子之道的历史启示\n郗延红\n全国人大代表、民盟安徽省委副主委、安徽...
# 1  《阅读徽州》第七编“徽州科技”（市委市政府通过市社科联组织编写）\n中国科学技术学大出版社出...
# 2  传统徽商的诚信为本和仁义向善\n\n郗延红\n徽州古楹联云“仁中取利真君子/义内求财大丈夫”...
# 3  传统徽商的诚信为本和仁义向善\n \n郗延红\n徽州古楹联云“仁中取利真君子/义内求财大丈夫...
# 4  黟县古城改造重要的是务须保住文教根脉\n                         郗...
#
#                                             raw_page from
# 0  <html xmlns="http://www.w3.org/1999/xhtml"><he...  NaN
# 1  <html xmlns="http://www.w3.org/1999/xhtml"><he...  NaN
# 2  <html xmlns="http://www.w3.org/1999/xhtml"><he...  NaN
# 3  <html xmlns="http://www.w3.org/1999/xhtml"><he...  NaN
# 4  <html xmlns="http://www.w3.org/1999/xhtml"><he...  NaN

# %%
df.loc[24]['url']
# Out:
# 'www.hzwh.com/article.asp?id=1347'

# %%
if(len(df) != 0):
    df.to_csv('../data/complete/hzwh_huixueyuanpu.csv', encoding='utf-8', index=False)

# %%
if(browser):
    browser.quit()

# %%
for item in df['title']:
    print item

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 11 columns):
# dt          0 non-null object
# source      0 non-null object
# domain      0 non-null object
# url         0 non-null object
# title       0 non-null object
# summary     0 non-null object
# image       0 non-null object
# brief       0 non-null object
# body        0 non-null object
# raw_page    0 non-null object
# from        0 non-null object
# dtypes: object(11)
# memory usage: 0.0+ bytes

# %%
df2 = pd.read_csv('../data/complete/hzwh_huixueyuanpu.csv')

# %%
df2.head()
# Out:
#            dt source  domain                                      url  \
# 0  2016-04-08  徽州文化网     NaN  http://www.hzwh.com/article.asp?id=2538
# 1  2016-04-08  徽州文化网     NaN  http://www.hzwh.com/article.asp?id=2537
# 2  2016-04-08  徽州文化网     NaN  http://www.hzwh.com/article.asp?id=2536
# 3  2016-04-08  徽州文化网     NaN  http://www.hzwh.com/article.asp?id=2535
# 4  2016-04-08  徽州文化网     NaN  http://www.hzwh.com/article.asp?id=2534
#
#                   title  summary  image  \
# 0  传统徽州仁商义贾践行商君子之道的历史启示      NaN    NaN
# 1       《阅读徽州》第七编“徽州科技”      NaN    NaN
# 2        传统徽商的诚信为本和仁义向善      NaN    NaN
# 3        传统徽商的诚信为本和仁义向善      NaN    NaN
# 4    黟县古城改造重要的是务须保住文教根脉      NaN    NaN
#
#                                         brief  \
# 0  全国人大代表、民盟安徽省委副主委、安徽省文联副主席钱念孙先生在《光明日报》201..
# 1  长期以来，得益于灵山秀水自然环境的滋养、兴学重教社会风气的熏染、经世致用治学风格..
# 2  徽州古楹联云“仁中取利真君子/义内求财大丈夫”。这是对传统徽商群体中那些仁商义贾..
# 3  徽州古楹联云“仁中取利真君子/义内求财大丈夫”。这是对传统徽商群体中那些仁商义贾..
# 4  黟县进行古城改造并申报国家级历史文化名城总体方案正在逐步完善，各项工作正在有条不..
#
#                                                 body  \
# 0  传统徽州仁商义贾践行商君子之道的历史启示\n郗延红\n全国人大代表、民盟安徽省委副主委、安徽...
# 1  《阅读徽州》第七编“徽州科技”（市委市政府通过市社科联组织编写）\n中国科学技术学大出版社出...
# 2  传统徽商的诚信为本和仁义向善\n\n郗延红\n徽州古楹联云“仁中取利真君子/义内求财大丈夫”...
# 3  传统徽商的诚信为本和仁义向善\n \n郗延红\n徽州古楹联云“仁中取利真君子/义内求财大丈夫...
# 4  黟县古城改造重要的是务须保住文教根脉\n                         郗...
#
#                                             raw_page  from
# 0  <html xmlns="http://www.w3.org/1999/xhtml"><he...   NaN
# 1  <html xmlns="http://www.w3.org/1999/xhtml"><he...   NaN
# 2  <html xmlns="http://www.w3.org/1999/xhtml"><he...   NaN
# 3  <html xmlns="http://www.w3.org/1999/xhtml"><he...   NaN
# 4  <html xmlns="http://www.w3.org/1999/xhtml"><he...   NaN
