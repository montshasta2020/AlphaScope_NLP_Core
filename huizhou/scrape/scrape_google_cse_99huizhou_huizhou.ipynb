# %%
import pandas as pd
from selenium import webdriver 
from bs4 import BeautifulSoup
import time
import re

# %%
from datetime import date, timedelta, datetime
import os.path

# %%
t0 =  date.today()

# %%
news_url='https://cse.google.com:443/cse/publicurl?cx=014023457988588298976:pf9o-6eh0dy'
datetime_str = t0
fname1 = './data/google/cse/' + '99huizhou-huizhou' + '.csv'

# %%
def get_columns():
    return ('dt', 'source', 'domain', 'url', 'title', 'summary', 'image', 'brief', 'body', 'raw_page', 'from') 
def get_empty_columns():
    return ('', '', '', '', '', '', '', '', '', '', '') 
def get_empty_columns1():
    return ('', '', '', '', '', '', '', '', '', '', '','')

# %%
browser = webdriver.Firefox() 
#browser = webdriver.Chrome('/Users/nhu2000/Downloads/Chromedriver')

# %%
if os.path.isfile(fname1): 
    df = pd.read_csv(fname1)
    idx = len(df.index)
else:
    df = pd.DataFrame(columns = get_columns())
    idx = 0

# %%
for item in df['url']:
    print item

# %% [markdown]
# if os.path.isfile(fname2):
#     df_0 = pd.read_csv(fname2)
# else:
#     df_0 = pd.DataFrame(columns = get_columns())

# %%
print len(df)
# Out:
# 97

# %%
browser.get(news_url)
time.sleep(5)

# %%
soup = BeautifulSoup(browser.page_source)
sub_text = soup.findAll('div', {'class':'gsc-webResult gsc-result'})
for item in sub_text:
    t10 = item.find('div', {'class':'gs-title'})
    #t1 = t10.text.split('_')[0]
    t1 = t10.text
    t2 = item.find('div', {'class':'gsc-url-top'})
    #t3 = item.find('table', {'class':'gsc-table-result'})
    t3 = item.find('div', {'class':'gs-bidi-start-align gs-snippet'})
    t4 = t3.text.split('...')
    
    #print t3.text
    ss = re.findall(ur'(\d+)年(\d+)月(\d+)日',t4[0])
    if len(ss) == 0:
        #print t4[1].encode('utf-8')
        t40 = t3.text.split(' ')
        if 'ago' in t4[0]:
            date_N_days_ago = datetime.now() - timedelta(days=int(t40[0]))
            t5 = date_N_days_ago.date()
            #t6 = t4[1]
        elif(len(t40) == 1):
            t5 = ''
            #t6 = t4[0]
        else:
            t5 = ''
            #t6 = t40[0]
        #print t5, t6
    else:
        ss = re.findall(ur'(\d+)年(\d+)月(\d+)日',t4[0])
        t5 = str(ss[0][0]) + '-' + str(ss[0][1]) + '-' + str(ss[0][2])
        #t6 = t4[1]

    #print t6    
    #print item.text
    #print t2.text

    url = t10.a['href']
    not_existed = True
    #check if in cleaned set
    if len(df) != 0:
        val_0 = abs(sum(df['url'].str.find(url))) 
        if val_0 != len(df):
            not_existed = False

    #print t0, len(df), t1

    if not_existed == True:   
        print "-------- add"
        print url
        df.loc[idx] = get_empty_columns()        
        df.loc[idx]['url'] = url
        df.loc[idx]['title'] = t1
        df.loc[idx]['brief'] = t3.text
        #df.loc[idx]['dt'] = t5
        df.loc[idx]['source'] = '故园徽州'

        idx += 1
# Out:
# -------- add
# http://www.99huizhou.com/archiver/fid-178.html
# -------- add
# http://www.99huizhou.com/thread-149701-1-1.html
# -------- add
# http://www.99huizhou.com/forum-101-1.html
# -------- add
# http://www.99huizhou.com/thread-189730-1-1.html
# -------- add
# 35  本帖最后由歙县山里人于2016-9-22 08:48 编辑 美好乡村建设和徽州传统村落保护\...
# 36  在这里，从《徽州府志》和《徽州赋役官解全书》等税文化展品中，您可以了解到徽州税\n文化的悠久...
# 37  故园徽州往期活动回顾. ... 第十一届中国黄山国际旅游节暨徽文化节: 主题: 25, 帖数...
# 38  徽学的影响力 方利山【摘要】徽学很有影响力，一是因为徽州文化源远流长，博大精深\n；二是因为...
# 39  故园徽州文化促进会理事会贺联. ... [慈善宣传位]当代徽州名点汪一挑馄饨 · 回复 \n...
# 40  故园徽州，心灵家园，一路随行，相伴有您。 2017“点亮徽州，西街文化之夜”故园徽州\n新春...
# 41  2011年1月30日 ... 摘要: 黄山市是徽州文化积淀厚实的主体地域，为了抢救性保护徽州...
# 42  2010年3月12日，国家社科基金项目、国家教育部人文社科研重点基地重大项目徽州\n文化生态...
# 43  改名”是依法纠偏 三十年前，历史悠久的独特地理历史文化单元的“徽州”，被用一座\n山名取代，...
# 44  春节要到了，各地都搞送文化下乡，大家都搞，你也搞就没有什么新鲜，媒体都懒得理\n你。如果换个...
# 45  收藏本版(3) 徽州美食 今日: 0↑|主题: 3891|排名: 81↓ |版主: 吃在徽州...
# 46   系统收集、整理、鉴赏、研究徽人创造或自然存在的、带有物质文化和精神文化价值的\n物品,故园徽州.
# 47  南北朝梁大同元年(535) 划歙县之华阳镇置良安县，属新安郡。治所在今大屏山下后\n外村。 ...
# 48  隐藏置顶帖 预览 2017“点亮徽州，西街文化之夜”故园徽州新春盛典报名帖 \nattach...
# 49  其他古村落、徽州古村落、徽州古城、黄山村落. ... 隐藏置顶帖 预览 2017“点亮徽州，...

# %%
print len(df)
# Out:
# 93

# %%
if(len(df) != 0):
    df.to_csv(fname1, encoding='utf-8', index=False)

# %%
if(browser):
    browser.quit()

# %%
df.head()
# Out:
#   dt source domain                                                url  \
# 0      故园徽州         www.99huizhou.com/forum.php?mod=forumdisplay&f...
# 1      故园徽州                        www.99huizhou.com/forum-148-1.html
# 2      故园徽州                        www.99huizhou.com/forum-119-1.html
# 3      故园徽州                        www.99huizhou.com/forum-147-1.html
# 4      故园徽州                         www.99huizhou.com/forum.php?gid=1
#
#                                       title summary image  \
# 0      人文徽州_徽州文化区_故园徽州_徽州网-故园徽州网-黄山门户社区 ...
# 1  第十一届中国黄山国际旅游节暨徽文化节-故园徽州网- Powered by ...
# 2          第十届中国黄山国际旅游节暨徽文化节_故园徽州-故园徽州网 ...
# 3                               徽州文化生态保护区专版
# 4             徽州文化-故园徽州- Powered by Discuz!
#
#                                                brief body raw_page from
# 0                    徽州，不仅有冠绝人寰的山水；徽州，更有着独特而深厚的文化底蕴.
# 1  第十一届中国黄山国际旅游节暨徽文化节. ... 隐藏置顶帖 预览 2017“点亮徽州，西街\...
# 2  第十届中国黄山国际旅游节暨徽文化节，定于11月4日至11月10日在黄山市隆重\n举行...&...
# 3  徽州文化是中华文化重要的组成部分。徽州文化的保护，最为重要、最为紧迫、最值得\n关注的，是对...
# 4  徽州文化网、徽州文化频道. ... 徽州文化是中华文化重要的组成部分。徽州文化的\n保护，最...

# %% [markdown]
# new_df = pd.DataFrame(columns = get_columns())
# for i in range(0, len(df)):
#     new_df.loc[i] = get_empty_columns()
#     item = df.loc[i]['url']
#     new_df.loc[i]['url'] = str('http://') + item[17:]
#     new_df.loc[i]['title'] = df.loc[i]['title']
#     new_df.loc[i]['brief'] = df.loc[i]['brief']
#     new_df.loc[i]['source'] = '徽州文化网'

# %% [markdown]
# new_df.head()

# %% [markdown]
# if(len(df) != 0):
#     new_df.to_csv(fname1, encoding='utf-8', index=False)

# %%
new_df = pd.DataFrame(columns = get_columns())

# %%
for i in range(0, len(df)):
    url_0 = df.loc[i]['url']
    print i, url_0
    browser.get(url_0)
    time.sleep(10)
    new_df.loc[i] = get_empty_columns()
    new_df.loc[i]['url'] = df.loc[i]['url']
    new_df.loc[i]['brief'] = df.loc[i]['brief']
    new_df.loc[i]['title'] = df.loc[i]['title']
    new_df.loc[i]['dt'] = df.loc[i]['dt']
    new_df.loc[i]['source'] = df.loc[i]['source']
    new_df.loc[i]['raw_page'] = browser.page_source
# Out:
# 0 http://www.99huizhou.com/forum.php?mod=forumdisplay&fid=78
# 1 http://www.99huizhou.com/forum-148-1.html
# 2 http://www.99huizhou.com/forum-119-1.html
# 3 http://www.99huizhou.com/forum-147-1.html
# 4 http://www.99huizhou.com/forum.php?gid=1
# 5 http://www.99huizhou.com/forum.php?mod=forumdisplay&fid=78&filter=typeid&typeid=13
# 6 http://www.99huizhou.com/thread-194203-1-1.html
# 7 http://www.99huizhou.com/archiver/fid-147.html
# 8 http://www.99huizhou.com/thread-187251-1-1.html
# 9 http://www.99huizhou.com/forum.php?mod=forumdisplay&fid=78&filter=typeid&typeid=162
# 10 http://www.99huizhou.com/forum-112-1.html
# 11 http://www.99huizhou.com/forum.php?mod=forumdisplay&fid=147&orderby=&filter=dateline&dateline=86400
# 12 http://www.99huizhou.com/forum.php?mod=forumdisplay&fid=78&filter=typeid&typeid=161
# 13 http://www.99huizhou.com/forum-144-1.html
# 14 http://www.99huizhou.com/thread-48039-1-1.html
# 15 http://www.99huizhou.com/forum-128-1.html
# 16 http://www.99huizhou.com/article-337-1.html
# 17 http://www.99huizhou.com/thread-16488-1-1.html
# 18 http://www.99huizhou.com/thread-175659-1-1.html
# 19 http://www.99huizhou.com/thread-187741-1-1.html
# 20 http://www.99huizhou.com/thread-177898-1-1.html
# 21 http://www.99huizhou.com/forum-214-1.html
# 22 http://www.99huizhou.com/archiver/tid-22147.html
# 23 http://www.99huizhou.com/group.php?sgid=235
# 24 http://www.99huizhou.com/thread-148631-1-1.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-0d230bbedfe5> in <module>()
#       3     print i, url_0
#       4     browser.get(url_0)
# ----> 5     time.sleep(10)
#       6     new_df.loc[i] = get_empty_columns()
#       7     new_df.loc[i]['url'] = df.loc[i]['url']
#
# KeyboardInterrupt:

# %%
http://www.99huizhou.com/archiver/  archiver
