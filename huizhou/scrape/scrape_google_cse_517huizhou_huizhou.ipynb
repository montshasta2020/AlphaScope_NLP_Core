# %%
#More check with content

# %%
import pandas as pd
from selenium import webdriver 
from bs4 import BeautifulSoup
import time
import re

# %%
from datetime import date, timedelta, datetime
import os.path

# %%
t0 =  date.today()

# %%
news_url='https://cse.google.com/cse/publicurl?cx=014023457988588298976:4vlzrq1vquy'
datetime_str = t0
fname1 = './data/google/cse/' + '517huizhou-huizhou' + '.csv'

# %%
def get_columns():
    return ('dt', 'source', 'domain', 'url', 'title', 'summary', 'image', 'brief', 'body', 'raw_page', 'from') 
def get_empty_columns():
    return ('', '', '', '', '', '', '', '', '', '', '') 
def get_empty_columns1():
    return ('', '', '', '', '', '', '', '', '', '', '','')

# %%
browser = webdriver.Firefox() 
#browser = webdriver.Chrome('/Users/nhu2000/Downloads/Chromedriver')

# %%
if os.path.isfile(fname1): 
    df = pd.read_csv(fname1)
    idx = len(df.index)
else:
    df = pd.DataFrame(columns = get_columns())
    idx = 0

# %% [markdown]
# df = pd.DataFrame(columns = get_columns())
# idx = 0

# %% [markdown]
# for item in df['url']:
#     print item

# %% [markdown]
# df['url'] = df.url.map(lambda x: 'http://' + x[18:])

# %%
print len('www.517huizhou.com')
# Out:
# 18

# %% [markdown]
# if os.path.isfile(fname2):
#     df_0 = pd.read_csv(fname2)
# else:
#     df_0 = pd.DataFrame(columns = get_columns())

# %%
print len(df)
# Out:
# 96

# %%
browser.get(news_url)
time.sleep(5)

# %%
soup = BeautifulSoup(browser.page_source)
sub_text = soup.findAll('div', {'class':'gsc-webResult gsc-result'})
for item in sub_text:
    t10 = item.find('div', {'class':'gs-title'})
    #t1 = t10.text.split('_')[0]
    t1 = t10.text
    t2 = item.find('div', {'class':'gsc-url-top'})
    #t3 = item.find('table', {'class':'gsc-table-result'})
    t3 = item.find('div', {'class':'gs-bidi-start-align gs-snippet'})
    t4 = t3.text.split('...')
    
    #print t3.text
    ss = re.findall(ur'(\d+)年(\d+)月(\d+)日',t4[0])
    if len(ss) == 0:
        #print t4[1].encode('utf-8')
        t40 = t3.text.split(' ')
        if 'ago' in t4[0]:
            date_N_days_ago = datetime.now() - timedelta(days=int(t40[0]))
            t5 = date_N_days_ago.date()
            t6 = t4[1]
        elif(len(t40) == 1):
            t5 = ''
            t6 = t4[0]
        else:
            t5 = ''
            t6 = t40[0]
        print t5, t6
    else:
        ss = re.findall(ur'(\d+)年(\d+)月(\d+)日',t4[0])
        t5 = str(ss[0][0]) + '-' + str(ss[0][1]) + '-' + str(ss[0][2])
        t6 = t4[1]

    #print t6    
    #print item.text
    #print t2.text

    url = t10.a['href']
    not_existed = True
    #check if in cleaned set
    if len(df) != 0:
        val_0 = abs(sum(df['url'].str.find(url))) 
        if val_0 != len(df):
            not_existed = False

    #print t0, len(df), t1

    if not_existed == True:   
        print "-------- add"
        print url
        df.loc[idx] = get_empty_columns()        
        df.loc[idx]['url'] = url
        df.loc[idx]['title'] = t1
        df.loc[idx]['brief'] = t3.text
        df.loc[idx]['dt'] = t5
        df.loc[idx]['source'] = '徽州文化'

        idx += 1
# Out:
#  徽州民生
#  徽州民生
#  徽州民生
#  琴棋书画,徽州大论坛.
# -------- add
# http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=47&page=4
#  逍遥户外,徽州大论坛.
#  徽州民生
#  徽州民生
#  徽州民生
#  徽州民生
#  徽州民生

# %%
print len(df)
# Out:
# 119

# %%
df.head(50)
# Out:
#            dt source domain  \
# 0         NaN   徽州文化    NaN
# 1   2014-11-8   徽州文化    NaN
# 2   2017-1-22   徽州文化    NaN
# 3         NaN   徽州文化    NaN
# 4         NaN   徽州文化    NaN
# 5         NaN   徽州文化    NaN
# 6         NaN   徽州文化    NaN
# 7         NaN   徽州文化    NaN
# 8         NaN   徽州文化    NaN
# 9         NaN   徽州文化    NaN
# 10        NaN   徽州文化    NaN
# 11        NaN   徽州文化    NaN
# 12        NaN   徽州文化    NaN
# 13        NaN   徽州文化    NaN
# 14        NaN   徽州文化    NaN
# 15        NaN   徽州文化    NaN
# 16        NaN   徽州文化    NaN
# 17        NaN   徽州文化    NaN
# 18        NaN   徽州文化    NaN
# 19        NaN   徽州文化    NaN
# 20        NaN   徽州文化    NaN
# 21        NaN   徽州文化    NaN
# 22        NaN   徽州文化    NaN
# 23        NaN   徽州文化    NaN
# 24        NaN   徽州文化    NaN
# 25        NaN   徽州文化    NaN
# 26        NaN   徽州文化    NaN
# 27        NaN   徽州文化    NaN
# 28        NaN   徽州文化    NaN
# 29        NaN   徽州文化    NaN
# 30        NaN   徽州文化    NaN
# 31        NaN   徽州文化    NaN
# 32        NaN   徽州文化    NaN
# 33        NaN   徽州文化    NaN
# 34        NaN   徽州文化    NaN
# 35        NaN   徽州文化    NaN
# 36        NaN   徽州文化    NaN
# 37        NaN   徽州文化    NaN
# 38        NaN   徽州文化    NaN
# 39        NaN   徽州文化    NaN
# 40        NaN   徽州文化    NaN
# 41        NaN   徽州文化    NaN
# 42        NaN   徽州文化    NaN
# 43        NaN   徽州文化    NaN
# 44        NaN   徽州文化    NaN
# 45        NaN   徽州文化    NaN
# 46        NaN   徽州文化    NaN
# 47        NaN   徽州文化    NaN
# 48        NaN   徽州文化    NaN
# 49        NaN   徽州文化    NaN
#
#                                                   url  \
# 0          http://www.517huizhou.com/forum.php?gid=43
# 1   http://www.517huizhou.com/hnews/bencandy-htm-f...
# 2   http://www.517huizhou.com/forum.php?mod=viewth...
# 3   http://www.517huizhou.com/forum.php?mod=forumd...
# 4   http://www.517huizhou.com/forum.php?mod=forumd...
# 5   http://www.517huizhou.com/forum.php?mod=forumd...
# 6   http://www.517huizhou.com/forum.php?mod=forumd...
# 7   http://www.517huizhou.com/forum.php?mod=forumd...
# 8   http://www.517huizhou.com/forum.php?mod=forumd...
# 9   http://www.517huizhou.com/forum.php?mod=forumd...
# 10  http://www.517huizhou.com/forum.php?mod=forumd...
# 11  http://www.517huizhou.com/forum.php?mod=forumd...
# 12  http://www.517huizhou.com/forum.php?mod=forumd...
# 13  http://www.517huizhou.com/forum.php?mod=forumd...
# 14  http://www.517huizhou.com/forum.php?mod=forumd...
徽州民生 · 逍遥户外 · 活动召集 · 新安茶馆 · 徽州文化 · 旅游频道. 兴趣. 音...  NaN      NaN  NaN
# 47  逍遥户外,徽州大论坛. ... 预览 12月27日画里山村祖源村首届民俗文化节花絮 \nat...  NaN      NaN  NaN
# 48  徽州民生 · 逍遥户外 · 活动召集 · 新安茶馆 · 徽州文化 · 旅游频道. 兴趣. 音...  NaN      NaN  NaN
# 49  徽州民生 · 逍遥户外 · 活动召集 · 新安茶馆 · 徽州文化 · 旅游频道. 兴趣. 音...  NaN      NaN  NaN

# %%
print len(df)
# Out:
# 119

# %%
if(len(df) != 0):
    df.to_csv(fname1, encoding='utf-8', index=False)

# %%
if(browser):
    browser.quit()

# %%
for item in df['title']:
    print df[]
# Out:
# 徽文化频道-中安在线
# 部省文化合作项目落户黄山中安在线-徽文化频道
# 徽文化“动起来”:推动徽文化走向世界中安在线-徽文化频道
# 30余位中外书画家安徽体验“徽文化” 中安在线-徽文化频道
# “徽州文化”行走课堂走进徽博中安在线-徽文化频道
# 2017合肥新春官方文化活动安排出炉中安在线-徽文化频道
# 洪建华夫妇的竹刻人生中安在线-徽文化频道
# 传统剧种艺术档案数字化初步建成中安在线-徽文化频道
# 我省对地方戏曲实行分类保护中安在线-徽文化频道
# 深圳市徽文化研究会成立(组图) 徽文化频道中安在线
# 海归人士子女体验“徽文化”（组图） 中安在线-徽文化频道
# ·民间艺人·农家人的“花样”世界中安在线-徽文化频道
# 中安在线－徽文化
# 转型升级路实体书店怎么走？ 中安在线-徽文化频道
# 徽学、徽文化不应受地域影响徽文化频道中安在线
# 贾道儒行竹雕人中安在线-徽文化频道
# 徽墨：传播徽文化的最早使者徽文化频道中安在线
# 文化部专题调研安徽戏曲传承中安在线-徽文化频道
# 黄山创新推动徽文化保护传承徽文化频道中安在线
# 《徽州文化大辞典》首发式举行（图） 中安在线-徽文化频道
# 以徽州文化生态赖以存生发展的徽派建筑（图）-徽文化-中安在线
# 安徽饮食文化，你了解吗？ 中安在线-徽文化频道
# 安徽国家重点文物保护专项资金分配(表) 中安在线-徽文化频道
# 26个国家青年汉学家来安徽考察徽州文化(图) 中安在线-徽文化频道
# 吴成林让徽墨飘香四海中安在线-徽文化频道
# 合肥：“非遗”作品迎新年中安在线-徽文化频道
# 传统剪纸“团团圆圆过大年” 中安在线-徽文化频道
# 探秘“超级宣纸”制作工艺中安在线-徽文化频道
# 歙县徽班纪念馆展示、传承徽文化（图） 中安在线-徽文化频道
# 安徽将打造黄梅戏影视文化特区中安在线-徽文化频道
# 徽文化生态保护区获批婺源、绩溪纳入-徽文化,婺源,绩溪-中安在线-徽 ...
# 徽州文化中的烟文化徽文化频道中安在线
# 安徽文化地理：徽州的居所中安在线-徽文化频道
# 徽文化出版精品展销月今启动-徽文化-中安在线-徽文化
# 池州举办非物质文化遗产展演中安在线-徽文化频道
# 近40位海外文化侨社负责人赴皖体验“徽文化” 中安在线-徽文化频道
# 40集电视连续剧《六尺巷》启动中安在线-徽文化频道
# 传统徽文化折服华裔少年传统文化海外流行中安在线-徽文化频道
# 黄山市打造靓丽“文化名片” 中安在线-徽文化频道
# 安徽新春文化活动丰富多彩滋润幸福年（图） 徽文化频道中安在线
# “徽州三雕”出新品徽文化放光彩-徽州三雕-中安在线-徽文化
# 探寻祁红技艺之美中安在线-徽文化频道
# 徽文化的思想使者——赵焰-赵焰-中安在线-徽文化
# “问道黄山——方绍武书画展览”在合肥开幕徽文化频道中安在线
# 安徽《黄梅音乐演唱会》登京城中安在线-徽文化频道
# 安徽民歌分六种五类（图） 中安在线-徽文化频道
# 合肥：德国中学生体验中国文化中安在线-徽文化频道
# 徽学百家——朱升-朱升-中安在线-徽文化
# 我国传统村落文化保护须用好“互联网+” 徽文化频道中安在线
# 徽学百家——俞正燮-俞正燮-中安在线-徽文化

# %%
temp = df.loc[1]['url']
print str('http://') + temp[18:]
# Out:
# http://www.517huizhou.com/hnews/bencandy-htm-fid-55-id-1360.html

# %%
new_df = pd.DataFrame(columns = get_columns())
for i in range(0, len(df)):
    new_df.loc[i] = get_empty_columns()     
    item = df.loc[i]['url']
    new_df.loc[i]['url'] = str('http://') + temp[18:]
    new_df.loc[i]['title'] = df.loc[i]['title']
    new_df.loc[i]['brief'] = df.loc[i]['brief']
    new_df.loc[i]['source'] = '徽州大论坛'

# %% [markdown]
# new_df.head()

# %%
if(len(df) != 0):
    df.to_csv(fname1, encoding='utf-8', index=False)

# %% [markdown]
# print fname1

# %%
new_df = pd.DataFrame(columns = get_columns())

# %%
for i in range(0, len(df)):
    url_0 = df.loc[i]['url']
    print i, url_0
    browser.get(url_0)
    time.sleep(10)
    new_df.loc[i] = get_empty_columns()
    new_df.loc[i]['url'] = df.loc[i]['url']
    new_df.loc[i]['brief'] = df.loc[i]['brief']
    new_df.loc[i]['title'] = df.loc[i]['title']
    new_df.loc[i]['dt'] = df.loc[i]['dt']
    new_df.loc[i]['source'] = df.loc[i]['source']
    new_df.loc[i]['raw_page'] = browser.page_source
# Out:
# 0 http://www.517huizhou.com/forum.php?gid=43
# 1 http://www.517huizhou.com/hnews/bencandy-htm-fid-55-id-971.html
# 2 http://www.517huizhou.com/forum.php?mod=viewthread&tid=94954
# 3 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=95
# 4 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=94
# 5 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=54
# 6 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=40&page=31
# 7 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=136
# 8 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=44
# 9 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=37
# 10 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=40&page=6
# 11 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=55
# 12 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=82
# 13 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=132
# 14 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=36
# 15 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=65
# 16 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=102&page=2
# 17 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=59
# 18 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=139
# 19 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=119
# 20 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=41&page=5
# 21 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=89&page=3
# 22 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=40&page=7
# 23 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=40&page=8
# 24 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=68
# 25 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=41&page=9
# 26 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=40&page=5
# 27 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=40&page=10
# 28 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=83
# 29 http://www.517huizhou.com/forum.php?mod=forumdisplay&fid=68&page=9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-0d230bbedfe5> in <module>()
#       3     print i, url_0
#       4     browser.get(url_0)
# ----> 5     time.sleep(10)
#       6     new_df.loc[i] = get_empty_columns()
#       7     new_df.loc[i]['url'] = df.loc[i]['url']
#
# KeyboardInterrupt:
