# %%
import pandas as pd
from selenium import webdriver 
from bs4 import BeautifulSoup
import time
import re

# %%
from datetime import date, timedelta, datetime
import os.path

# %%
t0 =  date.today()

# %%
news_url='https://cse.google.com/cse/publicurl?cx=014023457988588298976:og-09q9kgau'

datetime_str = t0
fname1 = './data/google/cse/' + 'anhuinews-huizhou' + '.csv'

# %%
def get_columns():
    return ('dt', 'source', 'domain', 'url', 'title', 'summary', 'image', 'brief', 'body', 'raw_page', 'from') 
def get_empty_columns():
    return ('', '', '', '', '', '', '', '', '', '', '') 
def get_empty_columns1():
    return ('', '', '', '', '', '', '', '', '', '', '','')

# %%
browser = webdriver.Firefox() 
#browser = webdriver.Chrome('/Users/nhu2000/Downloads/Chromedriver')

# %%
if os.path.isfile(fname1): 
    df = pd.read_csv(fname1)
    idx = len(df.index)
else:
    df = pd.DataFrame(columns = get_columns())
    idx = 0

# %%
for item in df['url']:
    print item

# %% [markdown]
# if os.path.isfile(fname2):
#     df_0 = pd.read_csv(fname2)
# else:
#     df_0 = pd.DataFrame(columns = get_columns())

# %%
print len(df)
# Out:
# 97

# %%
browser.get(news_url)
time.sleep(5)

# %%
soup = BeautifulSoup(browser.page_source)
sub_text = soup.findAll('div', {'class':'gsc-webResult gsc-result'})
for item in sub_text:
    t1 = item.find('div', {'class':'gs-title'})
    t2 = item.find('div', {'class':'gsc-url-top'})
    #t3 = item.find('table', {'class':'gsc-table-result'})
    t3 = item.find('div', {'class':'gs-bidi-start-align gs-snippet'})
    t4 = t3.text.split('...')
    
    #print t3.text
    ss = re.findall(ur'(\d+)年(\d+)月(\d+)日',t4[0])
    if len(ss) == 0:
        #print t4[1].encode('utf-8')
        t40 = t3.text.split(' ')
        if 'ago' in t4[0]:
            date_N_days_ago = datetime.now() - timedelta(days=int(t40[0]))
            t5 = date_N_days_ago.date()
            t6 = t4[1]
        elif(len(t40) == 1):
            t5 = ''
            t6 = t4[0]
        else:
            t5 = t40[1]
            t6 = t40[0]
        print t5, t6
    else:
        ss = re.findall(ur'(\d+)年(\d+)月(\d+)日',t4[0])
        t5 = str(ss[0][0]) + '-' + str(ss[0][1]) + '-' + str(ss[0][2])
        t6 = t4[1]

    #print t6    
    #print item.text
    #print t2.text

    url = t1.a['href']
    not_existed = True
    #check if in cleaned set
    if len(df) != 0:
        val_0 = abs(sum(df['url'].str.find(url))) 
        if val_0 != len(df):
            not_existed = False

    #print t0, len(df), t1

    if not_existed == True:   
        print "-------- add"
        print url
        df.loc[idx] = get_empty_columns()        
        df.loc[idx]['url'] = url
        df.loc[idx]['title'] = t1.text
        df.loc[idx]['brief'] = t6
        df.loc[idx]['dt'] = t5
        df.loc[idx]['source'] = '中安在线'

        idx += 1
# Out:
# -------- add
# http://cul.anhuinews.com/system/2016/01/26/007194821.shtml
# -------- add
# http://cul.anhuinews.com/system/2016/01/12/007173136.shtml
# -------- add
# http://cul.anhuinews.com/system/2016/01/28/007197783.shtml
# -------- add
# http://cul.anhuinews.com/system/2008/01/16/001933380.shtml
# 31   7月25日下午，黄山市委宣传部与市直有关部门负责人同黄山市部分自发参加2016\n年深圳文...
# 32   上海博物馆是我国著名的古代艺术博物馆之一，收藏有各类珍贵文物14万件。由于明\n清至民国时...
# 33   一、徽州文化内涵、特性和历程徽州文化是古徽州(一府六县)物质文明和精神文明的\n总和，是中...
# 34   今年暑假，浙江传媒学院电视艺术学院“走进徽派”暑期实践团队一行8人来到了黟县\n宏村开展以...
# 35   由凤阳县委宣传部与央视联合摄制的7集大型纪录片《花鼓纪》10月8日起在央视11套\n陆续播...
# 36   再芬剧院在韩再芬的带领下成功地创作了《徽州女人》、《徽州往事》等经典原创黄梅戏\n剧目，并...
# 37   安徽风味包括皖南、沿江、沿淮之地的菜点特色。皖南菜点是安徽风味的主要代表。它\n包括黄山、...
# 38   人民网讯12月19日，随着一声金锣声响，交易代码为901015的《九五至尊纪念宣纸》\n挂...
# 39   昨日，合肥非物质文化遗产“庐州蛋雕”传承人王剑正在创作鸡年题材蛋雕作品。为\n迎接农历鸡年...
# 40   近日，黄山呈坎迎来央视综艺节目的录制。 记者潘成摄. 近年来，一些影视剧和综艺\n节目纷纷...
# 41   据安庆新闻网消息，用黄梅音乐对接古典之雅，用音舞诗画演绎唐诗宋词，一幕幕\n诗意的情景再现...
# 42   “1月4日，我从文化部拿到正式批复，黄山市现属区域及绩溪县、江西婺源县一起，被\n批准设为...
# 43   皖文化”是安徽文化较为通用的简称，也有将安徽文化简称为“徽文化”的，视徽州文化\n为徽文化...
# 44   日前，安徽省文化厅在一份政协委员提案回复中表示，将把黄梅戏影视文化特区建设\n提到议事日程...
# 45   7月3日，“徽派版画(巡回)邀请展”首站“歙县展”在歙县徽派版画博物馆开幕。 据了解，\n...
# 46   中安在线讯11月8日，陈晓明书画作品展在合肥安徽画廊开展。本次展览由安徽省\n文化馆、全省...
# 47   《徽州文化全书》（之徽州戏曲）. 《鬼吹灯》（之精绝古城）. “一生痴绝处，无梦到徽州”，...
# 48   中安在线讯据铜陵新闻网报道，12月25日晚，2017铜陵新年音乐会在市行政会议\n中心礼堂...
# 49   5月7日晚，话剧《徽商传奇》在北京国家大剧院上演。记者夏胜为/摄. 这是一出关于徽\n商徽...

# %%
print len(df)
# Out:
# 97

# %%
if(len(df) != 0):
    df.to_csv(fname1, encoding='utf-8', index=False)

# %%
if(browser):
    browser.quit()

# %% [markdown]
# new_df = pd.DataFrame(columns = get_columns())
# for i in range(0, len(df)):
#     new_df.loc[i] = get_empty_columns()
#     item = df.loc[i]['url']
#     new_df.loc[i]['url'] = 'http://' + item[17:]
#     new_df.loc[i]['title'] = df.loc[i]['title']
#     new_df.loc[i]['brief'] = df.loc[i]['brief']
#     new_df.loc[i]['dt'] = df.loc[i]['dt']
#     new_df.loc[i]['source'] = '中安在线'
#     #print new_df.loc[i]['url']

# %% [markdown]
# new_df.head()

# %% [markdown]
# if(len(new_df) != 0):
#     new_df.to_csv(fname1, encoding='utf-8', index=False)
