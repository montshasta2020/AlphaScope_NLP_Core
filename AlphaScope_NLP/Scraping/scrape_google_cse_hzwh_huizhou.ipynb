# %%
import pandas as pd
from selenium import webdriver 
from bs4 import BeautifulSoup
import time
import re

# %%
from datetime import date, timedelta, datetime
import os.path

# %%
t0 =  date.today()

# %%
news_url='https://cse.google.com/cse/publicurl?cx=014023457988588298976:izpxduzw9rc'

datetime_str = t0
fname1 = './data/google/cse/' + 'hzwh-huizhou' + '.csv'

# %%
def get_columns():
    return ('dt', 'source', 'domain', 'url', 'title', 'summary', 'image', 'brief', 'body', 'raw_page', 'from') 
def get_empty_columns():
    return ('', '', '', '', '', '', '', '', '', '', '') 
def get_empty_columns1():
    return ('', '', '', '', '', '', '', '', '', '', '','')

# %%
browser = webdriver.Firefox() 
#browser = webdriver.Chrome('/Users/nhu2000/Downloads/Chromedriver')

# %%
if os.path.isfile(fname1): 
    df = pd.read_csv(fname1)
    idx = len(df.index)
else:
    df = pd.DataFrame(columns = get_columns())
    idx = 0

# %% [markdown]
# df = pd.DataFrame(columns = get_columns())
# idx = 0

# %% [markdown]
# for item in df['url']:
#     print item

# %% [markdown]
# if os.path.isfile(fname2):
#     df_0 = pd.read_csv(fname2)
# else:
#     df_0 = pd.DataFrame(columns = get_columns())

# %%
print len(df)
# Out:
# 98

# %%
browser.get(news_url)
time.sleep(5)

# %%
soup = BeautifulSoup(browser.page_source)
sub_text = soup.findAll('div', {'class':'gsc-webResult gsc-result'})
for item in sub_text:
    t10 = item.find('div', {'class':'gs-title'})
    t1 = t10.text.split('_')[0]
    t2 = item.find('div', {'class':'gsc-url-top'})
    #t3 = item.find('table', {'class':'gsc-table-result'})
    t3 = item.find('div', {'class':'gs-bidi-start-align gs-snippet'})
    t4 = t3.text.split('...')
    
    #print t3.text
    ss = re.findall(ur'(\d+)年(\d+)月(\d+)日',t4[0])
    if len(ss) == 0:
        #print t4[1].encode('utf-8')
        t40 = t3.text.split(' ')
        if 'ago' in t4[0]:
            date_N_days_ago = datetime.now() - timedelta(days=int(t40[0]))
            t5 = date_N_days_ago.date()
            #t6 = t4[1]
        elif(len(t40) == 1):
            t5 = ''
            #t6 = t4[0]
        else:
            t5 = '' #t40[1]
            #t6 = t40[0]
        print t5
    else:
        ss = re.findall(ur'(\d+)年(\d+)月(\d+)日',t4[0])
        t5 = str(ss[0][0]) + '-' + str(ss[0][1]) + '-' + str(ss[0][2])
        #t6 = t4[1]

    #print t6    
    #print item.text
    #print t2.text

    url = t10.a['href']
    not_existed = True
    #check if in cleaned set
    if len(df) != 0:
        val_0 = abs(sum(df['url'].str.find(url))) 
        if val_0 != len(df):
            not_existed = False

    #print t0, len(df), t1

    if not_existed == True:   
        print "-------- add"
        print url
        df.loc[idx] = get_empty_columns()        
        df.loc[idx]['url'] = url
        df.loc[idx]['title'] = t1
        df.loc[idx]['brief'] = t3.text
        df.loc[idx]['dt'] = t5
        df.loc[idx]['source'] = '徽州文化网'

        idx += 1
# Out:
# -------- add
# http://www.hzwh.com/toplistb.asp?id=240
#
# -------- add
# http://www.hzwh.com/toplistb.asp?id=243
#
#
# -------- add
# http://www.hzwh.com/article.asp?id=1417
#
#
# -------- add
# http://www.hzwh.com/toplistb.asp?id=269
#
#
# -------- add
# 29  徽文化与—定的地域和传统的生产生活习俗之间的联系是十分密切的。地域的特征(\n包括自然地貌特...
# 30  遍布徽州城乡的石刻，全面记载了徽州上自官府下至百姓生产与生活的方方面面，是\n徽州历史发展和...
# 31  您的位置: 首页>>知识库>>徽州工艺. 栏目导航. 徽派建筑. 徽派雕刻. 徽派篆刻. 徽...
# 32  古徽州科技以天文历法算术、医学、手工业技术为三大板块，并在这三大方面取得了\n一些国内最先进...
# 33  美籍华人学者唐德刚先生在整理《胡适口述自传》时以胡适之的口吻这样写道：“徽州\n在旧制时代是...
# 34  ... 年12月31日星期三. 您的位置: 首页>>文化窗>>文化景观 ... 古徽州文化旅...
# 35  从广度上说， 新安理学对徽州社会的影响无所不及， 渗透到政治、 经济、 文化等各个\n层面;...
# 36  徽州文化. ... 文化短波. 文化纵横. 文化典藏. 文化鉴赏. 文化景观. 文化旅游. ...
# 37  徽州文化. ... 您的位置: 首页>>知识库>>徽派版画. 栏目导航. 徽派建筑. 徽派雕...
# 38  徽州文化的现代意义徽州文化研究对于当代社会有着多方面的意义。 （一）明清时期\n的徽州，呈现...
# 39  徽州文化. ... 文化典藏. 文化鉴赏. 文化景观. 文化旅游. 文化事业. 文化产业. ...
# 40  徽州文化. ... 1969年12月31日星期三. 您的位置: 首页>>徽州册>>天下徽商 ...
# 41  徽州这片古老土地上的建筑，作为一种文化现象而被世人关注，当是基于它的风格\n特色以及形成这些...
# 42  ... 月31日星期三. 您的位置: 首页>>徽州册>>徽州宗族 ... 从徽州传统祭祀文化...
# 43  您的位置: 首页>>徽州册>>徽州鉴宝. 栏目导航. 图解徽州. 故园徽州. 秀美徽州. 徽...
# 44  徽州文化. ... 您的位置: 首页>>知识库>>徽派盆景. 栏目导航. 徽派建筑. 徽派雕...
# 45  2015年3月5日 ... 整体推进，文化生态保护成果斐然。强力推进徽州文化生态保护实验区建...
# 46  徽州文化. ... 您的位置: 首页>>知识库>>徽州文物. 栏目导航. 徽派建筑. 徽派雕...
# 47  徽州文化古镇——潜口 添加时间：2015年4月9日 发布人：hzwh 点击数：190. 徽州...
# 48  《徽州文化全书.徽州宗族社会》目录 添加时间：2014年7月10日 发布人：hzwh 点击数...
# 49  徽州文学是对渊远流长的中国文学来说，是一个创造性的丰富与补充，有着特定的\n地位和价值。 徽...

# %%
if(len(df) != 0):
    df.to_csv(fname1, encoding='utf-8', index=False)

# %%
if(browser):
    browser.quit()

# %%
new_df = pd.DataFrame(columns = get_columns())
for i in range(0, len(df)):
    new_df.loc[i] = get_empty_columns()     
    item = df.loc[i]['url']
    new_df.loc[i]['url'] = str('http://') + item[12:]
    new_df.loc[i]['title'] = df.loc[i]['title']
    new_df.loc[i]['brief'] = df.loc[i]['brief']
    new_df.loc[i]['source'] = '徽州文化网'

# %% [markdown]
# new_df.head()

# %% [markdown]
# if(len(df) != 0):
#     new_df.to_csv(fname1, encoding='utf-8', index=False)

# %% [markdown]
# print fname1
