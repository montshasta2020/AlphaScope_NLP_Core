# %%
import pandas as pd
from selenium import webdriver 
from bs4 import BeautifulSoup
import time
import re

# %%
from datetime import date, timedelta, datetime
import os.path

# %%
t0 =  date.today()

# %%
news_url='http://tieba.baidu.com/f?kw=%BB%D5%D6%DD&fr=ala0&tpl=5'

datetime_str = t0
fname1 = './data/general/' + 'baidu-huizhouba' + '.csv'

# %%
def get_columns():
    return ('dt', 'source', 'domain', 'url', 'title', 'summary', 'image', 'brief', 'body', 'raw_page', 'from') 
def get_empty_columns():
    return ('', '', '', '', '', '', '', '', '', '', '') 
def get_empty_columns1():
    return ('', '', '', '', '', '', '', '', '', '', '','')

# %%
browser = webdriver.Firefox() 
#browser = webdriver.Chrome('/Users/nhu2000/Downloads/Chromedriver')

# %%
if os.path.isfile(fname1): 
    df = pd.read_csv(fname1)
    idx = len(df.index)
else:
    df = pd.DataFrame(columns = get_columns())
    idx = 0

# %%
print len(df)
# Out:
# 2070

# %%
url = 'https://tieba.baidu.com/f?kw=%BB%D5%D6%DD&pn=2000'

# %%
browser.get(news_url)
time.sleep(5)

# %%
idx = 2576

# %%
for i in range(1000, 10000, 50):
    url = u'http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=' + str(i)
    print i, url
    browser.get(news_url)
    time.sleep(10)

    soup = BeautifulSoup(browser.page_source)
    sub_texts = soup.findAll('li', {'class':' j_thread_list clearfix'})

    for link in sub_texts:
        t1 = link.find('a', {'class': 'j_th_tit'})
        t3 = link.find('div', {'class': 'threadlist_abs threadlist_abs_onlyline '})
        t2 = 'http://tieba.baidu.com' + t1['href']
        #print t1.text
        #print t2   
        #print t3.text

        #tt0 = abs(sum(df['url'].str.find(str(t0.a['href']))))
        #if(tt0 == len(df) and 0):
        if 1:
            #print 'added ----'
            #print t1.text
            df.loc[idx] = get_empty_columns()

            #set title and url    
            df.loc[idx]['url'] = t2
            df.loc[idx]['title'] = t1.text

            df.loc[idx]['brief'] = t3.text
            df.loc[idx]['from'] = '百度贴吧'
            idx +=1
# Out:
# 1000 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1000
# 1050 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1050
# 1100 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1100
# 1150 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1150
# 1200 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1200
# 1250 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1250
# 1300 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1300
# 1350 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1350
# 1400 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1400
# 1450 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1450
# 1500 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1500
# 1550 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1550
# 1600 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1600
# 1650 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1650
# 1700 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1700
# 1750 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1750
# 1800 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1800
# 1850 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1850
# 1900 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1900
# 1950 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=1950
# 2000 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2000
# 2050 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2050
# 2100 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2100
# 2150 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2150
# 2200 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2200
# 2250 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2250
# 2300 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2300
# 2350 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2350
# 2400 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2400
# 2450 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2450
# 2500 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2500
# 2550 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2550
# 2600 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2600
# 2650 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2650
# 2700 http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=2700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-f31860d2c26e> in <module>()
#       3     print i, url
#       4     browser.get(news_url)
# ----> 5     time.sleep(10)
#       6
#       7     soup = BeautifulSoup(browser.page_source)
#
# KeyboardInterrupt:

# %%
url = u'http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn=' + str(i)
print i, url
browser.get(news_url)
time.sleep(10)

soup = BeautifulSoup(browser.page_source)
sub_texts = soup.findAll('li', {'class':' j_thread_list clearfix'})

for link in sub_texts:
    t1 = link.find('a', {'class': 'j_th_tit'})
    t3 = link.find('div', {'class': 'threadlist_abs threadlist_abs_onlyline '})
    t2 = 'http://tieba.baidu.com' + t1['href']
    #print t1.text
    #print t2   
    #print t3.text

    #tt0 = abs(sum(df['url'].str.find(str(t0.a['href']))))
    #if(tt0 == len(df) and 0):
    if 1:
        #print 'added ----'
        #print t1.text
        df.loc[idx] = get_empty_columns()

        #set title and url    
        df.loc[idx]['url'] = t2
        df.loc[idx]['title'] = t1.text

        df.loc[idx]['brief'] = t3.text
        df.loc[idx]['from'] = '百度贴吧'
        idx +=1

# %%
import string, urllib2

# %%
url = 'http://tieba.baidu.com/f?kw=%E5%BE%BD%E5%B7%9E&ie=utf-8&pn='
i = 3000

# %%
m = urllib2.urlopen(url + str(i)).read()

# %%
idx = 2576

# %%
for i in range(3000, 20000, 50):
    m = urllib2.urlopen(url + str(i)).read() 
    time.sleep(5)

    soup = BeautifulSoup(m)
    sub_texts = soup.findAll('li', {'class':' j_thread_list clearfix'})

    for link in sub_texts:
        t1 = link.find('a', {'class': 'j_th_tit'})
        t3 = link.find('div', {'class': 'threadlist_abs threadlist_abs_onlyline '})
        t2 = 'http://tieba.baidu.com' + t1['href']
        #print t1.text
        #print t2   
        #print t3.text

        #tt0 = abs(sum(df['url'].str.find(str(t0.a['href']))))
        #if(tt0 == len(df) and 0):
        if 1:
            print idx, 'added ----'
            print t1.text
            df.loc[idx] = get_empty_columns()

            #set title and url    
            df.loc[idx]['url'] = t2
            df.loc[idx]['title'] = t1.text

            df.loc[idx]['brief'] = t3.text
            df.loc[idx]['from'] = '百度贴吧'
            idx +=1
# Out:
# 2576 added ----
# 小巴诈尸了，消失好久了啊
# 2577 added ----
# 大祁门的何在！！
# 2578 added ----
# 祁门现夺命“二氧化碳湖” 5人进山离奇死亡
# 2579 added ----
# 无梦到徽州……我的一篇散文 请指教
# 2580 added ----
# 快递转让
# 2581 added ----
# 都别地域了、祁门5村民被不明气体毒倒身亡
# 2582 added ----
# 我妈让我把户口迁到屯溪来
# 2583 added ----
# 突然发现，我发帖子还不到2000贴
# 2584 added ----
# 朝奉们最近可好
# 2585 added ----
# 【吧主申请】在下想申请成为徽州吧的吧主
# 2586 added ----
# 举个例子、打个比方  剖析徽州经济发展障碍因素
# 2587 added ----
# 人生诚在坚持 贵能改变
# 2588 added ----
# 徽派建筑的影响力
# 2589 added ----
# 人多起来了，好多新朋友不认识。
# 2590 added ----
# 建议合福铁路歙县北站定名为徽州古城站
# 2591 added ----
# 大本，申请大吧！
# 2592 added ----
# 【开放大吧申请】
# 2593 added ----
# 抓紧申请啊，不申请我怎么滚啊。
# 2594 added ----
# 如愿怎么也走了，要嫁人了么？
# 2595 added ----
# 绩溪到景德镇的火车七月一号停运？？？
# 2596 added ----
# 【投票】票选你心目中的徽吧名片
# 2597 added ----
# 在杭州看到新闻报道，黄杭高铁终于开始动工了
# 2598 added ----
# 怎么群里的活跃的都成权限狗了？
# 2599 added ----
# 江西老婊子刘敏穷狗滚进来一下
# 2600 added ----
# 绩溪又上凤凰网首页了
# 2601 added ----
# 奶奶在徽州六县方言是什么，正字又是什么？
# 2602 added ----
# 又到一年6月30号
# 2603 added ----
# 黄山区和休宁，哪个经济好一点？
# 2604 added ----
# 绩溪话说我上你家老婆（玉）和想你家老婆（玉）发音是一样的
# 2605 added ----
# 这是不是抱徽州大腿？
# 2606 added ----
# 有没有出现账号密码不对的状况？
# 2607 added ----
# 在学校买了张回家的红色动车票
# 2608 added ----
# 黄山北站什么时候通车
# 2609 added ----
# 我只是想看到劲爆点的新闻
# 2610 added ----
# 徽州岩寺附近店铺出售
# 2611 added ----
# 在外地人家问你那里人、你咋说
# 2612 added ----
# 叹红逼圣景难现
# 2613 added ----
# 读下这个吧
# 2614 added ----
# 71调图，6091停运
# 2615 added ----
# 我在铜陵买车票，说去黄山！但是人家售票员问我是不是去屯溪
# 2616 added ----
# 徽州在哪里？？？？（科普）
# 2617 added ----
# 哼哼～
# 2618 added ----
# 请问徽州一府六县的最佳路线怎么走？
# 2619 added ----
# 德智教育大型安全教育动画片《美丽家园》，今日在黄山台首播
# 2620 added ----
# 马上要去徽州。
# 2621 added ----
# 对于徽州人的好消息 杭州房价大涨的趋势已经止住了
# 2622 added ----
# 灰化肥发黑会挥发
# 2623 added ----
# 婺源江湾话的全浊音
# 2624 added ----
# 徽州地域不同时期地图
# 2625 added ----
# 洛翔给个馍吧
# 2626 added ----
# @吗啦沙 这事情你以后可以接着做
# 2627 added ----
# 发了个吧名片投票贴，请爪鸡x切换至网页触屏版，有惊喜哟
# 2628 added ----
# 刘敏这个丑鸡又在发贴了
# 2629 added ----
# 我要上天台了
# 2630 added ----
# 早上起来随拍张。。。
# 2631 added ----
# 大家都用什么牌子的手机，进来说说
# 2632 added ----
# 哼哼 已在家
# 2633 added ----
# 徽州附近夜景图
# 2634 added ----
# 这是岩寺吧吗
# 2635 added ----
# 婺源县志（1987～2001）
# 2636 added ----
# 纪念旧年暑假那些日子
# 2637 added ----
# 好喜欢的美句，大家一起分享美句吧。
# 2638 added ----
# 这两天好热闹，我也来水一贴
# 2639 added ----
# 各县地理位置标示图（修改中）
# 2640 added ----
# 徽剑这个人？
# 2641 added ----
# 回来逛一逛
# 2642 added ----
# 我有点无力了。来点劲爆的吧！
# 2643 added ----
# 杭黄客专这回是真有戏了！年内开工！
# 2644 added ----
# 杭黄铁路毛蓬岗隧道率先开工段贯通
# 2645 added ----
# 废品三轮车多少钱
# 2646 added ----
# 浮西罢个罢锅～安徽黄山方言！急求～
# 2647 added ----
# 有没有看最新一集的舌尖上的中国，拍的是太看好了
# 2648 added ----
# 啦啦啦，我来水一贴
# 2649 added ----
# 有木有什么名人是安徽的？黄山的最好
# 2650 added ----
# 足球魅力真大 两国为晋级世界杯竟开战
# 2651 added ----
# 【徽州民歌】传承人——操明花
# 2652 added ----
# 梦系徽州，魂牵徽墨。求关注~求支持O(∩_∩)O
# 2653 added ----
# 生在扬州，穿在苏州，玩在杭州，吃在广州，死在柳州，葬在徽州
# 2654 added ----
# 湖南人对徽州印象
# 2655 added ----
# 快来看、！我又遇到好玩的事了
# 2656 added ----
# 我们家种植的蓝莓，马上也要到丰收的时节了！就在我们山东泰安
# 2657 added ----
# 百米中国山水画长卷,震撼！
# 2658 added ----
# 汉藏语系关系图
# 2659 added ----
# 深夜水一帖
# 2660 added ----
# 暑期速成提高班
# 2661 added ----
# 谷歌上不去了，被毙了吗？
# 2662 added ----
# 求端午节兼职啊，哪位老板能够提供啊，黄山学院学生
# 2663 added ----
# 看美国宇航局的夜景图了 规模大小一清二楚
# 2664 added ----
# 每年的这个时候、北边就开始讨论烧麦秸了
# 2665 added ----
# 【求助贴】鄙人穷学生党一枚求一徽州扇骨
# 2666 added ----
# 杭黄客运专线开始建了
# 2667 added ----
# 屯溪有种碗莲的么？求送一点种子或者种藕
# 2668 added ----
# 中国汪姓分布，徽州亮了
# 2669 added ----
# 歙县古城应尽快修复“承流宣化坊”
# 2670 added ----
# 徽王，关于徽州的清穿小说
# 2671 added ----
# 长期招生！西洋乐器「长笛」培训班
# 2672 added ----
# 【文艺】关于我的家乡——石金之恋
# 2673 added ----
# 景德镇捣毁一同性恋卖淫网——该网站卖淫业务延伸至徽州婺源
# 2674 added ----
# 一起一直觉得黄山大巴和江西大巴的涂色有些像
# 2675 added ----
# 徽杭古道免费游览人群，亲们，快来看看，适合你吗？
# 2676 added ----
# 以后自称徽州人！
# 2677 added ----
# 今年高考安徽卷，徽菜
# 2678 added ----
# 黄山市党委发文字号为什么是【黄发】而不是【徽发】
# 2679 added ----
# 《徽州魂之建吴称王》--隋唐演义唯一没出场的盖世英雄.......
# 2680 added ----
# 徽菜
# 2681 added ----
# 央视13新闻又在说徽州了。。。。
# 2682 added ----
# 来听听我唱的《飞鸟与射手》击败全国89%的人
# 2683 added ----
# 俄罗斯前50位最富官员总收入公布于联邦政府网站
# 2684 added ----
# 想想、除了西藏、也只有徽州、能回首一下了、
# 2685 added ----
# 数字黄山 频道 在介绍岩寺人文古韵
# 2686 added ----
# 徽州有端午节吃粽子的吗？
# 2687 added ----
# 太冷了 发一贴
# 2688 added ----
# 黄山只是一座山的名字，徽州文化源源流长
# 2689 added ----
# 肯德基这是要在我大徽州泛滥的节奏啊（内有亮点）
# 2690 added ----
# 又一个地名混乱、区划折腾的出现了
# 2691 added ----
# 【大徽州在中部吧被广西人欺负了】
# 2692 added ----
# 在家，车上就收听黄山交通旅游广播！
# 2693 added ----
# 胡适是皇族后裔吗
# 2694 added ----
# 这里，可以算是徽州吗
# 2695 added ----
# 徽州有什么好玩的吗？
# 2696 added ----
# 加个马头墙就是徽派了？
# 2697 added ----
# 城市复名，城市合并，国家能答应吗
# 2698 added ----
# 学校超市买到的灰菜精品地锅鸡面
# 2699 added ----
# 绩溪网中国视窗8 歙县枇杷节 竹匠
# 2700 added ----
# 求罩
# 2701 added ----
# 广德
# 2702 added ----
# 我是浙江嘉兴的 想明天出发去徽州玩  当地的朋友推荐下，跪求
# 2703 added ----
# 哈哈我是徽州女婿
# 2704 added ----
# 家里枇杷大熟耶
# 2705 added ----
# 闲暇画了个徽派房子，复制了几个看着还挺有感觉。
# 2706 added ----
# 各县县城自住房 商品房的比例是多少
# 2707 added ----
# 嘻嘻
# 2708 added ----
# 请问一下岩寺可以装联通宽带吗？
# 2709 added ----
# 复兴徽州，势在必行
# 2710 added ----
# 徽菜没落了吗？没有，它一直在寻找机会重生
# 2711 added ----
# 转贴:进来听听正宗徽语_方言吧_百度贴吧
# 2712 added ----
# 求助游徽州指导@～@
# 2713 added ----
# 520  寝室里一人今天去拿结婚证了
# 2714 added ----
# 在婺源大理坑买了瓶女儿红，30块，是真的吗？
# 2715 added ----
# 瑞瑞最近都不来了吗？
# 2716 added ----
# 在安徽吧里说一句徽州绩溪，居然被人家冷嘲热讽
# 2717 added ----
# 有徽州朝奉在淮南的吗？
# 2718 added ----
# 有富溪的不
# 2719 added ----
# 黄山区是徽州的么，外地刚考到黄山区
# 2720 added ----
# 求助：如何混进徽州古城
# 2721 added ----
# 在此吧办朋友求台二手货手机!5寸以上
# 2722 added ----
# 九和狗同音，徽语是否都是如此？
# 2723 added ----
# 有木有徽州宗祠的资料
# 2724 added ----
# 这是什么？有吃过的嘛？
# 2725 added ----
# 真心羡慕粤语区的人
# 2726 added ----
# 【徽派WC】
# 2727 added ----
# 徽州李姓有鸿达灿世严的辈分嘛？
# 2728 added ----
# 过来给徽州人民道个歉吧
# 2729 added ----
# 都戳进来吧
# 2730 added ----
# 安徽竹鼠养殖加盟咨询
# 2731 added ----
# 徽州最值得玩的地方在哪
# 2732 added ----
# 我看见有视频说，徽州地区过年吃饺子？？？我惊呆啦！！！
# 2733 added ----
# 姓氏 王 张 李 陈 刘 林 周 郑 孙 吴 夏 方 黄
# 2734 added ----
# [转帖]浙岭同春亭碑刻被盗
# 2735 added ----
# 徽文化保留的最好的是在黟县有木有
# 2736 added ----
# 朝奉都什么时候回家？
# 2737 added ----
# 百度已定义徽州地区属江南水乡，皖北佬自己去百度。。。。
# 2738 added ----
# 想去徽州旅游 求支招~
# 2739 added ----
# 徽州吧 果断关注 骚年门你们呢？
# 2740 added ----
# 拍到这个 好感动
# 2741 added ----
# 这个好像是老早老街的牌楼之一
# 2742 added ----
# 猕猴桃叫什么
# 2743 added ----
# 休宁到齐云山的省道在拓宽
# 2744 added ----
# 明天要去一个新的地方了 开心
# 2745 added ----
# 徽州有个叫铁渡桥的地方或者桥吗？
# 2746 added ----
# 杭黄铁路客运专线提前至6月30日全面开工
# 2747 added ----
# 绩溪话身边事7 2014-5-12 母亲节、讲故事等
# 2748 added ----
# 摄影网看到的几张美图
# 2749 added ----
# 朝奉文化  （我们这叫祖上 老奉 太奉 太太奉
# 2750 added ----
# 黄山上榜了“
# 2751 added ----
# 求徽州游览路线
# 2752 added ----
# o(≥ o ≤)o
# 2753 added ----
# 【求助】谁能帮我看看这个茶坐值多少
# 2754 added ----
# 终于快要铺轨了
# 2755 added ----
# 刚刚写作课，老师提到徽菜了！
# 2756 added ----
# 听说现在霸都传销很严重？
# 2757 added ----
# 绩溪县一间仓库出租
# 2758 added ----
# 有认识此人的吗!此人走失多年
# 2759 added ----
# 本人非徽州人，但非常喜欢徽文化。。。
# 2760 added ----
# 徽州人的宗族观念
# 2761 added ----
# 有谁知道深度派出所的电话
# 2762 added ----
# 今天第一天来到此吧，发觉吧又好会闹腾
# 2763 added ----
# 貌似建德和徽州说话差不多
# 2764 added ----
# 我们那把锅巴叫“焦pì”，这个pì到底是哪个字呢？
# 2765 added ----
# 原来烧饼有几百年的历史了，我还以为是近几十年从浙江传过来的
# 2766 added ----
# 舌尖上的中国也有淳安噢
# 2767 added ----
# 微博上黑舌尖上的中国
# 2768 added ----
# 发两张图片，做头像都是极好的！
# 2769 added ----
# 诚招销售代表
# 2770 added ----
# 中国地域差异大，各种地域歧视。
# 2771 added ----
# 黄山改回徽州的日子不远了～=_=～
# 2772 added ----
# 江淮官话大军压境
# 2773 added ----
# 广告贴 在龙游江边耍
# 2774 added ----
# 你们划拳都是怎么喊的？
# 2775 added ----
# 郁闷！天生没有发财梦！
# 2776 added ----
# 合福高铁婺源段铺轨照片，看着好激动
# 2777 added ----
# 舌尖2第二集第一个提到的就是歙县的菜籽油
# 2778 added ----
# 作为徽州人，婺源为之骄傲，我们的祖先的宗祠程氏祠堂就在黄山
# 2779 added ----
# 黄山市政府上 百度新闻 首页 了
# 2780 added ----
# 马上就到绩溪了、龙岗小憩中、
# 2781 added ----
# 有木有看见大黄山吧？欢迎来踩！
# 2782 added ----
# 徽州吧里有木有旌德人呐
# 2783 added ----
# 好久没来了 来一贴！
# 2784 added ----
# 我表示自己没有省籍认同
# 2785 added ----
# 绩溪话新鲜事（五）孙悟空“大闹”绩溪等（视频）
# 2786 added ----
# 请教去徽州的旅游攻略
# 2787 added ----
# 这是徽派的风格吗？
# 2788 added ----
# 齐云山牌
# 2789 added ----
# 准备回家
# 2790 added ----
# 歙县嘉银村镇银行参加笔试的有吗？
# 2791 added ----
# 徽州民俗手工艺术作品
# 2792 added ----
# 歙县菜籽油飘香“舌尖上的中国2”（图）
# 2793 added ----
# 歙县人，
# 2794 added ----
# 各位乡亲们，我的帖子上百度首页了
# 2795 added ----
# 婺源第一家肯德基今天正式营业
# 2796 added ----
# 婺源离开徽州已经80年了。。
# 2797 added ----
# 美，绩溪话怎么读/
# 2798 added ----
# 黄山人表示没去过徽州 ，是不是有点说不过去啊
# 2799 added ----
# 诚招销售代表
# 2800 added ----
# 我的大白完你有在做旅游吗?
# 2801 added ----
# 诚招销售代表
# 2802 added ----
# 屯溪哪家饭店能吃到果子狸和马蹄鳖
# 2803 added ----
# 最美徽州
# 2804 added ----
# 徽州成了浙江的了
# 2805 added ----
# 我觉得黄山市必须改为徽州市，安徽安徽，徽，不如安徽改成安黄省？
# 2806 added ----
# 在浙江桐庐看到的徽派建筑
# 2807 added ----
# 水一贴、我终于知道我的祖籍了
# 2808 added ----
# 给你们看一个真正的垃圾
# 2809 added ----
# 南陵由于拒绝划许镇入市区而暂定取消申报县级市
# 2810 added ----
# 有从淳安移民过来的吗
# 2811 added ----
# 歙县美食吧，腊肉炖笋干，近日采茶繁忙，炖一锅可以吃几天呢！
# 2812 added ----
# 黄山旅游收入的钱都用在哪了？
# 2813 added ----
# 旌德算徽州吗
# 2814 added ----
# 灰州早日光复啊，顺便把土省解散
# 2815 added ----
# 有“徽州历史群吗”
# 2816 added ----
# 最近都有在看网上的<绩溪话新鲜事>么
# 2817 added ----
# 那里有做墨模的
# 2818 added ----
# 话说痞王我回来了
# 2819 added ----
# 小雯报道：国家社会科学基金项目“徽州文化生态保护研究”顺利结
# 2820 added ----
# 歙县美食吧奉上毛豆腐，在徽园内，看完牌坊后，你石否也享用过？
# 2821 added ----
# 我是安徽徽州人
# 2822 added ----
# 给位徽州同乡注意了。【徽州崛起】势在必行。
# 2823 added ----
# 今天在上海打电话回家时被一个南通的同事误认为是苏南人
# 2824 added ----
# 刚买个土豪 很激动 想让大家推荐下好的配件呀
# 2825 added ----
# 歙县美食烧饼那酥香的感觉你是否记得？
# 2826 added ----
# 【百度百科 “马头墙”是吧友们改的吗？】
# 2827 added ----
# 对于淳安，建德，不知徽州人民怎么看
# 2828 added ----
# 徽州与宣州
# 2829 added ----
# 又一徽州籍厅官被查
# 2830 added ----
# 婺源的清明粿颜色好深啊~
# 2831 added ----
# 嘻嘻tv昨天在批新安江啊
# 2832 added ----
# 今天最后惊喜，经典中的经典，歙县石头粿！弘扬歙县美食，请顶我
# 2833 added ----
# 早安，徽州
# 2834 added ----
# 实在看不下去了，忍不住第一次发帖！废话不多说，看下图
# 2835 added ----
# 清明上山踏春
# 2836 added ----
# 山里人家--白际
# 2837 added ----
# 关于徽州地位的史上第一牛文
# 2838 added ----
# 【2013 纪录片】《徽茶》
# 2839 added ----
# 这个属于徽派建筑么？
# 2840 added ----
# 绩溪人戴和根2014年3月任中国铁路工程总公司党委书记
# 2841 added ----
# 徽州婺源甲路村是张姓的一大发源地。
# 2842 added ----
# 徽州在皖南哪里，一直想去走走
# 2843 added ----
# 【黄山人吧】前来求关注！
# 2844 added ----
# 我是大明徽州府
# 2845 added ----
# 你们是吃清明粿还是青团
# 2846 added ----
# 神马节奏   我明明在大歙县
# 2847 added ----
# 祁门到千岛湖的客车有吗
# 2848 added ----
# 反对千岛湖引水工程！！！！
# 2849 added ----
# Soso街景
# 2850 added ----
# 簸箕各县读音
# 2851 added ----
# 论徽，可辩勿删，不要恼羞成怒
# 2852 added ----
# 需找王氏三槐堂宗谱
# 2853 added ----
# 那些每天故意发贴问安徽什么什么的到底干嘛的
# 2854 added ----
# 歙县想当好
# 2855 added ----
# 吧里的回帖有点像跌停板
# 2856 added ----
# 新人想知道这里对汉服的态度。。。。。
# 2857 added ----
# 求小吧主
# 2858 added ----
# 上海城隍庙求个因缘
# 2859 added ----
# 绩溪话的两个“我们“
# 2860 added ----
# 在故园徽州看到黄山北站无柱雨棚改为有柱雨棚了，真的假的
# 2861 added ----
# 吾之徽州婺源簧岭游
# 2862 added ----
# 这时候的家乡是一年中最美的
# 2863 added ----
# 居然看见一文章称新安江是安徽人的母亲
# 2864 added ----
# 谁来拯救屯溪话？
# 2865 added ----
# 哪里来这么多问其他地区的帖子
# 2866 added ----
# 想到徽州旅游 有指点一二的么
# 2867 added ----
# 想去徽州旅游，~~~~请吧友支个招
# 2868 added ----
# 想去徽州旅游！不知道有什么推荐！
# 2869 added ----
# 已笑尿
# 2870 added ----
# 夏天的脚步近了，你是否想起了这样的美食？
# 2871 added ----
# 徽州地名中“坑”字，我的看法
# 2872 added ----
# 发现一个大徽州论坛~
# 2873 added ----
# 府志县志下载
# 2874 added ----
# 谁买过锅炉、前段时间的哥们呢？
# 2875 added ----
# 我发起了一个微博投票：你认为婺源应该划为安徽省还是江西省？
# 2876 added ----
# 骨呢哈
# 2877 added ----
# 3月12日晚中央1套CCTV1黄金档播出大型电视剧《原乡》处处说婺源
# 2878 added ----
# 【呱呱呱，唧唧唧~】
# 2879 added ----
# 【歙县美食吧】在歙县，吃这个，你们应该知道这是哪了吧
# 2880 added ----
# 大爱菠萝饭，叉烧包……吃货戳进来
# 2881 added ----
# 感觉徽州地区带 坑 的地名比较多哦！
# 2882 added ----
# 相亲女
# 2883 added ----
# 一生痴绝处，无梦到徽州。
# 2884 added ----
# 歙县我的窝装饰设计有限公司
# 2885 added ----
# 徽州各地「你我他」第一人称都怎么用？
# 2886 added ----
# 南陵的一栋仿徽式建筑民宅---留耕园
# 2887 added ----
# 春天来了、大家去照相吧
# 2888 added ----
# 清明去歙县求搭、、
# 2889 added ----
# 黟县人路过
# 2890 added ----
# 婺源话里几个“常用的吴语词”
# 2891 added ----
# 在黄山某乡镇工作，说说对这里的人的感觉。
# 2892 added ----
# 大家出来说说话吧
# 2893 added ----
# 对啊，我们徽州各地都是怎么称呼黄山的
# 2894 added ----
# 黄山机场2014年夏秋季航班时刻表(20140323更新)
# 2895 added ----
# 寻张氏宗亲，延肃公后人
# 2896 added ----
# 安徽省旅游局党组书记、局长胡学凡接受调查
# 2897 added ----
# 请问徽州的油菜花开了没有
# 2898 added ----
# 春雪！
# 2899 added ----
# 白完群众把嘴洗干净了再来灌输你们的讨饭经
# 2900 added ----
# 杯具的2011版歙县志方言志
# 2901 added ----
# 天啊，婺源还是共产党的天下吗？
# 2902 added ----
# 安徽省旅游局局长胡学凡涉严 重违纪被立案调查
# 2903 added ----
# 衢徽严杭嘉湖甬台温
# 2904 added ----
# 祁门、休宁、黑多不知道何时才能通高铁
# 2905 added ----
# 徽州哪个地方算命算卦最准最好,请知道的大侠告诉我
# 2906 added ----
# 低价转让一辆电动三轮车
# 2907 added ----
# 春季到了，各类花都开了，，各位可以出动赏花去了。
# 2908 added ----
# 安徽地区哪里卖pp打包带粉碎料
# 2909 added ----
# 大润发是周润发开的吗
# 2910 added ----
# 祁门的安庆移民是什么时候迁入的？占多大比重？
# 2911 added ----
# 徽语会消失吗？
# 2912 added ----
# 十一回家随便拍的..坐标：××村
# 2913 added ----
# 安徽十大难懂方言
# 2914 added ----
# 徽州 徽州
# 2915 added ----
# 老婆今天凌晨生崽了！女人好辛苦！
# 2916 added ----
# 黄杭高铁改来改去，这回是真的了
# 2917 added ----
# 从宏村早晨出发去徽州，应该怎么走？徽州一天时
# 2918 added ----
# 模拟一下典型的绩溪口音普通话
# 2919 added ----
# 宏村求偶遇
# 2920 added ----
# 2014年安徽‘教师资格证’考试题资料答案|考试时
# 2921 added ----
# 你们会不会看不起穷亲戚。
# 2922 added ----
# 油菜花开
# 2923 added ----
# 对于中国股市，我只想说一个字：草！
# 2924 added ----
# 还是新闻么？
# 2925 added ----
# 【歙县.春】四月随拍.（第一季）
# 2926 added ----
# 跟本州人有关的歌曲几首
# 2927 added ----
# 【屯溪一中 2015年 搬迁  实行全寄宿制0
# 2928 added ----
# 徽菜世家这个人大家知道么？
# 2929 added ----
# 其实说真的，祁门人对徽州的认同不浓，尤其是县城，
# 2930 added ----
# 坐在家里都可以看婺源了
# 2931 added ----
# 徽州和吴语金衢片地区的联系不知道你们徽州人有没有研究过。
# 2932 added ----
# 听懂德芙妹妹的绩溪话撸
# 2933 added ----
# 过年去开化走亲戚
# 2934 added ----
# 肛西马来
# 2935 added ----
# 杭黄铁路毛蓬岗隧道率先动工 萧山到黄山只需一个多小时
# 2936 added ----
# 跪求~下午啥时候有从府城去南陵的汽车。
# 2937 added ----
# 大家觉得皖南和徽州有关系么？
# 2938 added ----
# 拜托我是婺源人耶
# 2939 added ----
# 【京福高铁神马时候才能修通啊…】
# 2940 added ----
# “徽州贷”
# 2941 added ----
# 亲们有没有高清大黄山的下载地址。。
# 2942 added ----
# 合肥，合全省之力肥了一地之民
# 2943 added ----
# 一个江西上饶人对婺源的看法（原创）
# 2944 added ----
# 也谈 部分吧友对安徽其它地区缺乏认同感
# 2945 added ----
# 免费索取黄山旅游攻略，有问必答贴
# 2946 added ----
# 黄山一公车堵医院大门：伤员被截肢 涉事局长被免
# 2947 added ----
# 寻找徽姑娘，2014，你懂的！
# 2948 added ----
# 徽州文化产品有哪些
# 2949 added ----
# 事件已解决，帖子已删
# 2950 added ----
# 管事的出来删贴呢
# 2951 added ----
# 中国八大名酒之一
# 2952 added ----
# 杭黄高铁三阳客运站争取成功
# 2953 added ----
# 有没有觉得黄杭高铁太绕了
# 2954 added ----
# 说说徽州与金华的关系。
# 2955 added ----
# 关于徽州的词句、诗赋与民谣：一生痴绝处，无梦到徽州
# 2956 added ----
# 今天开始恢复签到
# 2957 added ----
# 淋逼一日游 门票130元
# 2958 added ----
# 为失踪客机上的人们祈祷
# 2959 added ----
# 不知真假大家看看
# 2960 added ----
# 转让95成新电动车60伏一辆
# 2961 added ----
# 陈胜吴广起义发生地宿州西寺坡镇改用“大泽乡”原名
# 2962 added ----
# 在齐云山上 当地人居然刻意教小孩普通话
# 2963 added ----
# 好久不来出什么事了？
# 2964 added ----
# 中午吃绩溪炒米粉
# 2965 added ----
# 女首富唐僧老婆陈丽华为何喜爱紫檀与徽派建筑
# 2966 added ----
# 安徽三大名山将建旅游轻轨 合肥黄山池州设免税购物
# 2967 added ----
# 黄山下雪了
# 2968 added ----
# 徽州地区哪些区县相对繁华经济也不错？
# 2969 added ----
# 有关徽州齐云山的仙侠小说，求支持！
# 2970 added ----
# 有点怕怕了
# 2971 added ----
# 龙川胡氏的所在地是不是现在的龙川景区
# 2972 added ----
# 百度中国十大匪城！！！
# 2973 added ----
# 池养化龙鱼，瞅瞅我家瓷皿中的鱼儿…
# 2974 added ----
# 大镇群英街上的徽州文化旅游招牌
# 2975 added ----
# 徽州，张姓是大姓吗？
# 2976 added ----
# 1904年徽州府 分县户口
# 2977 added ----
# 想在电脑上卖衣服的留号家你
# 2978 added ----
# 不要误解新疆人，那只是一小部分东突暴乱份子的行经
# 2979 added ----
# 麻烦大家看下徽韵中赞扬徽州的诗词迷茫了，不好
# 2980 added ----
# 安徽婺源朱氏在元末明初是否有位朱元字次乾的？
# 2981 added ----
# 麻烦大家看下徽韵中赞扬徽州的诗词了解的说下吧
# 2982 added ----
# 请教下徽韵中赞扬徽州的诗词了解的说下吧，十分
# 2983 added ----
# 最近油菜花开了没？
# 2984 added ----
# 如果徽州人都不说徽州话了，保护徽文化还有什么意义？
# 2985 added ----
# 想在电脑上卖衣服的留号家你
# 2986 added ----
# 徽州府改名争议（百度百科）
# 2987 added ----
# 有黄山市徽州区岩寺人吗
# 2988 added ----
# 在重庆被人问得最多也是最烦的一个问题
# 2989 added ----
# 同是徽州人，共饮一江水
# 2990 added ----
# 上次我碰到一个人，是个15岁的少年。
# 2991 added ----
# 我朋友最近刚玩贴吧
# 2992 added ----
# 为什么白完人讲安徽的时候总要扯上徽州呢？
# 2993 added ----
# 你们是什么心态？
# 2994 added ----
# 外省人请教：毛豆腐怎么做?
# 2995 added ----
# 【摄影】徽派建筑 +qq 654859653
# 2996 added ----
# 在徽州地区寻找徽雕的民间艺人
# 2997 added ----
# 【拜吧】黄山美食吧欢迎你
# 2998 added ----
# 想请教一个问题，赣语、吴语、徽语是不是有什么相似性啊？
# 2999 added ----
# 新人报道
# 3000 added ----
# 郑州动物园那只死去的大熊猫与休宁动物园那只可能是姐妹
# 3001 added ----
# 寻，蓝田镇的朋友。
# 3002 added ----
# 中国最美乡村婺源_微《篁岭人家》
# 3003 added ----
# “我是徽州人,徽州绩溪人”----赵日新
# 3004 added ----
# 过年在家手机随拍
# 3005 added ----
# 屯溪真的越来越漂亮了
# 3006 added ----
# 转贴:《中国最美乡村——徽州婺源》
# 3007 added ----
# 休宁'屯奚的朋友，有在济南的吗？
# 3008 added ----
# 婺源话应该大部分分平翘的
# 3009 added ----
# 【黎阳老街】百科
# 3010 added ----
# 胡适的家乡
# 3011 added ----
# 【延时摄影】走近徽州，走进徽州。
# 3012 added ----
# 明天走了，不舍
# 3013 added ----
# 新人来冒泡，在杭州
# 3014 added ----
# 转贴:特级原产地纯手工制作祁门红茶全国包邮香高味浓 买三送一包...
# 3015 added ----
# 你们那有这个么
# 3016 added ----
# 歙县便民电话大全
# 3017 added ----
# 徽州的春节习俗
# 3018 added ----
# 喜欢徽州，我想去徽州学门手艺，大家说说成不成？学点什么好
# 3019 added ----
# 【MTV】《在黄山》2014年正式版 （玩爆旧版）  【强力推荐！】
# 3020 added ----
# 你们的口音里还分不分“义务“和“义乌“啊
# 3021 added ----
# 请问屯溪哪里矫正牙齿比较好，就是箍牙
# 3022 added ----
# 【祝小猴子吧的小猴子们新年大叽~】
# 3023 added ----
# 明天去侉肥惹
# 3024 added ----
# 这是以前说的匪寇王直吗?…今天偶然看到的
# 3025 added ----
# 快春天了，快到了吃蒿粿的季节了
# 3026 added ----
# 我在车托之家发现了你
# 3027 added ----
# 我真的感觉应该再发一贴
# 3028 added ----
# 在我室友看来
# 3029 added ----
# 大明王朝1566里的胡宗宪符合史实吗
# 3030 added ----
# 这个砖雕如何
# 3031 added ----
# 上饶马拉松终点——朱熹纪念馆
# 3032 added ----
# 徽派建筑
# 3033 added ----
# 情侣装
# 3034 added ----
# 胡适的言论
# 3035 added ----
# 忘了学生证，门票好贵
# 3036 added ----
# 绍兴 婺源 徽州 哪个地方最好玩求解答啊啊啊！！
# 3037 added ----
# 快升级了，你们懂得
# 3038 added ----
# 猜猜那碑上写的是什么字？
# 3039 added ----
# 表妹男友家带来的婺源特产，叫啥名呢？
# 3040 added ----
# 想知道:黄山市 从黄山站到徽州古城怎么坐公交？
# 3041 added ----
# 徽州是个好地方
# 3042

# %%
soup = BeautifulSoup(browser.page_source)
sub_texts = soup.findAll('li', {'class':' j_thread_list clearfix'})

for link in sub_texts:
    t1 = link.find('a', {'class': 'j_th_tit'})
    t3 = link.find('div', {'class': 'threadlist_abs threadlist_abs_onlyline '})
    t2 = 'http://tieba.baidu.com' + t1['href']
    #print t1.text
    #print t2   
    #print t3.text

    #tt0 = abs(sum(df['url'].str.find(str(t0.a['href']))))
    #if(tt0 == len(df) and 0):
    if 1:
        print 'added ----'
        print t1.text
        df.loc[idx] = get_empty_columns()

        #set title and url    
        df.loc[idx]['url'] = t2
        df.loc[idx]['title'] = t1.text

        df.loc[idx]['brief'] = t3.text
        df.loc[idx]['from'] = '百度贴吧'
        idx +=1
# Out:
# added ----
# 自制徽州知识测试试题（十道）
# added ----
# 【吴门烟水】平江路里的徽文化
# added ----
# 绩溪曹姓是曹操后裔？
# added ----
# 德迷都出来吧
# added ----
# 超级月亮！！！？？？
# added ----
# 黄山市哪里学车比较好，比较便宜
# added ----
# 今晚我德意志战车将碾压潘帕斯雄鹰
# added ----
# 这么多德吹，伐开心
# added ----
# 徽州吧最近咱了，人气呢。。。
# added ----
# 新领导登基
# added ----
# 爸爸去哪儿里建德新叶古村为什么也被称徽派建筑嘞
# added ----
# 三十分钟5-0。大德国威武！
# added ----
# 问一下咱黄山本地人去黄山门票有优惠吗
# added ----
# 我发现了好多古坟墓
# added ----
# 我擦嘞 三个大吧我只认识昏哒一个
# added ----
# 【登基第一帖】
# added ----
# 徽州杂图
# added ----
# 看看浙江人是怎么说安徽人的，来自安吉吧。
# added ----
# “徽”字的意境原来这么美
# added ----
# 为什么古代休宁出了那么多状元？
# added ----
# 徽州行政地图
# added ----
# 徽语应该改名吴语严徽片，单独拎出来是不对的
# added ----
# 7月4日的 《天天向上》安徽美女 专辑看了么？
# added ----
# 苏州的安徽会馆
# added ----
# 黄山风景区的收入归谁啊？
# added ----
# 徽州为何把正月十八叫作“十八朝”？<转载>
# added ----
# 朱熹 戴震 胡适  理学历程
# added ----
# 胡宗宪VS徐渭
# added ----
# 我们给弄个微博话题吧
# added ----
# 杭州又划区了
# added ----
# 徽州到杭州高铁终于要开工啦！
# added ----
# 安徽皖南吧请求与贵吧结为友好贴吧，互加友情链接
# added ----
# 新安江水库对徽州影响太大了。
# added ----
# 网易首页了 安徽祁门5位农民离奇死亡续:系"二氧化碳湖"夺命
# added ----
# 新吧主上任，不应该一人来骂一句吗？
# added ----
# 妈的。在自己吧里就是好
# added ----
# 徽州吧戒严令第一号 徽吧字（2014）2号
# added ----
# 太坑了，绩溪的兄弟你们是不是好不爽
# added ----
# 新一届的三大长老不出来发表下政治观点么
# added ----
# 徽州科普动画
# added ----
# 吧主都换掉了？新吧主上任不来个自我介绍么
# added ----
# 簧岭游徽风记
# added ----
# 最后一课---（写在屯溪一中即将搬迁之际）（转载）
# added ----
# 【醒目】2014徽吧一号文件《关于吧主的任免问题》
# added ----
# 我申请吧主你们支持么？
# added ----
# 纳尼，纳尼，纳尼，纳尼
# added ----
# 小巴诈尸了，消失好久了啊

# %%
print len(df), idx
# Out:
# 2576 2625

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2625 entries, 0 to 2624
# Data columns (total 11 columns):
# dt          919 non-null object
# source      919 non-null object
# domain      919 non-null object
# url         2625 non-null object
# title       2625 non-null object
# summary     919 non-null object
# image       919 non-null object
# brief       2625 non-null object
# body        919 non-null object
# raw_page    919 non-null object
# from        2625 non-null object
# dtypes: object(11)
# memory usage: 246.1+ KB

# %%
df.head()
# Out:
#   dt source domain                                  url        title summary  \
# 0                   http://tieba.baidu.com/p/5010752847      池黄走北线了？
# 1                   http://tieba.baidu.com/p/5010799483       抱怨但难避免
# 2                   http://tieba.baidu.com/p/5009528016  两会关于恢复徽州的提案
# 3                   http://tieba.baidu.com/p/5010733891         《午后》
# 4                   http://tieba.baidu.com/p/5010715419       我仍然还爱你
#
#   image                                              brief body raw_page  from
# 0        \n            我看安庆某吧的人都在高潮，说确定走北线了。黄山市如今是腹背受敌，...                百度贴吧
# 1                        \n            甘美芬芳故乡情——\n                        百度贴吧
# 2        \n            http://mp.weixin.qq.com/s/-c99h5...                百度贴吧
# 3                      \n            如果他都走了　剩一把土\n                        百度贴吧
# 4                  \n            快看看 快看看 这某某 那某某\n                        百度贴吧

# %%
df_no_dup = df.drop_duplicates(['url'])

# %%
df_no_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2576 entries, 0 to 2624
# Data columns (total 11 columns):
# dt          870 non-null object
# source      870 non-null object
# domain      870 non-null object
# url         2576 non-null object
# title       2576 non-null object
# summary     870 non-null object
# image       870 non-null object
# brief       2576 non-null object
# body        870 non-null object
# raw_page    870 non-null object
# from        2576 non-null object
# dtypes: object(11)
# memory usage: 241.5+ KB

# %%
#print browser.page_source

# %%
print fname1
# Out:
# ./data/general/baidu-huizhouba.csv

# %%
df_no_dup.to_csv(fname1, encoding='utf-8', index=False)

# %%
df = pd.read_csv(fname1)

# %%
if(browser):
    browser.quit()

# %%
df.head(100)
# Out:
#             dt     source domain  \
# 0   2016-12-16      网易新闻     NaN
# 1   2016-12-10      网易新闻     NaN
# 2   2016-12-14    新华网安徽站     NaN
# 3   2016-11-29      网易新闻     NaN
# 4   2016-12-09     东方财富网     NaN
# 5   2016-10-04       凤凰网     NaN
# 6   2016-10-01      新浪新闻     NaN
# 7   2016-09-28       新华网     NaN
# 8   2016-09-28      腾讯财经     NaN
# 9   2016-12-07    人民网安徽站     NaN
# 10  2016-09-24      21CN     NaN
# 11  2016-09-24      新浪财经     NaN
# 12  2016-11-29   中国网福建频道     NaN
# 13  2016-11-27      浙江在线     NaN
# 14  2016-11-25  合肥房地产交易网     NaN
# 15  2016-11-15      万家热线     NaN
# 16  2016-09-30       凤凰网     NaN
# 17  2016-10-19    新华网安徽站     NaN
# 18  2016-08-20      网易新闻     NaN
# 19  2016-10-25     市场信息报     NaN
# 20  2016-10-04    cctv新闻     NaN
# 21  2016-10-03    cctv新闻     NaN
# 22  2016-08-18      网易新闻     NaN
# 23  2016-09-09     华夏经纬网     NaN
# 24  2016-08-10      网易新闻     NaN
# 25  2016-08-05   人民日报人民网     NaN
# 26  2016-08-04      网易新闻     NaN
# 27  2016-08-01      网易新闻     NaN
# 28  2016-09-24      万家热线     NaN
# 29  2016-09-12     中国台湾网     NaN
# ..         ...        ...    ...
# 70  2016-05-16     黄山新闻网     NaN
# 71  2016-03-29      21CN     NaN
# 72  2016-03-29      网易新闻     NaN
# 73  2016-05-05    新华网安徽站     NaN
# 74  2016-03-28      网易财经     NaN
# 75  2016-03-28       凤凰网     NaN
# 76  2016-05-01    新华网安徽站     NaN
# 77  2016-05-06     黄山新闻网     NaN
# 78  2016-04-25    新华网安徽站     NaN
# 79  2016-04-18       东方网     NaN
# 80  2016-04-24      万家热线     NaN
# 81  2016-04-24      万家热线     NaN
# 82  2016-03-30     华夏经纬网     NaN
# 83  2016-04-15      新浪乐居     NaN
# 84  2016-04-06    新华网安徽站     NaN
# 85  2016-04-10      合肥晚报     NaN
# 86  2016-03-25       腾讯网     NaN
# 87  2016-03-30     黄山新闻网     NaN
# 88  2016-03-29      华奥星空     NaN
# 89  2016-03-29       安徽网     NaN
# 90  2016-06-11       凤凰网     NaN
# 91  2016-02-05      网易新闻     NaN
# 92  2016-02-01      腾讯财经     NaN
# 93  2016-02-03      万家热线     NaN
# 94  2016-01-28    新华网安徽站     NaN
# 95  2016-01-29      中国视窗     NaN
# 96  2016-01-28      中安在线     NaN
# ..                            ...     ...   ...
# 70             “徽文化”精彩亮相2016深圳文博会     NaN   NaN
# 71              “徽文化”首部百科全书式工具书问世     NaN   NaN
# 72              “徽文化”首部百科全书式工具书问世     NaN   NaN
# 73            “徽文化”本月12日起将亮相深圳文博会     NaN   NaN
# 74       安徽黄山乡村旅游节启幕 “徽文化”遇见“新时尚”     NaN   NaN
# 75       安徽黄山乡村旅游节启幕 “徽文化”遇见“新时尚”     NaN   NaN
# 76               合肥蜀山区井岗镇举办徽文化培训班     NaN   NaN
# 77         歙县三阳镇: 探寻徽杭古道,挖掘和保护徽文化     NaN   NaN
# 78              黟县谋划打造“匠人圣地”传承徽文化     NaN   NaN
# 79         歙(shè)县坡山村:徽文化风光拍摄最佳位置     NaN   NaN
# 80     放弃“铁饭碗”南下做印刷 强抓设计欲与徽文化融合并进     NaN   NaN
# 81     放弃“铁饭碗”南下做印刷 强抓设计欲与徽文化融合并进     NaN   NaN
# 82       兴泽基金会代表台胞何元吉先生一行到歙县考察徽文化     NaN   NaN
# 83           重塑古镇徽文化 新华联拟斥巨资弘扬黄梅戏     NaN   NaN
# 84                 黄山设徽文化网络技术研究中心     NaN   NaN
# 85                  遇见“金水坊” 邂逅徽文化     NaN   NaN
# 86            徽州文化的智慧表征:遍布村落的徽派建筑     NaN   NaN
# 87                 《徽州文化大辞典》首发式举行     NaN   NaN
# 88          黄山市委书记任泽锋谈'旅游+'及徽文化保护     NaN   NaN
# 89                黄山今天发行《徽州文化大辞典》     NaN   NaN
# 90                     联谊会助力徽文化传承     NaN   NaN
# 91                 影视镜头里的“徽文化”(图)     NaN   NaN
# 92        黄山旅游:餐饮融入徽文化,酒店改造迎合消费升级     NaN   NaN
# 93    徽晚临时调档提前至本周五 丫蛋王小利新作融合徽文化 图     NaN   NaN
# 94                  黄山创新推动徽文化保护传承     NaN   NaN
# 95      黄山推动徽文化保护传承 继续推进徽州古建筑保护工程     NaN   NaN
# 96                  黄山创新推动徽文化保护传承     NaN   NaN
# 97         合肥“银发”旗袍队一年百余场走秀 宣传徽文化     NaN   NaN
# 98                  传承"徽骆驼" 再耀徽文化     NaN   NaN
# 99                 海外华裔青少年在皖体验徽文化     NaN   NaN
#
#                                                 brief body raw_page from
# 0   (原标题:停止“徽文化”的“异地保护”) 本报讯 徽州文化生态保护试验区在皖南国际旅游示范区...  NaN      NaN  NaN
# 1   来自中国、俄罗斯、印度、印度尼西亚、意大利、新加坡、日本和美国等十多个国家和地区的30余位书...  NaN      NaN  NaN
# 2   12月9日至10日,来自中国、俄罗斯、印度、印度尼西亚、意大利、新加坡、日本和美国等十多个国...  NaN      NaN  NaN
# 3   (原标题:黄山:“活态”传承徽文化) [编者按] 我省文化底蕴深厚,自然景观秀丽,风貌特色鲜...  NaN      NaN  NaN
# 4   华安证券认为,黄山旅游成为黄山市乃至安徽省旅游资源的运作平台,这也是安徽省和黄山市对公司的定...  NaN      NaN  NaN
# 5   安徽徽文化博物馆:梦回古徽州 资讯 > 社会 > 看东方 2016-10-04 08:50:...  NaN      NaN  NaN
# 88  “十三五”期间,我们要以此为契机,大力发展全域旅游,着力在“旅游+农业”壮大乡村旅游、“旅游...  NaN      NaN  NaN
# 89  今天上午,黄山市市委市政府召开《徽州文化大辞典》首发式,这部近340万字且配了大量精美珍贵图...  NaN      NaN  NaN
# 90  “组织传统文化的传播活动,尤其使青少年了解传统文化的精髓。”余重阳表示,联谊会还积极走进校园...  NaN      NaN  NaN
# 91  (原标题:影视镜头里的“徽文化”(图))近年来,一些影视剧和综艺节目纷纷来到黄山市取景拍摄,...  NaN      NaN  NaN
# 92  公司区位优势明显,转型文化旅游意愿强烈,同时外延+内生增长方式确定: 牵手祥源控股打开业务扩...  NaN      NaN  NaN
# 93  日前,记者获悉,原定2月6日(农历腊月二十八)晚在安徽卫视播出的《金猴报春 福满江淮——20...  NaN      NaN  NaN
# 94  “十三五”期间,该市在继续推进徽州古建筑保护利用工程的同时,将实施徽文化资源保护传承工程,推...  NaN      NaN  NaN
# 95  从日前召开的黄山市六届人大六次会议上了解到,“十三五”期间,黄山市在继续推进徽州古建筑保护利...  NaN      NaN  NaN
# 96  黄山市是徽文化的发祥地,也是皖南国际文化旅游示范区和徽州文化生态保护实验区的核心区域。  5...  NaN      NaN  NaN
# 97  资讯标签: 合肥“银发”旗袍队一年百余场走秀 宣传徽文化分享到: 更多 核心提示:秀丽江南、...  NaN      NaN  NaN
# 98  “徽骆驼”精神是徽州文化的深厚积淀,也是安徽地域文化的重要组成部分。“徽骆驼”精神作为安徽特...  NaN      NaN  NaN
# 99  本次活动为期10天,以中华文化中的“徽文化”为主要载体,采取课堂讲座和实地参观等形式,帮助海...  NaN      NaN  NaN
#
# [100 rows x 11 columns]

# %%
for i in range(0, len(df)):
    url =  df.loc[i]['url']        
    browser.get(url)
    time.sleep(5)
    df.loc[i]['raw_page'] = browser.page_source
    soup = BeautifulSoup(browser.page_source)
    [s.extract() for s in soup(['style', 'script', '[document]', 'head', 'title'])]
    visible_text = soup.getText()        
    df.loc[i]['raw_page'] = browser.page_source
    df.loc[i]['body'] = visible_text
# Out:
# 无障碍说明
#
#
#
#
# 首页
# 新闻
#
# 体育
# 娱乐
# 视频
# 财经
# 证券
# 汽车
# 房产
# 科技
# 数码
# 游戏
# 教育
# 时尚
# 文化
#
# 	更多
#
# 			动漫
# 			读书
# 			儿童
# 			星座
# 			精品课
# 			全部频道
#
#
#
#
#
#
#
#
#
#
# 			一键登录
#
#
# 			微博
#
#
# 			Qzone
#
#
# 			QQ邮箱
#
#
#
# 			收藏
#
#
#
#
#
#
#
#
#
#
#
# 	浏览器更新提醒立即更新×
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     证券
#                     港股
#                     美股
#                     宏观
#                     国际
#                     金融
#                     公司
#                     消费
#                     理财
#                     财经资讯
#
#
#
#
#
#
#
#
#
# 								搜狗
#
#
#
#
#
#
#
#
#
#
#
#
# 徽文化沙龙 解密徽商之道
#
#
# 综合新闻深圳新闻网-深圳商报2016-09-28 06:24
#
#
#
# 	分享
#
#
# 	腾讯微博
# 	QQ空间
# 	QQ好友
# 	新浪微博
#
# 		微信好友
#
#
# 	领英分享
#
#
#
#
#
#
#
#
# 　　深圳商报讯 （记者 陈广琳）由深圳市社科联主办、深圳市徽文化研究会承办的第二期徽文化沙龙日前在福田区图书馆举行，安徽大学徽学研究中心主任、中国著名徽学专家、深圳市徽文化研究会首席学术顾问卞利，应邀在沙龙上演讲题为《传统徽商的经营管理的成功之道及其现代启示》，沙龙主讲嘉宾、深圳市海天出版社副总编辑于志斌做了专题演讲，深圳市徽文化研究会秘书长郁海雷主持沙龙。
# 　　卞利从10个方面阐述了传统徽商的成功秘籍，为现代商帮、商业的发展提供了有益启示和借鉴。解析了传统徽商的成功之道后，卞利还揭示了徽商的现代价值。他认为，徽州经济文化领域越来越受到学术界的关注，徽商始终是一个凝重的话题。徽商数百年的经营活动，给我们留下了丰厚的遗产。卞利说，徽商正是凭着他们特有的徽商精神，从而能够从无到有，从小到大，乃至于发展为雄视天下的大商帮。这种精神植根于中国传统文化的土壤之中，又被徽商进一步发扬光大。“徽骆驼” 和“绩溪牛”所造就的徽商精神，不仅是徽商的巨大财富，更是徽商留给后人的宝贵遗产。
# 　　（陈广琳）
#
# 正文已结束，您可以按alt+4进行评论
#
#
#
#
#
#
#
#
#
#
#
#
# 		分享到:
#
# 												腾讯微博
# 	QQ空间
# 	QQ好友
# 	新浪微博
# 	二维码
# 	领英分享
#
#
#
#
#
#
# 				扫一扫，用手机看新闻！
# 				用微信扫描还可以
# 				分享至好友和朋友圈
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	相关搜索
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             为你推荐
#
#
#
#
# 恒大人寿被罚禁投股票一年 公司回应
# 2017-02-25 21:03:52
# 文/刘鹏继处罚前海人寿之后仅仅一天，另一只靴子落地。2017年2月25日晚间，保监会连发三文，对去年多次短炒股票的恒大人寿，以及两位责任人，进行了处罚。保监会的处罚决定书显示，对于恒大人寿的处罚为:限制股票投资一年，并调整权益类资产比例为20%。而对于时任恒大人寿董事会秘书、副总经理刘浩，时任恒大人寿投资管理
#
#
#
#
# 巴菲特2017年致股东信10大看点
# 2017-02-25 22:13:27
# 腾讯证券讯北京时间2月25日晚间消息，巴菲特（WarrenBuffett）旗下的伯克希尔·哈撒韦公司（BerkshireHathaway）周六发布了致股东信。该公司一年一度的股东信，不仅只有伯克希尔·哈撒韦自身的股东倍加关注，同时整个投资界也为之侧目，人人都想要了解巴菲特这位全球排名第三的亿万富翁投资者的想法。以下为伯克希尔·哈撒
#
#
#
#
# 任正非的小目标：三年内服务赶苹果 利润率追OV
# 2017-02-25 22:28:53
# 任正非：“灭了三星，灭了苹果”之类的话，无论公开场合，还是私下场合，一次都不能讲。谁讲一次就罚100元。相比于余承东“三年超越苹果、五年超越三星”的表态，任正非近日为华为终端提出的目标更为细致和实际一些。在华为“心声社区”的微信公众号2月25日晚间发出的一篇名为《任总在消费者BG年度大会上的讲话》中，任正
#
#
#
#
# 三星“太子”李在镕：一个西式韩国商人的困兽之斗
# 2017-02-25 19:22:06
# 华夏时报记者王晓慧北京报道　　不到一年的时间，连续两次调低费率，这么“任性”的险种只有失业保险。　　官方近日下发通知，从2017年1月1日起，失业保险总费率为1.5%的省(区、市)，可以将总费率降至1%，降低费率的期限执行至2018年4月30日。去年5月1日起，国务院决定失业保险总费率由2%阶段性降至1%-1.5%，其中个人费率
#
#
#
#
# 世界最大火力发电厂落地内蒙古 新机组通过试运行
# 2017-02-25 18:18:06
# 中新社北京2月25日电(记者魏晞)记者25日从总部位于北京的中国大唐集团公司获悉，当天下午内蒙古大唐国际托克托发电有限责任公司五期工程10号机组顺利通过168小时试运行。至此，该公司五期扩建工程两台国产66万千瓦超超临界机组全部投入商业运行，总装机达到672万千瓦，成为世界在役最大火力发电厂。其中，包括8台60万千瓦
#
#
#
#
# 李稻葵：中国在金融方面的科技创新已经超过美国
# 2017-02-25 21:47:59
# 中国与世界经济研究中心主任、著名经济学家李稻葵出席论坛进行演讲。李南轩摄中新网福州2月25日电(林玲)25日，2017首届科技金融国际峰会在厦门开幕。中国与世界经济研究中心主任、著名经济学家李稻葵来到现场，围绕“科技创新时代的中国金融新格局”这一主题进行演讲。他大胆预测，科技与金融的结合会影响未来金融格局，中
#
#
#
#
# 一图看懂保监会对两家险企的处罚为何差别这么大
# 2017-02-25 23:02:01
# 保监会连出重拳！2月24日对前海人寿开出最严监管处罚，对时任前海人寿董事长姚振华给予撤销任职资格并禁入保险业10年的处罚。一时引发业界热议。时隔一天，保监会又对恒大人寿出具处罚书。依法给予该公司限制股票投资一年、两名责任人分别行业禁入五年和三年的行政处罚决定。此外，还对该公司采取下调权益类资产投资比例上
#
#
#
#
# 刘伟履新财政部副部长 曾任职全国人大
# 2017-02-25 12:00:00
# 　　2月25日，财政部官网部长之窗显示，刘伟担任财政部副部长。昨日，第十二届全国人民代表大会常务委员会第二十六次会议，通过免去刘伟的全国人民代表大会常务委员会预算工作委员会副主任职务。　　根据官方公布的简历来看，刘伟是财政系统的“老兵”。　　1961年出生的刘伟，于1978年12月进入四川省重庆市财政局工作，19
#
#
#
#
# 华为与浙江省签战略合作协议 将建全球培训中心
# 2017-02-25 19:28:49
# 2月25日，省委书记、省人大常委会主任夏宝龙会见华为技术有限公司总裁任正非。浙江在线记者梁臻摄（原标题：浙江省与华为公司签订战略合作协议夏宝龙会见合作方代表车俊见证签约）25日上午，浙江省与华为技术有限公司在杭签署战略合作协议。签约前，省委书记、省人大常委会主任夏宝龙，省委副书记、省长车俊分别会见了华为
#
#
#
#
# 姚振华遭禁业10年 前海人寿股权无需处置
# 2017-02-25 07:52:47
# 文/刘鹏在保监会屡屡发声要求“保险姓保，保监会姓监”，并派驻检查组入驻前海人寿两个半月后，保监会对前海人寿及其董事长姚振华等人，下发了堪称保险业“顶格处罚”的决定书。2月24日，腾讯财经从保监会获悉，这份决定书历数前海人寿与姚振华两大罪名，因此对前海人寿处以80万元罚款，对姚振华给予撤销任职资格并禁入保
#
#
#
#
# 巴菲特告诉你为什么资本都偏爱保险业
# 2017-02-25 16:54:18
#
#
#
#
#
# 政府工作报告开始审议 经济增长或仍保持稳定
# 2017-02-25 07:32:09
#
#
#
#
#
#
#                             加载更多
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		其他模块
#
# 			直播台
# 			自动播放
#
#
#
#
#
#
#
#
# 				进入直播台
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     精华推荐
#
#
#
# 郭树清：不能创新是中国经济和金融的最大风险
#
#
#                             第325期：刚需购房人何时买房最合适？
#
# 生育险和医保合并的这6件事你要知道
#
#
#
#
#
# 	 张宗子：天涯风雪林教头
#
#
#
#
#
#
#
#                     money问吧
#
#
#
#
#
#
#
#
#             不懂法律知识你的钱就危险了，关于财经法律可以问我！
#             我要提问
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     财经图库
#
#
#
# 你家有这种“十块钱”吗？最贵的一张竟值15万
#
#
# 同是葡萄酿造 香槟如何成为了庆典必备
# 比尔盖茨：我与巴菲特不得不说的故事和367亿美元账单
# 第114期：越南武器进口量跃居全球第10 中国系第三大军售国
#
#
#
#
#
#
#
#
#
#
#
#
# 		腾讯理财超市
# 		更多
#
#
#
#
# 				领先CTA收益稳健
# 				同类产品年涨 27%
# 				主打私募  预约
#
#
# 				买黄金基金避险
# 				今年以来收益 13%
# 				9月策略  购买
#
#
# 				国企改革受益基金
# 				近1月涨 7.41%
# 				优质基金  购买
#
#
# 				储蓄罐活期
# 				7日年化收益 2.97%
# 				收益超余额宝  购买
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     热门视频
#
#                         “尔康”身价上亿是真的？一年“赌约”到期日本大开赌场吸引外国游客“一线人物”专访王小川：
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     在线购车
#
#
#
#
#     	在线购车
#
#
#
#
#
#
#
#                 	别克全系试驾送礼品
#                 	10000步换试驾好礼兑换
#
#
#
#
#
#
#
#                 	雪铁龙C6 10月17日上市
#                 	预订享1万置换补贴抢购
#
#
#
#
#
#
#
#
#                 	幻速H2直降1万元
#                 	北汽SUV低至5万抢购
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 财经要闻
# 北京学区房争夺季又启：25万1平仍抢手保监会处罚恒大人寿 限制股票投资一年三星太子李在镕：一个西式韩国商人的困兽之斗千亿失业金花不掉：失业率高人群多数未参保尚福林的38年金融监管之路（附语录）任正非：30多岁不努力光想躺在床上数钱可能吗世界最大火力发电厂落地内蒙古 机组通过试运行
#
#
#
#
#
#
#              	返回首页
#                 用户反馈
#
#
#
# 	为你推荐
# 	返回顶部
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		关于腾讯 | About Tencent | 服务协议 | 隐私政策 | 开放平台 | 广告服务 | 腾讯招聘 | 腾讯公益 | 客服中心 | 举报中心 | 网站导航
#
#   	Copyright © 1998 - 2017 Tencent. All Rights Reserved
#
# 		腾讯公司 版权所有
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Xname查看详情
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
soup = BeautifulSoup(browser.page_source)
[s.extract() for s in soup(['style', 'script', '[document]', 'head', 'title'])]
visible_text = soup.getText()   
print visible_text
# Out:
# 无障碍说明
#
#
#
#
# 首页
# 新闻
#
# 体育
# 娱乐
# 视频
# 财经
# 证券
# 汽车
# 房产
# 科技
# 数码
# 游戏
# 教育
# 时尚
# 文化
#
# 	更多
#
# 			动漫
# 			读书
# 			儿童
# 			星座
# 			精品课
# 			全部频道
#
#
#
#
#
#
#
#
#
#
# 			一键登录
#
#
# 			微博
#
#
# 			Qzone
#
#
# 			QQ邮箱
#
#
#
# 			收藏
#
#
#
#
#
#
#
#
#
#
#
# 	浏览器更新提醒立即更新×
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     证券
#                     港股
#                     美股
#                     宏观
#                     国际
#                     金融
#                     公司
#                     消费
#                     理财
#                     财经资讯
#
#
#
#
#
#
#
#
#
# 								搜狗
#
#
#
#
#
#
#
#
#
#
#
#
# 徽文化沙龙 解密徽商之道
#
#
# 综合新闻深圳新闻网-深圳商报2016-09-28 06:24
#
#
#
# 	分享
#
#
# 	腾讯微博
# 	QQ空间
# 	QQ好友
# 	新浪微博
#
# 		微信好友
#
#
# 	领英分享
#
#
#
#
#
#
#
#
# 　　深圳商报讯 （记者 陈广琳）由深圳市社科联主办、深圳市徽文化研究会承办的第二期徽文化沙龙日前在福田区图书馆举行，安徽大学徽学研究中心主任、中国著名徽学专家、深圳市徽文化研究会首席学术顾问卞利，应邀在沙龙上演讲题为《传统徽商的经营管理的成功之道及其现代启示》，沙龙主讲嘉宾、深圳市海天出版社副总编辑于志斌做了专题演讲，深圳市徽文化研究会秘书长郁海雷主持沙龙。
# 　　卞利从10个方面阐述了传统徽商的成功秘籍，为现代商帮、商业的发展提供了有益启示和借鉴。解析了传统徽商的成功之道后，卞利还揭示了徽商的现代价值。他认为，徽州经济文化领域越来越受到学术界的关注，徽商始终是一个凝重的话题。徽商数百年的经营活动，给我们留下了丰厚的遗产。卞利说，徽商正是凭着他们特有的徽商精神，从而能够从无到有，从小到大，乃至于发展为雄视天下的大商帮。这种精神植根于中国传统文化的土壤之中，又被徽商进一步发扬光大。“徽骆驼” 和“绩溪牛”所造就的徽商精神，不仅是徽商的巨大财富，更是徽商留给后人的宝贵遗产。
# 　　（陈广琳）
#
# 正文已结束，您可以按alt+4进行评论
#
#
#
#
#
#
#
#
#
#
#
#
# 		分享到:
#
# 												腾讯微博
# 	QQ空间
# 	QQ好友
# 	新浪微博
# 	二维码
# 	领英分享
#
#
#
#
#
#
# 				扫一扫，用手机看新闻！
# 				用微信扫描还可以
# 				分享至好友和朋友圈
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	相关搜索
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             为你推荐
#
#
#
#
# 恒大人寿被罚禁投股票一年 公司回应
# 2017-02-25 21:03:52
# 文/刘鹏继处罚前海人寿之后仅仅一天，另一只靴子落地。2017年2月25日晚间，保监会连发三文，对去年多次短炒股票的恒大人寿，以及两位责任人，进行了处罚。保监会的处罚决定书显示，对于恒大人寿的处罚为:限制股票投资一年，并调整权益类资产比例为20%。而对于时任恒大人寿董事会秘书、副总经理刘浩，时任恒大人寿投资管理
#
#
#
#
# 巴菲特2017年致股东信10大看点
# 2017-02-25 22:13:27
# 腾讯证券讯北京时间2月25日晚间消息，巴菲特（WarrenBuffett）旗下的伯克希尔·哈撒韦公司（BerkshireHathaway）周六发布了致股东信。该公司一年一度的股东信，不仅只有伯克希尔·哈撒韦自身的股东倍加关注，同时整个投资界也为之侧目，人人都想要了解巴菲特这位全球排名第三的亿万富翁投资者的想法。以下为伯克希尔·哈撒
#
#
#
#
# 任正非的小目标：三年内服务赶苹果 利润率追OV
# 原标题：缅甸工人罢工还打砸抢，中资服装厂过去两个半月经历了什么一家位于缅甸仰光兰达亚工业区的中资服装厂23日遭遇数百名缅籍罢工工人及外来人员打砸破坏，7名中国籍员工在厂内被困9小时才获准离开。企业负责人说，该厂已经被占据近一个月，迄今仍被罢工者控制。中国驻缅甸大使馆24日通报，在中国驻缅甸大使馆工作组和
#
#
#
#
# 千亿失业金花不掉背后：失业率高人群多数未参保
# 2017-02-25 16:30:20
# 华夏时报记者王晓慧北京报道　　不到一年的时间，连续两次调低费率，这么“任性”的险种只有失业保险。　　官方近日下发通知，从2017年1月1日起，失业保险总费率为1.5%的省(区、市)，可以将总费率降至1%，降低费率的期限执行至2018年4月30日。去年5月1日起，国务院决定失业保险总费率由2%阶段性降至1%-1.5%，其中个人费率
#
#
#
#
# 世界最大火力发电厂落地内蒙古 新机组通过试运行
# 2017-02-25 18:18:06
# 中新社北京2月25日电(记者魏晞)记者25日从总部位于北京的中国大唐集团公司获悉，当天下午内蒙古大唐国际托克托发电有限责任公司五期工程10号机组顺利通过168小时试运行。至此，该公司五期扩建工程两台国产66万千瓦超超临界机组全部投入商业运行，总装机达到672万千瓦，成为世界在役最大火力发电厂。其中，包括8台60万千瓦
#
#
#
#
# 李稻葵：中国在金融方面的科技创新已经超过美国
# 2017-02-25 21:47:59
# 中国与世界经济研究中心主任、著名经济学家李稻葵出席论坛进行演讲。李南轩摄中新网福州2月25日电(林玲)25日，2017首届科技金融国际峰会在厦门开幕。中国与世界经济研究中心主任、著名经济学家李稻葵来到现场，围绕“科技创新时代的中国金融新格局”这一主题进行演讲。他大胆预测，科技与金融的结合会影响未来金融格局，中
#
#
#
#
# 一图看懂保监会对两家险企的处罚为何差别这么大
# 2017-02-25 23:02:01
# 保监会连出重拳！2月24日对前海人寿开出最严监管处罚，对时任前海人寿董事长姚振华给予撤销任职资格并禁入保险业10年的处罚。一时引发业界热议。时隔一天，保监会又对恒大人寿出具处罚书。依法给予该公司限制股票投资一年、两名责任人分别行业禁入五年和三年的行政处罚决定。此外，还对该公司采取下调权益类资产投资比例上
#
#
#
#
# 刘伟履新财政部副部长 曾任职全国人大
# 2017-02-25 12:00:00
# 　　2月25日，财政部官网部长之窗显示，刘伟担任财政部副部长。昨日，第十二届全国人民代表大会常务委员会第二十六次会议，通过免去刘伟的全国人民代表大会常务委员会预算工作委员会副主任职务。　　根据官方公布的简历来看，刘伟是财政系统的“老兵”。　　1961年出生的刘伟，于1978年12月进入四川省重庆市财政局工作，19
#
#
#
#
# 华为与浙江省签战略合作协议 将建全球培训中心
# 2017-02-25 19:28:49
# 2月25日，省委书记、省人大常委会主任夏宝龙会见华为技术有限公司总裁任正非。浙江在线记者梁臻摄（原标题：浙江省与华为公司签订战略合作协议夏宝龙会见合作方代表车俊见证签约）25日上午，浙江省与华为技术有限公司在杭签署战略合作协议。签约前，省委书记、省人大常委会主任夏宝龙，省委副书记、省长车俊分别会见了华为
#
#
#
#
# 姚振华遭禁业10年 前海人寿股权无需处置
# 2017-02-25 07:52:47
# 文/刘鹏在保监会屡屡发声要求“保险姓保，保监会姓监”，并派驻检查组入驻前海人寿两个半月后，保监会对前海人寿及其董事长姚振华等人，下发了堪称保险业“顶格处罚”的决定书。2月24日，腾讯财经从保监会获悉，这份决定书历数前海人寿与姚振华两大罪名，因此对前海人寿处以80万元罚款，对姚振华给予撤销任职资格并禁入保
#
#
#
#
# 巴菲特告诉你为什么资本都偏爱保险业
# 2017-02-25 16:54:18
#
#
#
#
#
# 政府工作报告开始审议 经济增长或仍保持稳定
# 2017-02-25 07:32:09
#
#
#
#
#
#
#                             加载更多
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		其他模块
#
# 			直播台
# 			自动播放
#
#
#
#
#
#
#
#
# 				进入直播台
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     精华推荐
#
#
#
# 郭树清：不能创新是中国经济和金融的最大风险
#
#
#                             第325期：刚需购房人何时买房最合适？
#
# 生育险和医保合并的这6件事你要知道
#
#
#
#
#
# 	 张宗子：天涯风雪林教头
#
#
#
#
#
#
#
#                     money问吧
#
#
#
#
#
#
#
#
#             不懂法律知识你的钱就危险了，关于财经法律可以问我！
#             我要提问
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     财经图库
#
#
#
# 你家有这种“十块钱”吗？最贵的一张竟值15万
#
#
# 同是葡萄酿造 香槟如何成为了庆典必备
# 比尔盖茨：我与巴菲特不得不说的故事和367亿美元账单
# 第114期：越南武器进口量跃居全球第10 中国系第三大军售国
#
#
#
#
#
#
#
#
#
#
#
#
# 		腾讯理财超市
# 		更多
#
#
#
#
# 				领先CTA收益稳健
# 				同类产品年涨 27%
# 				主打私募  预约
#
#
# 				买黄金基金避险
# 				今年以来收益 13%
# 				9月策略  购买
#
#
# 				国企改革受益基金
# 				近1月涨 7.41%
# 				优质基金  购买
#
#
# 				储蓄罐活期
# 				7日年化收益 2.97%
# 				收益超余额宝  购买
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     热门视频
#
#                         “尔康”身价上亿是真的？一年“赌约”到期日本大开赌场吸引外国游客“一线人物”专访王小川：
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     在线购车
#
#
#
#
#     	在线购车
#
#
#
#
#
#
#
#                 	别克全系试驾送礼品
#                 	10000步换试驾好礼兑换
#
#
#
#
#
#
#
#                 	雪铁龙C6 10月17日上市
#                 	预订享1万置换补贴抢购
#
#
#
#
#
#
#
#
#                 	幻速H2直降1万元
#                 	北汽SUV低至5万抢购
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 财经要闻
# 北京学区房争夺季又启：25万1平仍抢手保监会处罚恒大人寿 限制股票投资一年三星太子李在镕：一个西式韩国商人的困兽之斗千亿失业金花不掉：失业率高人群多数未参保尚福林的38年金融监管之路（附语录）任正非：30多岁不努力光想躺在床上数钱可能吗世界最大火力发电厂落地内蒙古 机组通过试运行
#
#
#
#
#
#
#              	返回首页
#                 用户反馈
#
#
#
# 	为你推荐
# 	返回顶部
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		关于腾讯 | About Tencent | 服务协议 | 隐私政策 | 开放平台 | 广告服务 | 腾讯招聘 | 腾讯公益 | 客服中心 | 举报中心 | 网站导航
#
#   	Copyright © 1998 - 2017 Tencent. All Rights Reserved
#
# 		腾讯公司 版权所有
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Xname查看详情
