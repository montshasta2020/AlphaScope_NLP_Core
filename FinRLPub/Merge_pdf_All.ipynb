# %%
import os
import glob
import re
import shutil

from PyPDF2 import PdfReader

# %%
root_dir = '../References_Deep_Learning_For_Finance/000 more references/'

# %%
def found_references_tag(fn):
    reader = PdfReader(fn)
    
    text = ""
    
    for page in reader.pages:
        text += page.extract_text() + "\n"
    
    sen = text.split('\n')

    for s in sen:

        if 'References' in s or 'REFERENCES' in s:
            #print(s)            
            return True
        elif 'Bibliography' in s or 'BIBLIOGRAPHY' in s:
            return True
    
    return False

# %%
fn = './all_papers/A Survey on Machine Learning for Stock Price Prediction: Algorithms and Techniques .pdf'
get_all_text(fn)
# Out:
# Methods Data Purpose Method Advantages Disadvantages References
# Methods Data Purpose Method Advantages Disadvantages References
# Methods Data Purpose Method Advantages Disadvantages References
# REFERENCES

# %%
len(txt)
# Out:
# 51432

# %%
all_folders = [x[0] for x in os.walk(root_dir)]

# %%
from PyPDF2 import PdfReader

def get_all_text(fn)
    text = ""

    for page in reader.pages:
        text += page.extract_text() + "\n"
    
    sen = text.split('\n')

    for s in sen:

        if 'Github' in s:
            print(s)
        elif 'GitHub' in s:
            print(s)
        elif 'github' in s:
            print (s)

# %%
cnt = 0

skipped = ['all_collections/Fuzzy Based Modified SHL algorithm for Spiking Neural  Network.pdf']

for f in all_folders:
#    print (cnt, f)
    if 'Books' in f: #igore books for now
        continue
        
    if f in skipped:
        continue
        
    else:                
        files = f + '/*.pdf'
        for fn in glob.glob(files):            
            if re.search(u'[\u4e00-\u9fff]', fn): #check if it contains unicodes
                continue
            print (cnt, fn)
            ss = fn.split('/')
            dst= './all_collections_all/' + ss[-1]
            shutil.copyfile(fn, dst)
            cnt += 1
# Out:
# 0 ../References_Deep_Learning_For_Finance/000 more references/Financial Data Analysis - Estimize/thru_earnings_ws_estimize_delta_event_study.pdf
# 1 ../References_Deep_Learning_For_Finance/000 more references/Financial Data Analysis - Estimize/post_earnings_event_study.pdf
# 2 ../References_Deep_Learning_For_Finance/000 more references/Financial Data Analysis - Estimize/Estimize+Sales+Deck+October+2019.pdf
# 3 ../References_Deep_Learning_For_Finance/000 more references/Financial Data Analysis - Estimize/estimize_post_earnings_signal_strategy.pdf
# 4 ../References_Deep_Learning_For_Finance/000 more references/Financial Data Analysis - Estimize/estimize_signal_strategy.pdf
# 5 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/pdfcoffee.com_literature-review-on-data-normalization-and-clustering.pdf
# 6 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Adaptive Normalization: A Novel Data Normalization Approach for Non-Stationary Time Series .pdf
# 7 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/A Comparision of normalization techniques.pdf
# 8 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Feature Scaling _ Standardization Vs Normalization.pdf
# 9 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Normalization Techniques in Training DNNs: Methodology, Analysis and Application.pdf
# 10 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Modeling of Extreme Values via Exponential Normalization Compared with Linear and Power Normalization.pdf
# 11 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Neural Bag-of-Features Learning.pdf
# 12 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/a-review-on-data-normalization-techniques.pdf
# 13 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Normalization: A Preprocessing Stage.pdf
# 14 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/REVERSIBLE INSTANCE NORMALIZATION FOR ACCURATE TIME-SERIES FORECASTING AGAINST DISTRIBUTION SHIFT.pdf
# 15 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Normalization_methods_in_time_series_of_platelet.39.pdf
# 16 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/00b - Forecasting-Financial-Time-Series-using-Robust-Deep-Adaptive-Input-Normalization.pdf
# 17 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Self-normalization for Time Series: A Review of Recent Developments.pdf
# 18 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/The Effect of the Normalization Method Used in Different Sample Sizes on.pdf
# 19 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Time Series Data Prediction Using Sliding Window Based RBF Neural Network.pdf
# 20 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/00a - Deep Adaptive Input Normalization for Time Series Forecasting.pdf
# 21 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/A Study on Normalization Techniques for Privacy Preserving Data Mining .pdf
# 22 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Price-Trailing-for-Financial-Trading-using-Deep-Reinforcement-Learning-Transactions-on-Neural-Networks-and-Learning-Systems - 2019.pdf
# 23 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Comparison of Min-Max normalization and Z-Score Normalization in the K-nearest neighbor (kNN) Algorithm to Test the Accuracy of Types of Breast Cancer.pdf
# 24 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Temporal Logistic Neural Bag-of-Features for Financial Time.pdf
# 25 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Effects of Time Normalization on the Accuracy of the Success of Artificial Neural Network Model.pdf
# 26 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/002 - Bilinear Input Normalization for Neural Networks.pdf
# 27 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Data Normalization and Standardization A Technical Report.pdf
# 28 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Deep Adaptive Input Normalization for Time Series Forecasting.pdf
# 29 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/ST_Norm__Spatial_and_Temporal_Normalization_for_Multi_variate_Time_Series_Forecasting_camera ready version.pdf
# 30 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/A Sliding Window Filter for Time Series Streams.pdf
# 31 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Instance Normalization: The Missing Ingredient for Fast Stylization.pdf
# 32 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Adaptive Normalization in Streaming Data.pdf
# 33 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Impact_of_Data_Normalization_on_Stock_Index_Forecasting.pdf
# 34 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/00c -- Global Adaptive Input Normalization for Short-Term Electric Load Forecasting.pdf
# 35 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Using Deep Learning for price prediction by exploiting stationary limit order book features.pdf
# 36 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/A Reversible Automatic Selection Normalization (RASN) Deep Network for Predicting in the Smart Agriculture System.pdf
# 37 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/001 - Arbitrary Style Transfer in Real-time with Adaptive Instance Normalization.pdf
# 38 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Effect of Normalization Techniques on Univariate Time Series Forecasting using Evolutionary Higher Order Neural Network.pdf
# 39 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/High Performance Data Mining in Time Series: Techniques and Case Studies.pdf
# 40 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Adaptive sliding windows for improved estimation of data center resource utilization.pdf
# 41 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Effects of Time Normalization on the Accuracy of Dynamic Time Warping.pdf
# 42 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/New Interpretations of Normalization Methods in Deep Learning.pdf
# 43 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/Impact of Data Normalization on Deep Neural Network for Time Series Forecasting.pdf
# 44 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/000 - Using Deep Learning to Detect Price Change Indications in Financial Markets.pdf
# 45 ../References_Deep_Learning_For_Finance/000 more references/Time Series Normalization/normalize-time-series-and-forecast-using-evolutionary-neural-network.pdf
# 46 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/The Likelihood of Various Stock Market Return Distributions, Part 1: Principles of Inference.pdf
# 47 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/THE DISTRIBUTION OF STOCK MARKET RETURNS AND RETURNS OF SOUTHEAST EUROPEAN EMERGING MARKETS.pdf
# 48 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/The Empirical Distribution of UK and US Stock Returns.pdf
# 49 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/Time-varying volatility and the power law distribution of stock returns.pdf
# 50 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/THE DISTRIBUTION OF RETURNS OF STOCK PRICES.pdf
# 51 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/Predicting the Distribution of Stock Returns: Model Formulation, Statistical Evaluation, VaR Analysis and Economic Significance.pdf
# 52 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/The Likelihood of Various Stock Market Return Distributions, Part 2: Empirical Results.pdf
# 53 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/EMPIRICAL DISTRIBUTION OF STOCK .pdf
# 54 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/NONLINEAR DYNAMICS AND THE DISTRIBUTION OF DAILY STOCK INDEX RETURNS.pdf
# 55 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/THE DISTRIBUTION OF STOCK MARKET RETURNS AND THE MARKET MODEL*.pdf
# 56 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/Against the Norm: Modeling Daily Stock.pdf
# 57 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/The Distribution of Returns.pdf
# 58 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/The Distribution of Stock Returns: New Evidence Against the Stable Model.pdf
# 59 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/The distribution of stock market returns Returns with the Laplace Distribution.pdf
# 60 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/The Distribution of Stock Returns.pdf
# 61 ../References_Deep_Learning_For_Finance/000 more references/Returns of Distribution/The Distribution of Stock Return Volatility.pdf
# 62 ../References_Deep_Learning_For_Finance/000 more references/Heustrics and Finance/Using genetic algorithms to find technical trading rules.pdf
# 63 ../References_Deep_Learning_For_Finance/000 more references/Heustrics and Finance/Genetic algorithm evolved agent-based equity trading using Technical Analysis and the Capital Asset Pricing Model.pdf
# 64 ../References_Deep_Learning_For_Finance/000 more references/Heustrics and Finance/Computational Intelligence for Evolving Trading Rules.pdf
# 65 ../References_Deep_Learning_For_Finance/000 more references/Heustrics and Finance/Co-evolved Genetic Program for Stock Market Trading.pdf
# 66 ../References_Deep_Learning_For_Finance/000 more references/To do/A Python Package for Optimal Mean Reversion Trading _ by Tim Leung, Ph.D. _ Quantitative Investing _ Medium.pdf
# 67 ../References_Deep_Learning_For_Finance/000 more references/To do/4 Ways to Predict Market Performance.pdf
# 68 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/SURVEY ON STOCK MARKET PRICE PREDICTION VIA DEEP NEURAL  NETWORKS.pdf
# 69 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/Stock Trend Prediction Using Candlestick Charting and Ensemble Machine Learning T Machine Learning Techniques with a No echniques with a Novelty Feature Engineering e Engineering Scheme .pdf
# 70 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/A REVIEW OF STOCK TREND PREDICTION WITH COMBINATION OF EFFECTIVE MULTI TECHNICAL INDICATOR STRATEGY.pdf
# 71 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/Stock Trend Prediction: Based on Machine Learning Methods.pdf
# 72 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/Forecasting the Stock Market Index Using Artificial Intelligence Techniques .pdf
# 73 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/A Survey on different datasets employed during stock market prediction.pdf
# 74 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/REVIEW OF STOCK PREDICTION USING MACHINE LEARNING TECHNIQUES.pdf
# 75 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/A Comparison of Stock Trend Prediction Using Accuracy Driven Neural Network Variants.pdf
# 76 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/Multi-scale Two-way Deep Neural Network for Stock Trend Prediction.pdf
# 77 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/A Survey on Machine Learning for Stock Price Prediction: Algorithms and Techniques .pdf
# 78 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/Forecasting a Stock Trend Using Genetic Algorithm and Random Forest.pdf
# 79 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/Determinants of Stock Market Development: A Review of the Literature .pdf
# 80 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/Impact of chart image characteristics on stock price prediction with a convolutional neural network.pdf
# 81 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/A Survey on Stock Market Prediction.pdf
# 82 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/deep-learning-for-the-prediction-of-stockmarket-trends.pdf
# 83 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/Recent Advances in Stock Market Prediction Using Text Mining: A Survey.pdf
# 84 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/Artificial Counselor System for Stock Investment.pdf
# 85 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/Systematic Literature Review: Stock Price Prediction Using Machine Learning and Deep  Learning.pdf
# 86 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/Applications of ANNs in Stock Market Prediction: A Survey  .pdf
# 87 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/Short‑term stock market price trend prediction using a comprehensive deep learning system.pdf
# 88 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/A_Survey_on_Stock_Market_Price_Predictio.pdf
# 89 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/A Survey of Forex and Stock Price Prediction Using Deep Learning.pdf
# 90 ../References_Deep_Learning_For_Finance/000 more references/Trend_Predictions/Stock Trend Prediction Algorithm Based on Deep Recurrent Neural Network .pdf
# 91 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock Prices Prediction using Deep Learning Models.pdf
# 92 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Automated Trading System - A Survey.pdf
# 93 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Predicting stock prices using deep learning | by Yacoub Ahmed | Towards Data Science.pdf
# 94 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Using the latest advancements in deep learning to predict stock price movements | by Boris B | Towards Data Science.pdf
# 95 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Agent Inspired Trading Using Recurrent Reinforcement Learning and LSTM Neural Networks.pdf
# 96 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Temporal Relational Ranking for Stock Prediction.pdf
# 97 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock Price Pattern Prediction Based on Complex Network and Machine Learning.pdf
# 98 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/A Review of Artificial Intelligence in Investment.pdf
# 99 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Evaluation and potential improvements of a deep reinforcement learning model for automated stock trading.pdf
# 100 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/A Customer Churn Prediction Model Based on XGBoost and MLP.pdf
# 101 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Reinforcement Learning in Trading.pdf
# 102 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Opinion: Machine learning won’t crack the stock market— but here’s when investors should trust AI.pdf
# 103 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Purified sentiment indicators for the stock market5.04.09.pdf
# 104 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock selection with random forest: An exploitation of excess return in the Chinese stock market.pdf
# 105 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Thresholded-ConvNet-Ensembles-Neural-Networks-for-Technical-Forecasting.pdf
# 106 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Using Structured Events to Predict Stock Price Movement: An Empirical Investigation.pdf
# 107 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock market prediction - Wikipedia.pdf
# 108 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/MACHINE LEARNING IN QUANTITATIVE FINANCE.pdf
# 109 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/*** Predicting Stock Market Trends Using Machine Learning and Deep Learning Algorithms Via Continuous and Binary Data a Comparative Analysis.pdf
# 110 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock market as temporal network.pdf
# 111 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Market_Forecasting_Using_Deep_Learning_and_Technical_Analysis_A_Systematic_Review.pdf
# 112 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Predicting Short-Term Stock Movements with Quantitative Finance and Machine Learning in Python | by Mat Steininger | Towards Data Science.pdf
# 113 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Predicting Financial Markets using Text on the Web.pdf
# 114 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Machine Learning for Financial Market Prediction.pdf
# 115 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock Trend Prediction- Based on Machine Learning Methods.pdf
# 116 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Using the latest advancements in deep learning to predict stock price movements _ by Boris B _ Towards Data Science.pdf
# 117 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/The applications of artificial neural networks, support vector machines, and long–short term memory for stock market prediction.pdf
# 118 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock Price Prediction Based on Deep Learning | by Abhijit Roy | Towards Data Science.pdf
# 119 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Deep Neuro‑Fuzzy System application trends, challenges,  and future perspectives: a systematic survey.pdf
# 120 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/2018-Machine Learning Approaches to Macroeconomic Forecasting.pdf
# 121 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Investable and Interpretable Machine Learning for Equities.pdf
# 122 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Automated_Stock_Market_Trading_System_Parth_Shah.pdf
# 123 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Predicting Stock Market Returns with Machine Learning.pdf
# 124 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Forecasting East Asian Indices Futures via a Novel Hybrid of Wavelet-PCA Denoising and Artificial Neural Network Models.pdf
# 125 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Frontiers _ QF-TraderNet_ Intraday Trading via Deep Reinforcement With Quantum Price Levels Based Profit-And-Loss Control _ Artificial Intelligence.pdf
# 126 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/000 DeepLOB: Deep Convolutional Neural Networks .pdf
# 127 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock Market Trend Prediction using Supervised Machine Learning Algorithms.pdf
# 128 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Implementation of Artificial Intelligence and Machine learning in Financial services.pdf
# 129 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Predicting Trend of Stock Prices by Developing Data Mining Techniques with the Aim of Gaining Profit.pdf
# 130 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Deep Reinforcement Learning for Trading.pdf
# 131 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock Trend Prediction Using Deep Learning Approach on Technical Indicator and Industrial Specific Information.pdf
# 132 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Financial Time Series Forecasting with Deep Learning – The Data Exchange.pdf
# 133 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Selection of the optimal trading model for stock investment in different industries.pdf
# 134 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Generative Adversarial Networks for Stock Market prediction Report.pdf
# 135 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Intro-to-Machine-Learning-techniques-used-in-the-financial-industry-and-a-case-study-V1.pdf
# 136 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/A Robust Regression-Based Stock Exchange Forecasting and Determination of Correlation between Stock Markets.pdf
# 137 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Development of Artificial Intelligence and Effects on Financial System.pdf
# 138 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Impact of chart image characteristics on stock price prediction with a convolutional neural network.pdf
# 139 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Paper_106-Predicting_Stock_Closing_Prices_in_Emerging_Markets.pdf
# 140 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Machine Learning Methods in Finance Recent Applications and Prospects.pdf
# 141 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Machine learning approaches for financial time series forecasting.pdf
# 142 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Comparison of Stock Price Prediction Models using Pre-trained Neural Networks.pdf
# 143 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/CRAN Task View_ Machine Learning & Statistical Learning.pdf
# 144 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/COSMOS trader - Chaotic Neuro-oscillatory multiagent financial prediction and trading system.pdf
# 145 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Artificial intelligence and machine learning in financial services.pdf
# 146 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/A TSK type fuzzy rule based system for stock price prediction.pdf
# 147 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Predicting Stock Market.pdf
# 148 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Machine Learning for Trading - What Does it Really Look Like_.pdf
# 149 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Latent Segmentation of Stock Trading Strategies Using Multi-Modal Imitation Learning.pdf
# 150 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Artificial Intelligence Innovation in Financial Services.pdf
# 151 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Arti!cial Intelligence in Finance.pdf
# 152 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock Market Prediction Using Machine Learning Algorithms.pdf
# 153 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Artificial-intelligence-machine-learning-big-data-in-finance.pdf
# 154 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Machine Learning for Trading_ Part 2 - Robot Wealth.pdf
# 155 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Prediction Models for Indian Stock Market.pdf
# 156 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview of Machine Learning in Finance Applications.pdf
# 157 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/_ DB-201409-Seven_Sins_of_Quantitative_Investing.pdf
# 158 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Predicting stock and stock price index movement using Trend Deterministic Data Preparation and machine learning techniques.pdf
# 159 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Machine Learning Classification and Regression Models for Predicting Directional Changes Trend Reversal in FX Markets.pdf
# 160 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Generative Adversarial Networks for Stock Market prediction Summary.pdf
# 161 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Monte-Carlo Evaluation of Trading Systems.pdf
# 162 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Short-term stock market price trend prediction using a comprehensive deep learning system | Journal of Big Data | Full Text.pdf
# 163 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/AI Pioneers in Investment Management.pdf
# 164 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock returns, quantile autocorrelation, and volatility forecasting.pdf
# 165 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock Market Prediction using Novel Deep Learning Approaches: A Review .pdf
# 166 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Machine Learning for Market Microstructure and High Frequency Trading .pdf
# 167 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Action-specialized expert ensemble trading system with extended discrete action space using deep reinforcement learning.pdf
# 168 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock Prediction Overview and a Simple LSTM based Prediction Model.pdf
# 169 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Deep Learning for Event-Driven Stock Prediction.pdf
# 170 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Machine Learning for Quantitative Finance Applications: A Survey.pdf
# 171 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/s11135-008-9176-9.pdf
# 172 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Forecasting daily conditional volatility and h-step-ahead short and long Value-at-Risk accuracy_ Evidence from financial data.pdf
# 173 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/20 Key Examples Of AI In Finance You Should Know 2022 _ Built In.pdf
# 174 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/A Survey of Forex and Stock Price Prediction Using Deep Learning.pdf
# 175 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Computational Finance.pdf
# 176 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/A Few Useful Things to Know About Machine Learning.pdf
# 177 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Introducing Fuzzy Layers for Deep Learning.pdf
# 178 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/A Survey on Modern Deep Neural Network for Traffic Prediction: Trends, Methods and Challenges.pdf
# 179 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Deep learning for Stock Market Prediction.pdf
# 180 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Automated_Trading/Automated Trading System - A Survey.pdf
# 181 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Automated_Trading/Reinforcement-Learning-For-Automated-Trading.pdf
# 182 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Automated_Trading/Automated trading systems statistical and machine learning methods and hardware implementation: a survey .pdf
# 183 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Automated_Trading/Deep Reinforcement Learning in Quantitative Algorithmic Trading: A Review.pdf
# 184 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Automated_Trading/Algorithmic Trading Using Deep Neural Networks on High Frequency Data.pdf
# 185 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Automated_Trading/A Machine Learning Approach to Automated Trading.pdf
# 186 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Automated_Trading/The future of algo trading_ Using deep learning to more accurately predict equity market volumes - WatersTechnology.com.pdf
# 187 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Automated_Trading/Deep learning in the stock market—a systematic survey.pdf
# 188 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Automated_Trading/An Application of Deep Reinforcement Learning to Algorithmic Trading.pdf
# 189 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Automated_Trading/Survey on the application of deep learning in algorithmic trading.pdf
# 190 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/ML/A SURVEY ON MACHINE LEARNING TECHNIQUES FOR AUTO LABELING OF VIDEO, AUDIO, AND TEXT DATA .pdf
# 191 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Feature Selections/Optimal Feature Selection of Technical Indicator and Stock Prediction Using Machine Learning Technique.pdf
# 192 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Feature Selections/EXTRACTING THE BEST FEATURES FROM MULTI-COMPANY STOCK DATA TO IMPROVE STOCK PRICE PREDICTION.pdf
# 193 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Feature Selections/Integrated_Long-Term_Stock_Selection_Models_Based_on_Feature_Selection_and_Machine_Learning_Algorithms_for_China_Stock_Market.pdf
# 194 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Feature Selections/Feature Selection for Stock Market Analysis.pdf
# 195 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Feature Selections/Feature selection and deep neural networks for stock price direction forecasting using technical analysis indicators .pdf
# 196 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Feature Selections/Stock Prediction Based on Genetic Algorithm Feature Selection and Long Short-Term Memory Neural Network.pdf
# 197 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Feature Selections/Stock price prediction using feature engineering and machine learning Techniques.pdf
# 198 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Feature Selections/Stock Market Trend Prediction Model Using Data Mining Techniques.pdf
# 199 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Feature Selections/Stock Market Prediction Using Data Mining Techniques.pdf
# 200 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Feature Selections/Technical and Fundamental Features’ analysis for Stock Market Prediction with Data Mining Methods .pdf
# 201 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/Financial Data Mining with Genetic Programming.pdf
# 202 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/Applying Data Mining Techniques to Stock Market  Analysis.pdf
# 203 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/A-Hybrid-Approach-To-Evaluate-Stock-Returns-Using-Data-Mining-Techniques.pdf
# 204 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/Stock Portfolio Selection using Data Mining Approach.pdf
# 205 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/A-Review-on-Applied-Data-Mining-Techniques-to-Stock-Market-Prediction.pdf
# 206 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/DATA MINING AND NEURAL NETWORK TECHNIQUES IN STOCK MARKET PREDICTION: A METHODOLOGICAL REVIEW.pdf
# 207 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/Does the use of technical & fundamental analysis improve stock choice? : A data mining approach applied to the Australian stock market.pdf
# 208 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/applications-of-data-mining-in-stock-market.pdf
# 209 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/Insight on Stock Market using Data Mining.pdf
# 210 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/A Review on Data Mining Applications to the Performance of Stock Marketing.pdf
# 211 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/A Review on Data Mining Applications to the .pdf
# 212 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/Using Data Mining to Study Upstream and Downstream Causal Relationship in Stock Market.pdf
# 213 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/Machine learning for stock selection.pdf
# 214 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/EXPLOITING STOCK DATA: A SURVEY OF STATE OF THE ART  COMPUTATIONAL TECHNIQUES AIMED AT PRODUCING BELIEFS REGARDING INVESTMENT PORTFOLIOS  .pdf
# 215 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/Fundamental Analysis and the Cross-Section of Stock Returns: A Data-Mining Approach.pdf
# 216 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/An enabling technique analysis in Data Mining for Stock Market  trend by Approaching Genetic Algorithm.pdf
# 217 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/TURNOVER PREDICTION OF SHARES USING DATA MINING TECHNIQUES: A CASE STUDY.pdf
# 218 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/Analyzing and Predicting Stock Market Using Data Mining Techniques – A Review .pdf
# 219 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Stock_Selections/Data-mining-techniques-and-applications.pdf
# 220 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/a-literature-survey-on-stocks-predictions-using-hybrid-machine-learning-and-deep-learning-models-IJERTV8IS100002.pdf
# 221 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Review 01 -- Reinforcement learning in financial markets - a survey.pdf
# 222 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Survey on Machine Learning for Stcok.pdf
# 223 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/(paper) Transformers in Time Series ; A Survey - AAA (All About AI).pdf
# 224 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Reinforcement learning in financial markets - a survey.pdf
# 225 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Deep Reinforcement Learning For Trading - A Critical Survey.pdf
# 226 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Reinforcement Learning Approaches to Optimal Market Making.pdf
# 227 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Machine Learning Methods in Finance: Recent Applications and Prospects.pdf
# 228 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Recent Advances in Reinforcement Learning in Finance.pdf
# 229 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/An Introduction to Evolutionary Computation in Finance.pdf
# 230 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/REVIEW OF STOCK PREDICTION USING MACHINE LEARNING TECHNIQUES.pdf
# 231 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Stock Market Forecasting Using Deep Learning and Technical Analysis: A Systematic Review.pdf
# 232 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Stock Market Analysis: A Review and Taxonomy of Prediction Techniques.pdf
# 233 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Artificial intelligence techniques in finance and financial markets: A survey of the literature.pdf
# 234 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Artificial_Intelligence_Applied_to_Stock_Market_Trading_A_Review.pdf
# 235 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Deep Learning Networks for Stock Market Analysis and Prediction- Methodology, Data Representations, and Case Studies.pdf
# 236 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Review 03 - Deep Reinforcement Learning For Trading - A Critical Survey.pdf
# 237 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/STOCK MARKET FORECASTING BASED ON  ARTIFICIAL INTELLIGENCE TECHNOLOGY.pdf
# 238 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/REVIEW OF AUTOMATED TIME SERIES FORECASTING PIPELINES.pdf
# 239 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Deep Learning for Financial Applications : A Survey.pdf
# 240 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Machine learning techniques and data for stock market forecasting: A literature review .pdf
# 241 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Machine Learning Approaches in Stock Price Prediction: A Systematic Review.pdf
# 242 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Applications of Genetic Programming to Finance and Economics: Past, Present, Future.pdf
# 243 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Comprehensive Review of Deep Reinforcement Learning Methods and Applications in Economics.pdf
# 244 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Financial_time_series_forecasting_with_machine_learning_techniques.pdf
# 245 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Stock Market Forecasting using Machine Learning Algorithms.pdf
# 246 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Overview of Machine Learning in Finance Applications.pdf
# 247 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Transformers in Time Series: A Survey.pdf
# 248 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/****Stock Price Movement Prediction Based on a Deep Factorization Machine and the Attention Mechanism.pdf
# 249 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/A Survey of Forex and Stock Price Prediction UsingDeep Learning.pdf
# 250 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Stock Prediction Overview and a Simple LSTM based Prediction Model.pdf
# 251 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Forecasting_stock_market_prices.pdf
# 252 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Applications of deep learning in stock market prediction: recent progress.pdf
# 253 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Financial Time Series Forecasting with Deep Learning _ A Systemic Literature Review 2005-2019.pdf
# 254 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Deep Learning Techniques for Stock Market Prediction in the European Union: A Systematic Review.pdf
# 255 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Computational Finance.pdf
# 256 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Reinforcement Learning in Financial Markets.pdf
# 257 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/***Short term stock market price trend prediction using a comprehensive deep learning system.pdf
# 258 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Transformers in Time Series_ A Survey.pdf
# 259 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Overview/Stock Market Prediction Using Machine Learning Techniques: A Decade Survey on Methodologies, Recent Developments, and Future Directions.pdf
# 260 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Stock Market Forecasting Using Computational Intelligence: A Survey.pdf
# 261 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Using_neural_networks_to_forecast_stock_market_price.pdf
# 262 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Applications of artificial neural networks in financial market forecasting - PhD thesis.pdf
# 263 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Text mining approaches for stock market prediction.pdf
# 264 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Stock Market Prediction: A Systematic Review.pdf
# 265 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Surveying stock market forecasting techniques part i: Conventional methods .pdf
# 266 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/A review of stock market prediction with Artificial neural network (ANN).pdf
# 267 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Short-term_stock_market_price_trend_prediction_using a comprehensive deep learning system .pdf
# 268 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Stock Market Analysis: A Review and Taxonomy of Prediction Techniques.pdf
# 269 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Classification-based Financial Markets Prediction using Deep Neural Networks.pdf
# 270 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Genetic algorithms and darwinian approaches in financial applications: A survey.pdf
# 271 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Natural Language Based Financial Forecasting: A Survey.pdf
# 272 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Survey of stock market prediction using machine learning approach.pdf
# 273 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Computational intelligence and financial markets: A survey and future directions.pdf
# 274 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/A Review of Stock Market Prediction Using Neural Network.pdf
# 275 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Machine Learning for Quantitative Finance Applications: A Survey.pdf
# 276 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Stock Market Prediction: A Survey and Evaluation.pdf
# 277 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Evaluation of current research on stock return predictability.pdf
# 278 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Artificial Neural Networks architectures for stock price prediction: comparisons and applications.pdf
# 279 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/A Survey on Stock Market Prediction Using Machine Learning Techniques.pdf
# 280 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Applications of artificial neural networks in financial economics: A Survey.pdf
# 281 ../References_Deep_Learning_For_Finance/000 more references/AI and Finance/Sav/Surveying stock market forecasting techniques Part II: Soft computing methods.pdf
# 282 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/Fuzzy ART: Fast stable learning and categorization of analog patterns by an adaptive resonance system.pdf
# 283 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/A Survey of Adaptive Resonance Theory Neural Network Models for Engineering Applications.pdf
# 284 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/FUZZY, DISTRIBUTED, INSTANCE COUNTING, AND DEFAULT ARTMAP NEURAL NETWORKS FOR FINANCIAL DIAGNOSIS.pdf
# 285 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/CNS Tech Lab.pdf
# 286 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/Optimal Control Using Adaptive Resonance Theory and Q-Learning.pdf
# 287 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/Reinforcement Learning for An ART-B ased Fuzzy Adaptive Learning Control Network .pdf
# 288 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/A GA-based fuzzy adaptive learning control network.pdf
# 289 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/ARTMAP: Supervised real-time learning and classification of nonstationary data by a self-organizing neural network.pdf
# 290 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/Pattern recognition by self-organizing neural networks.pdf
# 291 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/Fuzzy-Embedded Gated Recurrent Unit (FE-GRU) System with Application in Stock Trading.pdf
# 292 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/Default ARTMAP 2.pdf
# 293 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/Fuzzy adaptive resonance theory_ Applications and extensions.pdf
# 294 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/The Adaptive Resonance Theory network : (clustering-)behaviour in relation with Brainstem Auditory Evoked Potential patterns.pdf
# 295 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/Neuroengineering of Clustering Algorithms .pdf
# 296 ../References_Deep_Learning_For_Finance/000 more references/Resonance Theory/Time series prediction using the adaptive resonance theory algorithm ART-2.pdf
# ...
# 1582 ../References_Deep_Learning_For_Finance/000 more references/Image Processing and Finance/LOB and Predictions/An_Attention-Based_LSTM_Model_for_Stock_Price_Trend.pdf
# 1583 ../References_Deep_Learning_For_Finance/000 more references/Image Processing and Finance/LOB and Predictions/Deep Learning for Limit Order Book Trading and Mid-Price Movement Prediction.pdf
# 1584 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Optimizing Multiple Stock Trading Rules using Genetic  Algorithms.pdf
# 1585 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Evolving Trading Strategies With Genetic Programming - Encoding Trading Strategies · Fabian Kostadinov.pdf
# 1586 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Successful Technical Trading Agents Using Genetic Programming.pdf
# 1587 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/STATISTICAL ANALYSIS OF GENETIC ALGORITHMS IN DISCOVERING TECHNICAL TRADING STRATEGIES.pdf
# 1588 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/A novel artificial neural network trained using evolutionary algorithms for reinforcement learning.pdf
# 1589 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/A Comparison of Genotype Representations to Acquire Stock Trading Strategy Using Genetic Algorithms.pdf
# 1590 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Comparison of Genetic Algorithms for Trading Strategies.pdf
# 1591 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Using Genetic Algorithms to Find Technical Trading Rules A Comment on Risk Adjustment.pdf
# 1592 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Relative to ARIMA Models.pdf
# 1593 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Utilizing Articial Neural Networks and Genetic Algorithms.pdf
# 1594 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Evolving Trading Strategies With Genetic Programming - Data · Fabian Kostadinov.pdf
# 1595 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/HEURISTIC BASED TRADING SYSTEM ON FOREX DATA USING TECHNICAL INDICATOR RULES.pdf
# 1596 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Evolving Trading Strategies With Genetic Programming - GP Parameters and Operators · Fabian Kostadinov.pdf
# 1597 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/A Comparative Study of Technical Trading Strategies  Using Genetic Algorithm.pdf
# 1598 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Evolving Trading Strategies With Genetic Programming - Punishing Complexity · Fabian Kostadinov.pdf
# 1599 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/OPTIMIZATION OF TECHNICAL TRADING RULES IN FOREX MARKET USING GENETIC ALGORITHM.pdf
# 1600 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Designing safe, profitable automated stock trading agents using evolutionary algorithms.pdf
# 1601 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Using Genetic Algorithms to Build Trading Strategies _ by Victor Sim _ Towards Data Science.pdf
# 1602 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Evolving Trading Strategies With Genetic Programming - Fitness Functions · Fabian Kostadinov.pdf
# 1603 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Instance Selection Using Genetic Algorithms for an Intelligent Ensemble Trading System .pdf
# 1604 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Computational Learning Techniques for Intraday FX Trading Using Popular Technical Indicators.pdf
# 1605 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/An Exploration of Simple Optimized Technical Trading  Strategies.pdf
# 1606 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/The Application of the Genetic Algorithm in Promoting Stock Trading Performances.pdf
# 1607 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Forecasting financial time series volatility using Particle Swarm Optimization trained Quantile Regression Neural Network.pdf
# 1608 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Comparison of Genetic Algorithm, Particle Swarm Optimization and Biogeography-based Optimization for Feature Selection to Classify Clusters of Microcalcifications.pdf
# 1609 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Comparative Study of FOREX Trading Systems Built with SVR+GHSOM and Genetic Algorithms Optimization of Technical Indicators.pdf
# 1610 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/The applications of genetic algorithms in stock market data mining optimisation .pdf
# 1611 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/A Random Walk Through Stock Market.pdf
# 1612 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Developing High Performing Trading Strategies with Genetic Programming.pdf
# 1613 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/ON INCREASING THE SCOPE OF GENETIC PROGRAMMING TRADING AGENTS.pdf
# 1614 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Generating Long-Term Trading System Rules Using a Genetic Algorithm Based on Analyzing Historical Data.pdf
# 1615 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Financial Data Modeling by Using Asynchronous Parallel Evolutionary Algorithms.pdf
# 1616 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Genetic Algorithm- An Application to Technical Trading System Design.pdf
# 1617 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Genetic-Based Trading Rules - A New Tool to Beat the Market With? - First Empirical Results - .pdf
# 1618 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Evolving Trading Strategies With Genetic Programming - An Overview · Fabian Kostadinov.pdf
# 1619 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/An Effective Approach for Obtaining a Group Trading Strategy Portfolio Using Grouping Genetic Algorithm.pdf
# 1620 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Calibrating an Adaptive Farmer-Joshi Agent-Based Model for Financial Markets.pdf
# 1621 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Using Genetic Algorithms to Find Technical Trading Rules.pdf
# 1622 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Time Series Modeling with Genetic Programming Prediction of Stock Market Index Using Genetic Algorithm .pdf
# 1623 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/Predicting break-points in trading strategies with Twitter .pdf
# 1624 ../References_Deep_Learning_For_Finance/000 more references/Genetic Trading Strategies/The Bio-Inspired Optimization of Trading Strategies and Its Impact on the Efficient Market Hypothesis and Sustainable Development Strategies.pdf
# 1625 ../References_Deep_Learning_For_Finance/000 more references/Misc/A Survey on Policy Search for Robotics.pdf
# 1626 ../References_Deep_Learning_For_Finance/000 more references/Misc/Human-level control through deep reinforcement learning.pdf
# 1627 ../References_Deep_Learning_For_Finance/000 more references/Misc/A comprehensive survey on machine learning for networking.pdf
# 1628 ../References_Deep_Learning_For_Finance/000 more references/Misc/A Survey of Machine Learning Approaches and Techniques for Student Dropout Prediction.pdf
# 1629 ../References_Deep_Learning_For_Finance/000 more references/Misc/Reinforcement Learning in Robotics.pdf
# 1630 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Gated Value Network for Multilabel Classification.pdf
# 1631 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Comparative Study of Stock Trend Prediction using Time Delay Recurrent and Probabilistic Neural Networks.pdf
# 1632 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Hands-On Machine Learning with Scikit-Learn and TensorFlow_ Concepts, Tools, and Techniques to Build Intelligent Systems.pdf
# 1633 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/A FINE-GRAINED ANALYSIS ON DISTRIBUTION SHIFT.pdf
# 1634 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/A Hierarchical Fused Fuzzy Deep Neural Network for Data Classiification.pdf
# 1635 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Wide & Deep Learning for Recommender Systems.pdf
# 1636 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Deep Compressed Sensing.pdf
# 1637 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Logistic discrimination based on G-mean and F-measure for imbalanced problem.pdf
# 1638 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Review of deep learning: concepts, CNN architectures, challenges, applications, future  directions.pdf
# 1639 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Fundamentals of Machine Learning for Predictive Data Analytics.pdf
# 1640 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/a-tutorial-survey-of-architectures-algorithms-and-applications-for-deep-learning.pdf
# 1641 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/deep-learning-for-the-prediction-of-stockmarket-trends.pdf
# 1642 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Sliding Window Algorithms for k-Clustering Problems.pdf
# 1643 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Practical Machine Learning with H2O.pdf
# 1644 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Deep learning in finance and banking_ A literature review and classification.pdf
# 1645 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Neuro-Fuzzy Systems: A Survey.pdf
# 1646 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/71. Deep learning.pdf
# 1647 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Absolute exponential stability of recurrent neural networks with Lipschitz-continuous activation functions and time delays.pdf
# 1648 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Deep learning for Stock Market Prediction.pdf
# 1649 ../References_Deep_Learning_For_Finance/000 more references/Deep Learning/Data Augmentation and Finance/Enhancing Stock Price Trend Prediction via a Time-Sensitive Data Augmentation Method.pdf
# 1650 ../References_Deep_Learning_For_Finance/000 more references/Feature Similarity/Time-Series Clustering and Association Analysis of Financial Data .pdf
# 1651 ../References_Deep_Learning_For_Finance/000 more references/Feature Similarity/Dimensionality Reduction using Similarity-induced Embeddings.pdf
# 1652 ../References_Deep_Learning_For_Finance/000 more references/Feature Similarity/Unsupervised Knowledge Transfer using Similarity Embeddings.pdf
# 1653 ../References_Deep_Learning_For_Finance/000 more references/Feature Similarity/PySEF: A Python Library for Similarity-based Dimensionality Reduction.pdf
# 1654 ../References_Deep_Learning_For_Finance/000 more references/Feature Similarity/Discriminative Clustering using Regularized Subspace Learning.pdf
# 1655 ../References_Deep_Learning_For_Finance/000 more references/Feature Similarity/A Sliding Window Filter for Time Series Streams.pdf
# 1656 ../References_Deep_Learning_For_Finance/000 more references/Feature Similarity/Mining_the_stock_market_Which_measure_is_best.pdf
# 1657 ../References_Deep_Learning_For_Finance/000 more references/Transfer Learning/A Survey on Transfer Learning.pdf
# 1658 ../References_Deep_Learning_For_Finance/000 more references/Transfer Learning/A Comprehensive Survey on Transfer Learning.pdf
# 1659 ../References_Deep_Learning_For_Finance/000 more references/LSTM Learning/An Attention-Based LSTM Model for Stock Price Trend Prediction Using Limit Order Books .pdf
# 1660 ../References_Deep_Learning_For_Finance/000 more references/LSTM Learning/A Survey on LSTM-based Stock Market Prediction.pdf
# 1661 ../References_Deep_Learning_For_Finance/000 more references/LSTM Learning/The Direct Reversal Trading Strategy in Python. _ by Sofien Kaabar, CFA _ Geek Culture _ Medium.pdf
# 1662 ../References_Deep_Learning_For_Finance/000 more references/Objective_Functions/technical-analysis-of-stocks-amp-commodities-oct-2018.pdf
# 1663 ../References_Deep_Learning_For_Finance/000 more references/Objective_Functions/Deep Learning for Forecasting Stock Returns in the Cross-Section.pdf
# 1664 ../References_Deep_Learning_For_Finance/000 more references/Objective_Functions/Loss Functions in Time Series Forecasting.pdf
# 1665 ../References_Deep_Learning_For_Finance/000 more references/Objective_Functions/Customize loss function to make LSTM model more applicable in stock price prediction _ by Zedric Cheung _ Towards Data Science.pdf
# 1666 ../References_Deep_Learning_For_Finance/000 more references/Objective_Functions/Optimization of a Trading System using Global Search Techniques and Local Optimization.pdf
# 1667 ../References_Deep_Learning_For_Finance/000 more references/Objective_Functions/Loss Functions in Financial Sector- An Overview.pdf
# 1668 ../References_Deep_Learning_For_Finance/000 more references/Objective_Functions/The Optimization Process- An example of portfolio optimization.pdf
# 1669 ../References_Deep_Learning_For_Finance/000 more references/Objective_Functions/Neural networks for algorithmic trading. Volatility forecasting and custom loss functions _ by Alexandr Honchar _ codeburst.pdf
# 1670 ../References_Deep_Learning_For_Finance/000 more references/Objective_Functions/The training dilemma_ loss vs profit function_ _ by Haris (Chariton) Chalvatzis _ Analytics Vidhya _ Medium.pdf
# 1671 ../References_Deep_Learning_For_Finance/000 more references/Objective_Functions/Loss Functions _ Encyclopedia.com.pdf
# 1672 ../References_Deep_Learning_For_Finance/000 more references/Objective_Functions/Forecasting Volatility of Stock Index- Deep Learning Model with Likelihood-Based Loss Function.pdf
# 1673 ../References_Deep_Learning_For_Finance/000 more references/Genetic Algorthms Game Theory/Game Theory Using Genetic Algorithms.pdf
# 1674 ../References_Deep_Learning_For_Finance/000 more references/Genetic Algorthms Game Theory/A Game-Theoretic Investigation of Selection Methods Used in Evolutionary Algorithms.pdf
# 1675 ../References_Deep_Learning_For_Finance/000 more references/Genetic Algorthms Game Theory/Algorithms, Games, and Evolution.pdf
# 1676 ../References_Deep_Learning_For_Finance/000 more references/Genetic Algorthms Game Theory/Game Theory for Multi-Access Edge Computing: Survey, Use Cases, and Future Trends.pdf
# 1677 ../References_Deep_Learning_For_Finance/000 more references/Genetic Algorthms Game Theory/Game Theory-Inspired Evolutionary Algorithm for Global Optimization.pdf
# 1678 ../References_Deep_Learning_For_Finance/000 more references/Genetic Algorthms Game Theory/A survey of Game Theory using Evolutionary Algorithms.pdf

# %%
import os.path

for fn in glob.glob('all_collections/*.pdf'):
    
    skipped = ['all_collections/Fuzzy Based Modified SHL algorithm for Spiking Neural  Network.pdf', 
               'all_collections/A Survey on Unsupervised Machine Learning Algorithms for Automation, Classification and Maintenance.pdf',
              'all_collections/Evolutionary Function Approximation for Reinforcement Learning.pdf',
              'all_collections/Purified sentiment indicators for the stock market5.04.09.pdf',
               'all_collections/Time Series Analysis by State Space Methods (2ed).pdf',
               'all_collections/Machine Learning for Time Series Anomaly Detection.pdf',
               'all_collections/The Effect of the Normalization Method Used in Different Sample Sizes on.pdf',
               'all_collections/Genetic Algorithm: An Application to Technical Trading System Design.pdf',
              'all_collections/Improving stock trading decisions based on pattern recognition using machine learning technology.pdf']
    
    ss = fn.split('/')
    
    if os.path.isfile('all_papers/' + ss[-1]) or os.path.isfile('all_articles/' + ss[-1]):
        #print('Skipped')
        continue
    
    if fn in skipped:
        continue
    
    if found_references_tag(fn):
        dst= './all_papers/' + ss[-1]
        shutil.copyfile(fn, dst)
    else:
        dst= './all_articles/' + ss[-1]
        shutil.copyfile(fn, dst)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Input In [68], in <cell line: 3>()
#      21 if fn in skipped:
#      22     continue
# ---> 24 if found_references_tag(fn):
#      25     dst= './all_papers/' + ss[-1]
#      26     shutil.copyfile(fn, dst)
#
# Input In [62], in found_references_tag(fn)
#       4 text = ""
#       6 for page in reader.pages:
# ----> 7     text += page.extract_text() + "\n"
#       9 sen = text.split('\n')
#      11 for s in sen:
#
# File ~/.local/lib/python3.8/site-packages/PyPDF2/_page.py:1317, in PageObject.extract_text(self, Tj_sep, TJ_sep, space_width)
#    1299 def extract_text(
#    1300     self, Tj_sep: str = "", TJ_sep: str = "", space_width: float = 200.0
#    1301 ) -> str:
#    1302     """
#    1303     Locate all text drawing commands, in the order they are provided in the
#    1304     content stream, and extract the text.
#    (...)
#    1315     :return: The extracted text
#    1316     """
# -> 1317     return self._extract_text(self, self.pdf, space_width, PG.CONTENTS)
#
# File ~/.local/lib/python3.8/site-packages/PyPDF2/_page.py:1130, in PageObject._extract_text(self, obj, pdf, space_width, content_key)
#    1128 if "/Font" in resources_dict:
#    1129     for f in cast(DictionaryObject, resources_dict["/Font"]):
# -> 1130         cmaps[f] = build_char_map(f, space_width, obj)
#    1131 cmap: Tuple[
#    1132     Union[str, Dict[int, str]], Dict[str, str], str
#    1133 ]  # (encoding,CMAP,font_name)
#    1134 try:
#
# File ~/.local/lib/python3.8/site-packages/PyPDF2/_cmap.py:21, in build_char_map(font_name, space_width, obj)
#      19 space_code = 32
#      20 encoding, space_code = parse_encoding(ft, space_code)
# ---> 21 map_dict, space_code, int_entry = parse_to_unicode(ft, space_code)
#      23 # encoding can be either a string for decode (on 1,2 or a variable number of bytes) of a char table (for 1 byte only for me)
#      24 # if empty string, it means it is than encoding field is not present and we have to select the good encoding from cmap input data
#      25 if encoding == "":
#
# File ~/.local/lib/python3.8/site-packages/PyPDF2/_cmap.py:234, in parse_to_unicode(ft, space_code)
#     227 fmt2 = b"%%0%dX" % len(lst[2])
#     228 while a <= b:
#     229     map_dict[
#     230         unhexlify(fmt % a).decode(
#     231             "charmap" if map_dict[-1] == 1 else "utf-16-be",
#     232             "surrogatepass",
#     233         )
# --> 234     ] = unhexlify(fmt2 % c).decode("utf-16-be", "surrogatepass")
#     235     int_entry.append(a)
#     236     a += 1
#
# Error: Odd-length string

# %%
fn
# Out:
# 'all_collections/Machine Learning for Time Series Anomaly Detection.pdf'

# %%
fn
# Out:
# '../References_Deep_Learning_For_Finance/000 more references/Genetic Algorthms Game Theory/A survey of Game Theory using Evolutionary Algorithms.pdf'

# %%
#check if unicode

#fn = 'A Deep Learning Approach for Stock Market Prediction.pdf'
fn = 'all_collections/Purified sentiment indicators for the stock market5.04.09.pdf'

reader = PdfReader(fn)

text = ""

for page in reader.pages:
    print(page.extract_text())
    print('------------------------')
    text += page.extract_text() + "\n"

#sen = text.split('\n')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Input In [78], in <cell line: 10>()
#       8 text = ""
#      10 for page in reader.pages:
# ---> 11     print(page.extract_text())
#      12     print('------------------------')
#      13     text += page.extract_text() + "\n"
#
# File ~/.local/lib/python3.8/site-packages/PyPDF2/_page.py:1317, in PageObject.extract_text(self, Tj_sep, TJ_sep, space_width)
#    1299 def extract_text(
#    1300     self, Tj_sep: str = "", TJ_sep: str = "", space_width: float = 200.0
#    1301 ) -> str:
#    1302     """
#    1303     Locate all text drawing commands, in the order they are provided in the
#    1304     content stream, and extract the text.
#    (...)
#    1315     :return: The extracted text
#    1316     """
# -> 1317     return self._extract_text(self, self.pdf, space_width, PG.CONTENTS)
#
# File ~/.local/lib/python3.8/site-packages/PyPDF2/_page.py:1130, in PageObject._extract_text(self, obj, pdf, space_width, content_key)
#    1128 if "/Font" in resources_dict:
#    1129     for f in cast(DictionaryObject, resources_dict["/Font"]):
# -> 1130         cmaps[f] = build_char_map(f, space_width, obj)
#    1131 cmap: Tuple[
#    1132     Union[str, Dict[int, str]], Dict[str, str], str
#    1133 ]  # (encoding,CMAP,font_name)
#    1134 try:
#
# File ~/.local/lib/python3.8/site-packages/PyPDF2/_cmap.py:21, in build_char_map(font_name, space_width, obj)
#      19 space_code = 32
#      20 encoding, space_code = parse_encoding(ft, space_code)
# ---> 21 map_dict, space_code, int_entry = parse_to_unicode(ft, space_code)
#      23 # encoding can be either a string for decode (on 1,2 or a variable number of bytes) of a char table (for 1 byte only for me)
#      24 # if empty string, it means it is than encoding field is not present and we have to select the good encoding from cmap input data
#      25 if encoding == "":
#
# File ~/.local/lib/python3.8/site-packages/PyPDF2/_cmap.py:234, in parse_to_unicode(ft, space_code)
#     227 fmt2 = b"%%0%dX" % len(lst[2])
#     228 while a <= b:
#     229     map_dict[
#     230         unhexlify(fmt % a).decode(
#     231             "charmap" if map_dict[-1] == 1 else "utf-16-be",
#     232             "surrogatepass",
#     233         )
# --> 234     ] = unhexlify(fmt2 % c).decode("utf-16-be", "surrogatepass")
#     235     int_entry.append(a)
#     236     a += 1
#
# Error: Odd-length string

# %%
text
# Out:
# ' CS 230  \nA Deep Learning Approach for Stock Market Prediction  \n \nYan Miao  \nCompute r Science Department  \nStanford Un iversity \nyanmiao@stanford.edu  \nAbstract  \nThe project explores  a stock market prediction model using  a LSTM \nnetwork . A  LSTM  model  with  different param eters  are  tested  to \ndetermine  the  effect  of  number  of  hidden  layers,  dropout \nregularization  and batch size on the  result accuracy . The model  is \ntested on t he stock price  of Amazon, Google and Faceboo k.  \n1 Introduction  \nFinancial  time series are non-stationary,  nonlinear  and high-noise.  While individuals  and firms all \nhave interests  in gaining  profits  from the stock market,  it is difficult  to predict  the trend of a stock’s  \nprice by instinct.  Despite  the success  of classical  machine  learning  algorithms,  the evolution  of \ndeep learning  has provide d new models  for researchers  to analyze  big data with cheap  computation  \ndevices.  The input to my algorithm  is the daily price value of a stock in a chosen  time period. Then \nI use a long short-term memory  (LSTM) recurrent  neural  network  to output the predicted  stock \nprice.  \n \n2 Related Work  \n \nThe deep learning  neural  network  is a reliable  predictor  due to its ability  to approximate  nonlinear  \nfunctions.  There already exists many papers  on this topic. For example,  Artificial  Neural  Networks  \n(ANN)  are able to predict the stock price and direction  of movement  of the price [1][2]. \nConvolutional  Neural  Networks  (CNN),  though  more frequently  used for image processing,  can \nalso be used to predict  the stock movement  as a classification  model  with one day close,  open, \nhigh, low, volume  data [3]. In his paper,  experiments  on a one-dimensional  convolutional  network  \nwith three convolutional  layers using MaxPooling  and ReLu activation.  In particular,  LSTM neural  \nnetworks  have the characteristics  of selectivity  and memory  cells that are suitable  for random  non-\nstationary  sequences  like stock-price time series [4]. LSTM can store memory  and solve the \ngradient  vanishing  problem.  The LSTM network  is also the most popular  model  adopted  right now. \nIn a study that systematically  reviews  the Deep Learning  models  implemented  for stock market  \nforecasting,  researchers  find that the LSTM technique  is widely  applied  (73.5%)  [5]. In this \nproject,  an LSTM network  is implemented  to predict  the Amazon  stock price. Similar  works can \nbe found here: [6][7][8] . \n \n3 Dataset  and Features  \nThe experimental data comes from the data provided by Yahoo Finance.  The stock price is selected \nfrom  January  28,  2015  to  January  29,  2020. Stocks  from  three companies  are  selected: \nAmazon (AMZN ), Google( GOOG) and Facebook( FB). Such selection is to minimize unn ecessary \ninfluences due to different industries.  \n \n \n \n \n \nIn the dataset, there are five features: the day of the transaction (date), the opening price value of \nthe specified day (open), the closing price value of the specified day (close), the lowest price value \nof the specified day (low), the highest price valu e of the specified day (high). For the project, the \ngoal is to predict the “close” stock price value.  For each  dataset, there are 1260 entries in total.  The \nfirst 800  entries are selected for training, and the  remaining  460 entries are used for testing.  Neural \nnetworks are sensitive to unnormalized data.  Before training the model, the data was  rescaled  into \nthe range of [0, 1] using Min -Max normalization  to make  the model more reliable . Then, each row \nof the input matrix is a data  structure  with 30 time -steps. For training  input, the shape is ( 770, 30, \n1) and for testing input, the shape   is (430, 30, 1 ). \n4 Methods  \nThe LSTM network  model  is implemented in this project . The structure of the me mory unit  of a \nLSTM is demonstrated ...
