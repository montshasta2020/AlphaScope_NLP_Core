# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/references/Parsed_Raw_Ref_48062.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  date                                      names title  \
# 0           0  2001                              Arun K Punjar    []
# 1           1  1991             L. Davis, Van Nostrand Reinhol    []
# 2           2  1995            Y. Hiemstra, Trippi, R. R, Irwi    []
# 3           3  1997  K. Kohara, Ishikawa, Fukuhara Y., Nakamur    []
# 4           4  1990                         K. Kamijo, Tanigaw    []
#
#                                              raw_ref
# 0  Arun K Punjari “Data mining techniques” univer...
# 1  L. Davis, Handbook of genetic algorithms, Van ...
# 2  Y. Hiemstra, “Modeling structured nonlinear kn...
# 3  K. Kohara, Ishikawa T., Fukuhara Y. and Nakamu...
# 4  K. Kamijo and Tanigawa T., “Stock price patter...

# %%
type(df['date'].values[0])
# Out:
# numpy.int64

# %%
sub_df = df[df['date'] == 2020]

# %%
for i in range(sub_df.shape[0]):
    c = sub_df['raw_ref'].values[i]
    if 'stock' in c:        
        print(i, 'Stock', c)
        print ('-------------------------------------')
    elif 'trading' in c:
        print (i, 'Trading', c)
        print ('-------------------------------------')
# Out:
# 45 Stock 41. Nti, I.K.; Adekoya, A.F.; Weyori, B.A. A comprehensive evaluation of ensemble learning for stock-market prediction. J. Big Data 2020, 7, 1–40. [CrossRef]
# -------------------------------------
# 81 Stock 11. Maqsood, H.; Mehmood, I.; Maqsood, M.; Yasir, M.; Afzal, S.; Aadil, F.; Selim, M.M.; Muhammad, K. A local and global event sentiment based efficient stock exchange forecasting using deep learning. Int. J. Inf. Manag. 2020, 50, 432–451. [CrossRef]
# -------------------------------------
# 86 Stock 58. Pang, X.; Zhou, Y.; Wang, P.; Lin, W.; Chang, V. An innovative neural network approach for stock market prediction. J. Supercomput. 2020, 76, 2098–2118. [CrossRef]
# -------------------------------------
# 88 Stock 63. Long, J.; Chen, Z.; He, W.; Wu, T.; Ren, J. An integrated framework of deep learning and knowledge graph for prediction of stock price trend: An ap-plication in Chinese stock exchange market. Appl. Soft Comput. 2020, 91, 106205. [CrossRef]
# ...

# %%
for i in range(df.shape[0]):
    c = df['raw_ref'].values[i]
    if 'survey' in c:        
        print(i, 'survey', c)
        print ('-------------------------------------')
    elif 'review' in c:
        print (i, 'review', c)
        print ('-------------------------------------')
    elseif 'overview' in c:
        print (i, 'overview', c)
        print ('-------------------------------------')
