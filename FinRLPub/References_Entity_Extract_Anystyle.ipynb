# %%
import pandas as pd
import glob

# %%
#!anystyle find '{in_fn}' > '{out_fn}'

# %%
cnt = 1
for fn in glob.glob('./all_collections/*.pdf'):
    s = fn.split('/')
    ss = s[-1].split('.')[0]
    
    out_fn = './References/' + ss + '.json'
    # !anystyle find '{fn}' > '{out_fn}'
    
    print (cnt, out_fn)
    cnt += 1
# Out:
# 1 ./References/Using image recognition for trading.json
# 2 ./References/An Automatic Stock Trading System using Particle Swarm Optimization .json
# 3 ./References/thru_earnings_ws_estimize_delta_event_study.json
# 4 ./References/Best technical indicators for Bitcoin from TA-lib _ by Berend _ Coinmonks _ Mar, 2022 _ Medium.json
# 5 ./References/Deep learning for relaive stock performance prediction.json
# 6 ./References/Stock Prices Prediction using Deep Learning Models.json
# 7 ./References/Attentive Neural Models for Algorithmic Trading-1.json
# 8 ./References/Optimization Techniques: An Overview.json
# 9 ./References/A multi-layer and multi-ensemble stock trader using deep learning and deep reinforcement learning .json
# 10 ./References/Deep Reinforcement Learning- An Overview.json
# 11 ./References/Neural Architecture Search for Time Series Classification.json
# 12 ./References/A review of Reinforcement learning for financial time series prediction and portfolio optimization _ by Nick Smith _ Journal of Quantitative finance _ Medium.json
# 13 ./References/On the efciency of nature-inspired metaheuristics in expensive global optimization with limited budget.json
# 14 ./References/Bilinear Input Normalization for Neural Networks.json
# 15 ./References/Classification Problem in Imbalanced Datasets.json
# 16 ./References/The Evolution of Rough Sets.json
# 17 ./References/Dealing with Class Imbalance using Thresholding.json
# 18 ./References/Immunity to Device Variations in a Spiking Neural Network With Memristive Nanodevices.json
# 19 ./References/A Survey and Classification of Methods for (Mostly) Unsupervised Learning of Morphology.json
# 20 ./References/A Novel Ensemble Deep Learning Mode.json
# 21 ./References/Lin-Feature Investigation for Stock Market Prediction.json
# 22 ./References/Time series forecasting with applications to finance.json
# 23 ./References/Gated Value Network for Multilabel Classification.json
# 24 ./References/SURVEY ON STOCK MARKET PRICE PREDICTION VIA DEEP NEURAL  NETWORKS.json
# 25 ./References/Long Term Stock Prediction Based On Financial Statements.json
# 26 ./References/Approaching Time-Series with a Tree-based Model _ by Agnis Liukis _ Towards Data Science.json
# 27 ./References/Deep Learning for Stock Price Forecasting.json
# 28 ./References/ROUGH SETS AND FUZZY SETS.json
# 29 ./References/Comparative Study of Stock Trend Prediction using Time Delay Recurrent and Probabilistic Neural Networks.json
# 30 ./References/Stock Market Forecasting Using Computational Intelligence: A Survey.json
# 31 ./References/Forecasting Stock Prices from the Limit Order Book using Convolutional Neural Networks.json
# 32 ./References/Stable-Baselines3_ Reliable Reinforcement Learning Implementations _ Antonin Raffin _ Homepage.json
# 33 ./References/ANALYSIS OF DAILY STOCK TREND PREDICTION USING ARIMA MODEL.json
# 34 ./References/A hybrid stock trading framework integrating technical analysis with machine learning techniques.json
# 35 ./References/Predicting Stock Market Movements Using A Neural Network Applied To The Deutsche Börse Public Dataset.json
# 36 ./References/Deep_Learning_for_Time_Series_Tutorial.json
# 37 ./References/Golden section search over hyper-rectangle: A Direct search method.json
# 38 ./References/Optimal Feature Selection of Technical Indicator and Stock Prediction Using Machine Learning Technique.json
# 39 ./References/A Survey of Preference-Based Reinforcement Learning Methods.json
# 40 ./References/Incorporating Transformers and Attention Networks for Stock Movement Prediction.json
# 41 ./References/A Note on Evolutionary Algorithms and Its Applications.json
# 42 ./References/A research overview of manifold-learning-based multiobjective evolutionary algorithm .json
# 43 ./References/Machine Learning in Stock Price Prediction Using Long Short-Term.json
# 44 ./References/What is Reinforcement Learning_ Overview, Comparisons and Applications _ AltexSoft.json
# 45 ./References/A Tutorial Survey of Reinforcement Learn.json
# 46 ./References/Implementation Classification.json
# 47 ./References/Benchmark and Survey of Automated Machine Learning Frameworks.json
# 48 ./References/a-literature-survey-on-stocks-predictions-using-hybrid-machine-learning-and-deep-learning-models-IJERTV8IS100002.json
# 49 ./References/Review 01 -- Reinforcement learning in financial markets - a survey.json
# 50 ./References/Technical Analysis of Stock Trends (Robert D.json
# 51 ./References/Using_neural_networks_to_forecast_stock_market_price.json
# 52 ./References/Game Theory Using Genetic Algorithms.json
# 53 ./References/Continuous vs.json
# 54 ./References/Automated Trading System - A Survey.json
# 55 ./References/The Likelihood of Various Stock Market Return Distributions, Part 1: Principles of Inference.json
# 56 ./References/Pattern recognition with Spiking Neural Networks: a simple training method.json
# 57 ./References/A Survey on Semi-parametric Machine Learning.json
# 58 ./References/Journal of Forecasting - 2018 - Ntakaris - Benchmark dataset for mid‐price forecasting of limit order book data with.json
# 59 ./References/A REINFORCEMENT LEARNING ALGORITHM WITH EVOLVING FUZZY NEURAL NETWORKS.json
# 60 ./References/Predicting Bitcoin Price Trends.json
# 61 ./References/Making Financial Trading by Recurrent Reinforcement Learning.json
# 62 ./References/Cross-Validation Techniques.json
# 63 ./References/A Dynamic Adjusting Reward Function Method for Deep Reinforcement Learning with Adjustable Parameters.json
# 64 ./References/Arbitrary Style Transfer in Real-time with Adaptive Instance Normalization.json
# 65 ./References/Learning the dynamics of technical trading strategies.json
# 66 ./References/Testing different Reinforcement Learning configurations for financial trading: Introduction and applications.json
# 67 ./References/A Search Heuristic Guided Reinforcement Learning Approach to the Traveling Salesman Problem.json
# 68 ./References/****Stock movement_ Predict a 5 Pct rise in 10 days with GAN.json
# 69 ./References/Biomimetic Use of Genetic Algorithms.json
# 70 ./References/Training of Spiking Neural Networks with Reinforcement Learning.json
# 71 ./References/10 creative applications of symbolic regression - TuringBot.json
# 72 ./References/Predicting stock prices using deep learning | by Yacoub Ahmed | Towards Data Science.json
# 73 ./References/Predictive-Analytics-For-Dummies-E-book-by-Tangent-Works.json
# 74 ./References/Booms and Busts_ An Encyclopedia of Economic History from the First Stock Market Crash of 1792 to the Current Global Economic Crisis ( PDFDrive ).json
# 75 ./References/STOCK MOVEMENT PREDICTION WITH DEEP LEARNING FINANCE TWEETS SENTIMENT, TECHNICAL INDICATORS AND CANDLESTICK CHARTING.json
# 76 ./References/Data mining for imbalanced data:Improving classifiers by selective pre-processing of examples .json
# 77 ./References/Reinforcement learning improves behaviour from evaluative feedback.json
# 78 ./References/Fuzzy Based Modified SHL algorithm for Spiking Neural  Network.json
# 79 ./References/Adaptive Normalization: A Novel Data Normalization Approach for Non-Stationary Time Series .json
# 80 ./References/C__Users_matqsb_Documents_My files_Research_Presentation_Mike Paper 3_Salah_post_thesis Oct 20 v3.json
# 81 ./References/Volume Weighted Average Price Optimal Execution.json
# 82 ./References/Dynamics of Gene Expression in an Artificial Genome.json
# 83 ./References/A-Review-On-Big-Data-With-Machine-Learning-And-Fuzzy-Logic-For-Better-Decision-Making.json
# 84 ./References/Reinforcement Learning Algorithms for Automated Stock Trading.json
# 85 ./References/technical-analysis-of-stocks-amp-commodities-oct-2018.json
# 86 ./References/Learning Robust Features using Deep Learning for Automatic Seizure Detection.json
# 87 ./References/Complex Stock Trading Strategy Based on Particle Swarm Optimization.json
# 88 ./References/Stock Market Prediction on High-Frequency Data Using Generative Adversarial Nets.json
# 89 ./References/A reinforcement learning model based on reward correction for quantitative stock selection.json
# 90 ./References/A Survey on Unsupervised Machine Learning Algorithms for Automation, Classification and Maintenance.json
# 91 ./References/Time-Series Clustering and Association Analysis of Financial Data .json
# 92 ./References/Fuzzy rough sets 1.json
# 93 ./References/Generative_Adversarial_Networks_for_Financial_Trad.json
# 94 ./References/Replacing financial charting with sequence models for trading stocks.json
# 95 ./References/Using the latest advancements in deep learning to predict stock price movements | by Boris B | Towards Data Science.json
# 96 ./References/Introduction_to_Evolutionary_Algorithms.json
# 97 ./References/Fuzzy SETS UNCERTAINTY AND INFORMATION.json
# 98 ./References/Time Series Forecasting with Deep Learning Models.json
# 99 ./References/Understanding Feature Importance in Financial Machine Learning _ by Lucas Astorian _ Medium.json
# 100 ./References/A Comparision of normalization techniques.json
# 101 ./References/Agent Inspired Trading Using Recurrent Reinforcement Learning and LSTM Neural Networks.json
# 102 ./References/Statsmodels- Econometric and statistical modeling with Python.json
# 103 ./References/An overview of time series forecasting models.json
# 104 ./References/Google AI Uses Temporal Fusion Transformer for Time Series Forecasting.json
# 105 ./References/TCCT: Tightly-coupled convolutional transformer on time series  forecasting.json
# 106 ./References/AI in Finance_ how to finally start to believe your backtests [2_3] _ by Alexandr Honchar _ Towards Data Science.json
# 107 ./References/Temporal Relational Ranking for Stock Prediction.json
# 108 ./References/Towards Effective Classification of Imbalanced Data with Convolutional Neural Networks.json
# 109 ./References/Hands-On Machine Learning with Scikit-Learn and TensorFlow_ Concepts, Tools, and Techniques to Build Intelligent Systems.json
# 110 ./References/Feature Scaling _ Standardization Vs Normalization.json
# 111 ./References/Maximum and minimum stock price forecasting of Brazilian power distribution companies based on artificial neural networks.json
# 112 ./References/A STUDY ON FINANCIAL TIME SERIES FORECASTING AND SYMBOLIC REGRESSION BY MEANS OF A HYBRID PROBABILISTIC MODEL-BUILDING CARTESIAN GENETIC PROGRAMMING METHODOLOGY.json
# 113 ./References/SNN Project Intro.json
# 114 ./References/A review of feature selection methods with applications.json
# 115 ./References/10-EvolutionaryComputation.json
# 116 ./References/reinforcement learning - Suitable reward function for trading buy and sell orders - Artificial Intelligence Stack Exchange.json
# 117 ./References/Adaptation in Evolutionary Computation:A Survey.json
# error: Too many arguments for command
#
# 118 ./References/Predicting stock price dynamics using stacked GRU's and LSTM's.json
# 119 ./References/Evolutionary Computations for Trading Systems.json
# 120 ./References/Fuzzy ART: Fast stable learning and categorization of analog patterns by an adaptive resonance system.json
# 121 ./References/Stock Price Pattern Prediction Based on Complex Network and Machine Learning.json
# 122 ./References/A Survey of Adaptive Resonance Theory Neural Network Models for Engineering Applications.json
# 123 ./References/Heuristic Search Based Explorationin Reinforcement Learning.json
# 124 ./References/FUZZY, DISTRIBUTED, INSTANCE COUNTING, AND DEFAULT ARTMAP NEURAL NETWORKS FOR FINANCIAL DIAGNOSIS.json
# 125 ./References/Neural Architecture Search for Spiking Neural Networks.json
# 126 ./References/Practical Text Classification With Python and Keras – Real Python.json
# 127 ./References/A Review of Artificial Intelligence in Investment.json
# 128 ./References/Convolutional Neural Network for Predicting Company Performance Based on Historical Financial Statement Information.json
# 129 ./References/Trend Filtering Methods for Momentum Strategies.json
# 130 ./References/Stock Trend Prediction Using Candlestick Charting and Ensemble Machine Learning T Machine Learning Techniques with a No echniques with a Novelty Feature Engineering e Engineering Scheme .json
# 131 ./References/Interval_Forecasting_of_Financial_Time_Series_by_Accelerated_Particle_Swarm-Optimized_Multi-Output_Machine_Learning_System.json
# 132 ./References/Deep Learning for Forecasting Stock Returns in the Cross-Section.json
# 133 ./References/Applications of artificial neural networks in financial market forecasting - PhD thesis.json
# 134 ./References/A Game-Theoretic Investigation of Selection Methods Used in Evolutionary Algorithms.json
# 135 ./References/Optimizing Multiple Stock Trading Rules using Genetic  Algorithms.json
# 136 ./References/Overview of Time Series Forecasting from Statistical to Recent ML Approaches _ by Phylypo Tum _ Medium.json
# 137 ./References/Global Adaptive Input Normalization for Short-Term Electric Load Forecasting.json
# error: Too many arguments for command
#
# NAME
#     find - Find and extract references from text documents
#
# SYNOPSIS
#
#     anystyle [global options] find [command options] input [output]
#
#
#
# DESCRIPTION
#     This manual page documents the AnyStyle `find' command. AnyStyle `find'
#     analyzes PDF or text documents and extracts all references it finds.
#
#     The input argument can be a single PDF or text document, or a folder
#     containing multiple documents. The (optional) output argument specifies
#     the folder where the results shall be saved; if no output folder is
#     specified, results will be saved in the folder containing the input.
#
#     AnyStyle `find' supports the following formats:
#         bib     BibTeX (references only);
#         csl     CSL/JSON (references only);
#         json    AnyStyle JSON (references only);
#         ref     One reference per line, suitable for parser input;
#         txt     Plain text document;
#         ttx     Tagged document format, used for training the finder model;
#         xml     References only, XML, suitable for training the parser model.
#
#     You can specify multiple output formats, separated by commas.
#
#     Anlyzing PDF documents currently depends on `pdftotext' which must be
#     installed separately.
#
# EXAMPLES
#     anystyle -f csl,xml find thesis.pdf
#
#     Extract references from `thesis.pdf' and save them in `thesis.csl' and
#     `thesis.xml'.
#
#     anystyle -f bib find --no-layout thesis.pdf bib
#
#     Extract references from `thesis.pdf' in `no-layout' mode (e.g., use this
#     if your document uses a multi-column layout) and save them in BibTeX in
#     `./bib/thesis.bib'.
#
#     anystyle find --crop 72 thesis.pdf -
#
#     Extract references from `thesis.pdf' cropping away one inch (72pt) from
#     each page border and print the results to STDOUT.
#
#     anystyle find --crop 72,28 thesis.pdf -
#
#     Extract references from `thesis.pdf' cropping away one inch (72pt) from
#     each page's left and right border, approx. 1cm (28pt) from the top
#     and bottom.
#
#
#
#
# COMMAND OPTIONS
#     -C, --crop=pt - Set cropping boundary for text extraction (default: none)
#     --[no-]layout - Use layout mode for PDF text extraction (default: enabled)
#     --[no-]solo   - Include references outside of reference sections
#
#
#
# 138 ./References/Time Series Anomaly Detection using LSTM Autoencoders with PyTorch in Python _ Curiousily - Hacker's Guide to Machine Learning.json
# 139 ./References/Symbolic Reinforcement Learning using Inductive Logic Programming Philippines Population Prediction: 2010-2020.json
# 140 ./References/Modeling and Monitoring Erosion of the Leading Edge of Wind Turbine Blades.json
# 141 ./References/Self-Constructing Fuzzy Neural Network Speed Controller for Permanent-Magnet Synchronous Motor Drive.json
# 142 ./References/Financial Time Series Prediction Using Spiking Neural Networks-2.json
# 143 ./References/FinRL FAQ v0.json
# 144 ./References/Digest generation for the news articles using LSTMs.json
# 145 ./References/Combining Exploitation-Based and Exploration-Based Approach in Reinforcement Learning.json
# 146 ./References/Nonstationary time series transformation methods: An experimental review.json
# 147 ./References/Deep Learning Prediction on Price Movement of NASDAQ.json
# 148 ./References/Foreword: special issue on computational finance and economics 2009.json
# 149 ./References/Survey on Machine Learning for Stcok.json
# 150 ./References/A Survey on Policy Search for Robotics.json
# 151 ./References/A Survey on Transfer Learning.json
# 152 ./References/A Deep Reinforcement Learning Framework for the Financial Portfolio Management Problem.json
# 153 ./References/Time-Series-Forecasting-of-Amazon-Stock-Prices-using-Neural-Networks-LSTM-and-GAN.json
# 154 ./References/Feature Selection Based on Evolutionary Algorithms for Affective Computing and Stress Recognition.json
# 155 ./References/(paper) Transformers in Time Series ; A Survey - AAA (All About AI).json
# 156 ./References/A REVIEW PAPER ON PORTFOLIO OPTIMIZATION USING GENETIC ALGORITHM.json
# 157 ./References/Evaluation and potential improvements of a deep reinforcement learning model for automated stock trading.json
# 158 ./References/Fidelity Learning Center_ Technical Analysis Indicator Guide - 003.json
# 159 ./References/Unsupervised Learning - A Systematic Literature Review.json
# 160 ./References/AUTOMATED MACHINE LEARNING OVERVIEW.json
# 161 ./References/Evolutionary_Optimization_Evopt_A_Brief_Review_And.json
# 162 ./References/Multivariate Time Series Classification Using Spiking Neural Networks.json
# 163 ./References/10 Misconceptions about Neural Networks.json
# 164 ./References/Predicting Stock Price Movement with Event-Driven Deep Learning Approach.json
# 165 ./References/Reinforcement Learning for Automated Financial Trading: Basics and Applications.json
# 166 ./References/Development of stock market trend prediction system using multiple regression .json
# 167 ./References/Genetic Algorithms and their Applications 1996.json
# 168 ./References/Deep Reinforcement Learning for Trading2.json
# 169 ./References/Stock reward function - Lokad Technical Documentation.json
# 170 ./References/Stock Movement Prediction using Technical and Data.json
# 171 ./References/Evolving Trading Strategies With Genetic Programming - Encoding Trading Strategies · Fabian Kostadinov.json
# 172 ./References/Enforcing constraints for time series prediction in supervised, unsupervised and reinforcement learning.json
# 173 ./References/Reinforcement Learning algorithms an intuitive overview _ by SmartLab AI _ Medium.json
# 174 ./References/Price Trend Prediction of Stock Market Using Outlier Data Mining Algorithm.json
# 175 ./References/reinforcement learning - How should I define the reward function for a stock trading-like game_ - Artificial Intelligence Stack Exchange.json
# 176 ./References/Evolutionary Function Approximation for Reinforcement Learning.json
# 177 ./References/EXTRACTING THE BEST FEATURES FROM MULTI-COMPANY STOCK DATA TO IMPROVE STOCK PRICE PREDICTION.json
# 178 ./References/CNS Tech Lab.json
# 179 ./References/Enhancing Stock Market Prediction with Extended Coupled Hidden Markov Model over Multi-Sourced Data.json
# 180 ./References/Biomimetics: lessons from nature – an overview.json
# 181 ./References/Self-optimization of EA_ Evolutionary and genetic algorithms - MQL5 Articles.json
# 182 ./References/Prediction of Cryptocurrency Price Movements from Order Book Data Using LSTM Neural Networks.json
# 183 ./References/The Applications of Genetic Algorithms in Stock Market Data Mining Optimisation.json
# 184 ./References/Hierarchical Modelling for Financial Data.json
# 185 ./References/Trading Through Reinforcement Learning using LSTM Neural Networks _ by Armando Vieira _ Medium.json
# 186 ./References/A Volume-Weighted Average Paper.json
# 187 ./References/A Deep Learning Approach for Stock Market Prediction.json
# 188 ./References/Algos Gone Wild: Risk in the World of Automated Trading Strategies .json
# 189 ./References/Getting Returns from RL Algorithms - matthewmcateer.json
# 190 ./References/Stock price prediction using Generative Adversarial Networks.json
# 191 ./References/Spike-Timing-Dependent Hebbian Plasticity as Temporal Difference Learning.json
# 192 ./References/A Customer Churn Prediction Model Based on XGBoost and MLP.json
# 193 ./References/A Trend-Following Strategy in Python.json
# 194 ./References/An efcient stock market prediction model using hybrid feature reduction method based on variational autoencoders and recursive feature elimination.json
# 195 ./References/Normalization Techniques in Training DNNs: Methodology, Analysis and Application.json
# 196 ./References/THE DISTRIBUTION OF STOCK MARKET RETURNS AND RETURNS OF SOUTHEAST EUROPEAN EMERGING MARKETS.json
# 197 ./References/Learning Connections in Financial Time Series.json
# 198 ./References/Reinforcement learning in financial markets - a survey.json
# 199 ./References/QuantConnect-PairTradinginPython.json
# 200 ./References/A Unified View of Nonconvex Heuristic Approach for Low-Rank and Sparse Structure Learning.json
# 201 ./References/Stock Market Prediction using CNN and LSTM.json
# 202 ./References/Modeling of Extreme Values via Exponential Normalization Compared with Linear and Power Normalization.json
# 203 ./References/DEEP EXECUTION - VALUE AND POLICY BASED REINFORCEMENT LEARNING FOR TRADING AND BEATING MARKET BENCHMARKS.json
# 204 ./References/Reinforcement Learning in Trading.json
# 205 ./References/Deep Transformer Models for Time Series Forecasting-The Influenza Prevalence Case.json
# 206 ./References/Financial Data Mining with Genetic Programming.json
# 207 ./References/Building and Evaluating Interpretable Models using Symbolic Regression and Generalized Additive Models.json
# 208 ./References/Computational learning techniques for intraday FX trading using popular technical indicators.json
# 209 ./References/Improving On-policy Learning with Statistical Reward Accumulation.json
# 210 ./References/a survey of inverse reinforcement learning techniques.json
# 211 ./References/Opinion: Machine learning won’t crack the stock market— but here’s when investors should trust AI.json
# 212 ./References/An Analysis of Publications on Particle Swarm Optimisation Applications Particle Swarm Optimisation.json
# 213 ./References/Cost-Sensitive Learning Methods for Imbalanced Data.json
# 214 ./References/Deep Direct Reinforcement Learning for Financial Signal Representation and Trading.json
# 215 ./References/Successful Technical Trading Agents Using Genetic Programming.json
# 216 ./References/Machine Learning Methods in Finance.json
# 217 ./References/Deep Reinforcement Learning For Trading - A Critical Survey.json
# 218 ./References/Using genetic algorithms to find technical trading rules.json
# 219 ./References/Policy invariance under reward transformations: Theory and application to reward shaping.json
# 220 ./References/Optimal Control Using Adaptive Resonance Theory and Q-Learning.json
# 221 ./References/Auto-Pytorch: Multi-Fidelity MetaLearning for Efficient and Robust AutoDL .json
# 222 ./References/TranAD: Deep Transformer Networks for Anomaly Detection in Multivariate Time Series Data.json
# 223 ./References/Pairs Rotation With Ehlers Loops.json
# 224 ./References/AdaRNN: Adaptive Learning and Forecasting for Time Series∗.json
# 225 ./References/Purified sentiment indicators for the stock market5.json
# 226 ./References/AutoML performance in model fitting .json
# 227 ./References/STRUCTURED LOW-RANK MATRIX RECOVERY VIA OPTIMIZATION METHODS.json
# 228 ./References/Language models are few-shot learners.json
# 229 ./References/Reinforcement Learning: A Tutorial Survey and Recent Advances.json
# 230 ./References/A Biologically Plausible Supervised Learning Method for Spiking Neural Networks Using the Symmetric STDP Rule.json
# 231 ./References/METRIC-SPACE ANALYSIS OF SPIKE TRAINS: THEORY, ALGORITHMS, AND APPLICATION.json
# 232 ./References/A Brief Survey of Deep Reinforcement Learning.json
# 233 ./References/Technical Analysis Of The Financial Markets.json
# 234 ./References/Reinforcement_Learning_for_Systematic_FX_Trading.json
# 235 ./References/Practical Deep Reinforcement Learning Approach for Stock Trading.json
# 236 ./References/Stock selection with random forest: An exploitation of excess return in the Chinese stock market.json
# 237 ./References/Scaling laws for neural language models.json
# 238 ./References/A FINE-GRAINED ANALYSIS ON DISTRIBUTION SHIFT.json
# 239 ./References/Regularized Evolution for Image Classifier Architecture Search.json
# 240 ./References/MULTIVARIATE TIME-SERIES ANALYSIS VIA MANIFOLD LEARNING.json
# 241 ./References/DSANet: Dual Self-Attention Network for Multivariate Time Series Forecasting.json
# 242 ./References/Reinforcement-Learning-For-Automated-Trading.json
# 243 ./References/Comparison_of_Auto_PyTorch_and_AutoCVE.json
# 244 ./References/Scaling tree-based automated machine learning to biomedical big data with a feature set selector _ Bioinformatics _ Oxford Academic.json
# 245 ./References/SAMPLE-EFFICIENT AUTOMATED DEEP REINFORCEMENT LEARNING .json
# 246 ./References/A REVIEW OF STOCK TREND PREDICTION WITH COMBINATION OF EFFECTIVE MULTI TECHNICAL INDICATOR STRATEGY.json
# 247 ./References/Integrated_Long-Term_Stock_Selection_Models_Based_on_Feature_Selection_and_Machine_Learning_Algorithms_for_China_Stock_Market.json
# 248 ./References/Robust manifold broad learning system for large-scale noisy chaotic time series prediction: A perturbation perspective.json
# 249 ./References/Reducing bias in the measurement of selection.json
# 250 ./References/Thresholded-ConvNet-Ensembles-Neural-Networks-for-Technical-Forecasting.json
# 251 ./References/NIPS-1998-reinforcement-learning-for-trading-Paper.json
# 252 ./References/Extending Deep Reinforcement Learning Frameworks in Cryptocurrency Market Making.json
# 253 ./References/Predicting Stock Market Trends Using Machine Learning and Deep Learning Algorithms Via Continuous and Binary Data a Comparative Analysis.json
# 254 ./References/Carving Out Evolutionary Paths Towards Greater Complexity.json
# 255 ./References/Stock Forecasting with Transformer Architecture & Attention Mechanism — Neuravest.json
# 256 ./References/Option Pricing with Deep Learning.json
# 257 ./References/The Empirical Distribution of UK and US Stock Returns.json
# 258 ./References/Reinforcement Learning for An ART-B ased Fuzzy Adaptive Learning Control Network .json
# 259 ./References/Spiking Neural Networks for Computational Intelligence: An Overview.json
# 260 ./References/Hyperparameter tuning using optuna for FinRL _ by Astarag Mohapatra _ Analytics Vidhya _ Medium.json
# 261 ./References/Best Automatic Machine Learning (AutoML) Frameworks in 2022 _ Geniusee.json
# 262 ./References/A Review of Algorithms and Hardware Implementations for Spiking Neural Networks.json
# 263 ./References/Image Recognition in Stock Prediction with Visual Explanations from Grad-CAM.json
# 264 ./References/INTRODUCTION TO MODELING AND GENERATING PROBABILISTIC INPUT PROCESSES FOR SIMULATION.json
# 265 ./References/QF-TraderNet_ Intraday Trading via Deep Reinforcement With Quantum Price Levels Based Profit-And-Loss Control - PMC.json
# 266 ./References/Deep reinforcement learning for time series_ playing idealized trading games.json
# 267 ./References/Using Structured Events to Predict Stock Price Movement: An Empirical Investigation.json
# 268 ./References/Character Recognition using Spiking Neural Networks.json
# 269 ./References/PERFORMANCE FUNCTIONS AND REINFORCEMENT LEARNING FOR TRADING SYSTEMS AND PORTFOLIOS.json
# 270 ./References/Encoding Time Series as Images for Visual Inspection and Classification Using Tiled Convolutional Neural Networks.json
# 271 ./References/STATISTICAL ANALYSIS OF GENETIC ALGORITHMS IN DISCOVERING TECHNICAL TRADING STRATEGIES.json
# 272 ./References/Deep Reinforcement Learning for Automated Stock Trading _ by Bruce Yang _ Towards Data Science.json
# 273 ./References/Stock market prediction - Wikipedia.json
# 274 ./References/LSTM Fully Convolutional Networks for Time Series Classification.json
# 275 ./References/GAN_Stock - Summary.json
# 276 ./References/Text mining approaches for stock market prediction.json
# 277 ./References/Quantitative Trading Strategies Deep Learning: Pairs Trading.json
# 278 ./References/The price dynamics of common trading strategies.json
# 279 ./References/Introduction to Deep Learning Business Applications for Developers .json
# 280 ./References/A Hierarchical Fused Fuzzy Deep Neural Network for Data Classiification.json
# 281 ./References/Applying Data Mining Techniques to Stock Market  Analysis.json
# 282 ./References/Sparse Coding and Decorrelation in Primary Visual Cortex During Natural Vision.json
# 283 ./References/An Attention-Based LSTM Model for Stock Price Trend Prediction Using Limit Order Books .json
# 284 ./References/A novel artificial neural network trained using evolutionary algorithms for reinforcement learning.json
# 285 ./References/BindsNET_A_Machine_Learning-Oriented_Spiking_Neural_Networks_Library_in_Python.json
# 286 ./References/Optimization of Quantitative Financial Data Analysis System Based on Deep Learning.json
# 287 ./References/Policy invariance under reward transformations_.json
# 288 ./References/High Frequency Trading for Active High Frequency Trading.json
# 289 ./References/Low-Rank Structure Learning via Nonconvex Heuristic Recovery.json
# 290 ./References/Neural-Symbolic Learning and Reasoning:A Survey and Interpretation.json
# 291 ./References/Neural Bag-of-Features Learning.json
# 292 ./References/Dimensionality Reduction using Similarity-induced Embeddings.json
# 293 ./References/Global Optimization Algorithms Theory and Application.json
# 294 ./References/MACHINE LEARNING IN QUANTITATIVE FINANCE.json
# 295 ./References/Stock Trend Prediction: Based on Machine Learning Methods.json
# 296 ./References/A Comparison of Genotype Representations to Acquire Stock Trading Strategy Using Genetic Algorithms.json
# 297 ./References/Human-level control through deep reinforcement learning.json
# 298 ./References/The Inverse Fisher Transform.json
# 299 ./References/Automated Reinforcement Learning (AutoRL): A Survey and Open Problems.json
# 300 ./References/Stock market as temporal network.json
# 301 ./References/Evolutionary convolutional neural networks: An application to handwriting recognition.json
# 302 ./References/Enhancing Time Series Momentum Strategies Using Deep Neural Networks.json
# 303 ./References/Wide & Deep Learning for Recommender Systems.json
# 304 ./References/An Overview of Genetic Algorithms : Part 1, Fundamentals.json
# 305 ./References/Resampling Methods: Cross Validation.json
# 306 ./References/Stock_Market_Forecasting_Using_Deep_Learning_and_Technical_Analysis_A_Systematic_Review.json
# 307 ./References/a-review-on-data-normalization-techniques.json
# 308 ./References/7 Candlestick Patterns that Predict a Bullish Move • TradeSmart University.json
# 309 ./References/Predicting Short-Term Stock Movements with Quantitative Finance and Machine Learning in Python | by Mat Steininger | Towards Data Science.json
# 310 ./References/Predicting Financial Markets using Text on the Web.json
# 311 ./References/A Survey of Exploration Strategies in Reinforcement Learning .json
# 312 ./References/Multivariate Real Time Series Data Using Six Unsupervised Machine Learning Algorithms _ IntechOpen.json
# 313 ./References/A GA-based fuzzy adaptive learning control network.json
# 314 ./References/Price Formation in Stock Markets Using Fundamental Analysis.json
# 315 ./References/Foreword: special issue on computational finance and economics 2012.json
# 316 ./References/ARTMAP: Supervised real-time learning and classification of nonstationary data by a self-organizing neural network.json
# 317 ./References/Policy invariance under reward transformations:Theory and application to reward shaping.json
# 318 ./References/Heuristic Optimization.json
# 319 ./References/Applying fuzzy logic and machine learning techniques in financial performance predictions .json
# 320 ./References/Neuroevolution: From architectures to learning.json
# 321 ./References/A TRADING SYSTEM BASED ON FUZZY LOGIC.json
# 322 ./References/Deep_Reinforcement_Learning_Versus_Evoluation Strategies: A Comparative Survey.json
# 323 ./References/OVERVIEW OF HANDLING IMBALANCED DATASETS IN MACHINE LEARNING.json
# 324 ./References/Multisource financial sentiment analysis for detecting Bitcoin price change indications using deep learning.json
# 325 ./References/Large-scale evolution of image classifiers.json
# 326 ./References/An Introduction to Genetic Algorithms for Numerical Optimization.json
# 327 ./References/Data-driven construction of Convex Region Surrogate Models.json
# 328 ./References/Machine Learning for Financial Market Prediction.json
# 329 ./References/NAST_ Non-Autoregressive Spatial-Temporal Transformer for Time Series Forecasting – arXiv Vanity.json
# 330 ./References/Deep learning for time series classification: a review.json
# 331 ./References/Do candlestick patterns work on their own_ A systematic FX back-test using Python.json
# 332 ./References/An Analysis of Technical Trading Strategies.json
# 333 ./References/Deep Candlestick Mining.json
# 334 ./References/application-of-data-mining-techniques-in-stock-markets.json
# 335 ./References/A new evolutionary system for evolving Artificial Neural Networks.json
# 336 ./References/A hitchhikers guide to FinRL_ A Deep Reinforcement Learning Framework for Quantitative Finance _ by Astarag Mohapatra _ Analytics Vidhya _ Medium.json
# 337 ./References/Reinforcement Learning for Visual Object Detection.json
# 338 ./References/The extraction of trading rules from stock market data using rough sets.json
# 339 ./References/A state-of-the-Art review of heuristic and metaheuristic optimization techniques for the management of water resources.json
# 340 ./References/Machine Learning Advances for Time Series Forecasting.json
# 341 ./References/The profitability of technical analysis Evidence from the piercing line and dark cloud cover patterns in the forex market.json
# 342 ./References/Fuzzy Rough Sets: from Theory into Practice.json
# 343 ./References/Reinforcement Learning for Neural Architecture Search: A Review.json
# 344 ./References/Unsupervised Knowledge Transfer using Similarity Embeddings.json
# 345 ./References/A review of learning in biologically plausible spiking neural networks.json
# 346 ./References/TimeCaps: Capturing Time Series Data with Capsule Networks.json
# 347 ./References/Predicting Stock Market Movements Using Global News Headlines.json
# 348 ./References/Normalization: A Preprocessing Stage.json
# 349 ./References/A New Approach to Rough Set Based on Remote Neighborhood Systems.json
# 350 ./References/Drift independent volatility estimation based on on High, Low, Open, and Close Prices.json
# 351 ./References/Robust Anomaly Detection for Multivariate Time Series through Stochastic Recurrent Neural Network.json
# 352 ./References/Segmenting Time Series: A Survey and Novel Approach.json
# 353 ./References/Automated Machine Learning on Graphs: A Survey.json
# 354 ./References/Predicting US Stock Market Movement from Political Tweets.json
# 355 ./References/REVERSIBLE INSTANCE NORMALIZATION FOR ACCURATE TIME-SERIES FORECASTING AGAINST DISTRIBUTION SHIFT.json
# 356 ./References/New-High, New-Low System by Dennis Meyers, Ph.json
# 357 ./References/Learning to Trade via Direct Reinforcement.json
# 358 ./References/Issues in Mining Imbalanced Data Sets - A Review Paper.json
# 359 ./References/fuzzy-rough-learn 0.json
# 360 ./References/Normalization_methods_in_time_series_of_platelet.json
# 361 ./References/Mastering Chess and Shogi by Self-Play with a General Reinforcement Learning Algorithm.json
# 362 ./References/Financial time series prediction: an approach using motif information and neural networks.json
# 363 ./References/Earliness-Aware Deep Convolutional Networks for Early Time Series Classification.json
# 364 ./References/An Overview of the Applications of Particle Swarm in Water Resources Optimization .json
# 365 ./References/Reinforcement Learning Approaches to Optimal Market Making.json
# 366 ./References/Stock Trend Prediction- Based on Machine Learning Methods.json
# 367 ./References/POSITIVE AND UNLABELED LEARNING ALGORITHMS AND APPLICATIONS:  A Survey.json
# 368 ./References/Identifying-Trading-Opportunities.json
# 369 ./References/Fuzzy Set Theory 2001.json
# 370 ./References/AutoML: A Survey of the State-of-the-Art.json
# 371 ./References/A Survey on Semi-, Self- and Unsupervised Learning in Image Classification.json
# 372 ./References/Pattern recognition by self-organizing neural networks.json
# 373 ./References/How to Solve It_ A New Aspect of Mathematical Method.json
# 374 ./References/Google Stock Market Price Prediction using Reinforcement Learning Technique.json
# 375 ./References/Generating Probability Distributions for Future Stock Prices.json
# 376 ./References/Deep Reward Shaping from Demonstrations.json
# 377 ./References/Machine Learning Methods in Finance: Recent Applications and Prospects.json
# 378 ./References/Recent Advances in Reinforcement Learning in Finance.json
# 379 ./References/Stock market price trendprediction using Customized Deep Learning System.json
# 380 ./References/Comparative Overview of Rough Set Toolkit Systems for Data Analysis.json
# 381 ./References/Hybrid Autogressive-Recurrent Neural Network Architecture for Algorithmic Trading of Cryptocurrencies.json
# 382 ./References/Optimization of Multi-Factor Model in Quantitative Trading Based On Reinforcement Learning.json
# 383 ./References/Final presentation.json
# 384 ./References/Improving stock trading decisions based on pattern recognition using machine learning technology.json
# 385 ./References/IS TECHNICAL ANALYSIS INFORMATIVE IN UK STOCK MARKET? EVIDENCE FROM DECOMPOSITION-BASED VECTOR AUTOREGRESSIVE (DVAR) MODEL.json
# 386 ./References/EVOLUTIONARY COMPUTATION: An Overview.json
# 387 ./References/The Utility Average Stock Market Indicator by Dennis Meyers, P.json
# 388 ./References/An Introduction to Evolutionary Computation in Finance.json
# 389 ./References/RECENT TRENDS IN TIME SERIES FORECASTING– A SURVEY.json
# 390 ./References/Chapter 5: Foundations of Data Imbalance and Solutions for a Data Democracy.json
# 391 ./References/HEBO_Heteroscedastic_Evolutionary_Bayesian_Optimis.json
# 392 ./References/Multi-Agent Deep Reinforcement Learning for Liquidation Strategy Analysis.json
# 393 ./References/Automated Reinforcement Learning: An Overview.json
# 394 ./References/Using the latest advancements in deep learning to predict stock price movements _ by Boris B _ Towards Data Science.json
# 395 ./References/Spatially Encoding Temporal Correlations to Classify Temporal Data Using Convolutional Neural Networks.json
# 396 ./References/reinforcement_learning_from_heuristics-3.json
# 397 ./References/Optimistic Bull or Pessimistic Bear: Adaptive Deep Reinforcement Learning.json
# 398 ./References/The applications of artificial neural networks, support vector machines, and long–short term memory for stock market prediction.json
# 399 ./References/Episode 1 — Genetic Algorithm for Reinforcement Learning _ by Moustafa Alzantot _ Becoming Human_ Artificial Intelligence Magazine.json
# 400 ./References/PySEF: A Python Library for Similarity-based Dimensionality Reduction.json
# 401 ./References/Technical Analysis - Explained.json
# 402 ./References/Comparison of Genetic Algorithms for Trading Strategies.json
# 403 ./References/Loss Functions in Time Series Forecasting.json
# 404 ./References/Survey of Clustering Algorithms.json
# 405 ./References/Google AI Blog_ Interpretable Deep Learning for Time Series Forecasting.json
# 406 ./References/Informer- Beyond Efficient Transformer for Long Sequence Time-Series Forecasting.json
# 407 ./References/ML Approaches for Time Series.json
# 408 ./References/AutoML _ AutoRL_ AutoML for RL.json
# 409 ./References/The Indomitable Investor_ Why a Few Succeed in the Stock Market When Everyone Else Fails ( PDFDrive ).json
# 410 ./References/Fuzzy-Based Time Series Forecasting and Modelling:  A Bibliometric Analysis.json
# 411 ./References/The use of fundamental and technical analyses by foreign exchange dealers Hong Kong evidence.json
# 412 ./References/AutoML - Tutorial 2020.json
# 413 ./References/Data-Science-for-Lazy-People-Automated-Machine-Learning-by-Diego-Hueltes-min.json
# 414 ./References/post_earnings_event_study.json
# 415 ./References/Forecasting the Stock Market Index Using Artificial Intelligence Techniques .json
# 416 ./References/A Survey on LSTM-based Stock Market Prediction.json
# 417 ./References/ROUGH FUZZY SETS AND FUZZY ROUGH SETS.json
# 418 ./References/momentum-strategies-in-futures Markets and Trend-Following Funds.json
# 419 ./References/Fuzzy-Embedded Gated Recurrent Unit (FE-GRU) System with Application in Stock Trading.json
# 420 ./References/Feature Engineering for Mid-Price Prediction with Deep Learning.json
# 421 ./References/Transferring knowledge as heuristics in reinforcement learning_ A case-based approach _ Elsevier Enhanced Reader.json
# 422 ./References/Stock Market Trend Prediction Model for the Egyptian Stock Market Using Neural Networks and Fuzzy Logic.json
# 423 ./References/Feature Engineering & Feature Selection _ by Ke Gui _ Towards Data Science.json
# 424 ./References/A-Hybrid-Approach-To-Evaluate-Stock-Returns-Using-Data-Mining-Techniques.json
# 425 ./References/Application of Deep Reinforcement Learning in Stock Trading Strategies and Stock Forecasting.json
# 426 ./References/A New Utility Average Stock Market System by Dennis Meyers,.json
# 427 ./References/Cross-Validation for Selecting a Model Selection Procedure.json
# 428 ./References/Generating trading rules on the stock markets with.json
# 429 ./References/The Merits of a Parallel Genetic Algorithm in Solving Hard Optimization Problems.json
# 430 ./References/Discriminative Clustering using Regularized Subspace Learning.json
# 431 ./References/A survey of unsupervised learning methods for high-dimensional uncertainty quantification in black-box-type problems.json
# 432 ./References/Machine learning advances for time series forecasting.json
# 433 ./References/Reinforcement Learning for Combinatorial Optimization: A Survey.json
# 434 ./References/Stock Market Prediction: A Systematic Review.json
# 435 ./References/Capturing Financial markets to apply Deep Reinforcement Learning .json
# 436 ./References/Towards Self-Adaptive Efficient Global Optimization.json
# 437 ./References/Stock_Market_Trend_Prediction_Using_High-Order_Information_of_Time_Series.json
# 438 ./References/From Evolutionary Computation to the Evolution of Things.json
# 439 ./References/SELF-LEARNING FUZZY SPIKING NEURAL NETWORK  AS A NONLINEAR PULSE-POSITION THRESHOLD DETECTION DYNAMIC SYSTEM BASED ON SECOND-ORDER CRITICALLY DAMPED RESPONSE UNITS .json
# 440 ./References/Default ARTMAP 2.json
# 441 ./References/Using Genetic Algorithms to Find Technical Trading Rules A Comment on Risk Adjustment.json
# 442 ./References/A critical survey of STDP in Spiking Neural Networks for Pattern Recognition.json
# 443 ./References/GTM_Transformer-Monitoring-Markets-2013_Brochure.json
# 444 ./References/Financial Time Series Prediction Using Spiking Neural Networks Prediction.json
# 445 ./References/Parallelism and evolutionary algorithms.json
# 446 ./References/Stock Price Prediction Based on Deep Learning | by Abhijit Roy | Towards Data Science.json
# 447 ./References/Anomaly Detection of Time Series.json
# 448 ./References/Unsupervised Learning of Spiking Neural Networks.json
# 449 ./References/4 Common Machine Learning Data Transforms for Time Series Forecasting.json
# 450 ./References/Automatic Trading System based on Genetic Algorithm and Technical Analysis for Stock Index.json
# 451 ./References/Genetic Algorithm: An Application to Technical Trading System Design.json
# 452 ./References/How To Automate The Stock Market Using FinRL (Deep Reinforcement Learning Library)_.json
# 453 ./References/Time Series Analysis by State Space Methods.json
# 454 ./References/Stock Market Prediction using Novel Deep Learning Approaches: A Review.json
# 455 ./References/Stock Market Trading Based on Market Sentiments and Reinforcement Learning.json
# 456 ./References/Deep Neuro‑Fuzzy System application trends, challenges,  and future perspectives: a systematic survey.json
# 457 ./References/Algorithmic Stock Trading using Deep Reinforcement Learning.json
# 458 ./References/Time2Vec: Learning a Vector Representation of Time.json
# 459 ./References/Accurate Multivariate Stock Movement Prediction via Data-Axis Transformer with Multi-Level Contexts.json
# 460 ./References/Stock Price Volatility Prediction with Long Short- Term Memory Neural Networks.json
# 461 ./References/Top 10 AutoML Python packages to automate your machine learning tasks.json
# 462 ./References/Deep Reinforcement Learning for Portfolio Management.json
# 463 ./References/Using neural network to forecast stock index option price: a new hybrid GARCH approach.json
# 464 ./References/A comprehensive survey on machine learning for networking.json
# 465 ./References/Symbolic regression for scientific discovery: an application to wind speed forecasting .json
# 466 ./References/state-of-the-art-reinforcement-learning-algorithms.json
# 467 ./References/Transfer Learning for Reinforcement Learning Domains_ A Survey.json
# 468 ./References/A_Hybrid_Model_for_Financial_Time_Series_ForecastingIntegration_of_EWT_ARIMA_With_The_Improved_ABC_Optimized_ELM.json
# 469 ./References/Feature Selection for Stock Market Analysis.json
# 470 ./References/Self-normalization for Time Series: A Review of Recent Developments.json
# 471 ./References/Stock Market Prediction Using Optimized Deep-ConvLSTM Model.json
# 472 ./References/Algorithms, Games, and Evolution.json
# 473 ./References/Classification with Imbalanced Datasets _ Soft Computing and Intelligent Information Systems.json
# 474 ./References/USING FUZZY LOGIC FOR ON-LINE TREND ANALYSIS .json
# 475 ./References/Simulated Annealing for Portfolio Optimization.json
# 476 ./References/The-Complete-Guide-to-Trading.json
# 477 ./References/Forecasting Time Series by SOFNN with Reinforcement Learning.json
# 478 ./References/Financial Time Series Forecasting Using Optimized Multistage Wavelet Regression.json
# error: Too many arguments for command
#
# NAME
#     find - Find and extract references from text documents
#
# SYNOPSIS
#
#     anystyle [global options] find [command options] input [output]
#
#
#
# DESCRIPTION
#     This manual page documents the AnyStyle `find' command. AnyStyle `find'
#     analyzes PDF or text documents and extracts all references it finds.
#
#     The input argument can be a single PDF or text document, or a folder
#     containing multiple documents. The (optional) output argument specifies
#     the folder where the results shall be saved; if no output folder is
#     specified, results will be saved in the folder containing the input.
#
#     AnyStyle `find' supports the following formats:
#         bib     BibTeX (references only);
#         csl     CSL/JSON (references only);
#         json    AnyStyle JSON (references only);
#         ref     One reference per line, suitable for parser input;
#         txt     Plain text document;
#         ttx     Tagged document format, used for training the finder model;
#         xml     References only, XML, suitable for training the parser model.
#
#     You can specify multiple output formats, separated by commas.
#
#     Anlyzing PDF documents currently depends on `pdftotext' which must be
#     installed separately.
#
# EXAMPLES
#     anystyle -f csl,xml find thesis.pdf
#
#     Extract references from `thesis.pdf' and save them in `thesis.csl' and
#     `thesis.xml'.
#
#     anystyle -f bib find --no-layout thesis.pdf bib
#
#     Extract references from `thesis.pdf' in `no-layout' mode (e.g., use this
#     if your document uses a multi-column layout) and save them in BibTeX in
#     `./bib/thesis.bib'.
#
#     anystyle find --crop 72 thesis.pdf -
#
#     Extract references from `thesis.pdf' cropping away one inch (72pt) from
#     each page border and print the results to STDOUT.
#
#     anystyle find --crop 72,28 thesis.pdf -
#
#     Extract references from `thesis.pdf' cropping away one inch (72pt) from
#     each page's left and right border, approx. 1cm (28pt) from the top
#     and bottom.
#
#
#
#
# COMMAND OPTIONS
#     -C, --crop=pt - Set cropping boundary for text extraction (default: none)
#     --[no-]layout - Use layout mode for PDF text extraction (default: enabled)
#     --[no-]solo   - Include references outside of reference sections
#
#
#
# 479 ./References/Neural Architecture Search _ Lil'Log.json
# ...
# 1416 ./References/EVOLUTIONARY COMPUTATION.json
# 1417 ./References/Google AI Blog_ Evolving Reinforcement Learning Algorithms.json
# 1418 ./References/Stock Index Prices Prediction via Temporal Pattern Attention and.json
# 1419 ./References/Making the Titanic Fly by Dennis Meyers.json
# 1420 ./References/Deep Reinforcement Learning in Agent Based Financial Market Simulation .json
# 1421 ./References/Genetic- Algorithm Programming Environments.json
# 1422 ./References/20 Key Examples Of AI In Finance You Should Know 2022 _ Built In.json
# 1423 ./References/Profitable Strategy Design by Using Deep Reinforcement Learning for Trades on Cryptocurrency Markets.json
# 1424 ./References/Time Series Analysis for Business Forecasting.json
# 1425 ./References/Deep Reinforcement Learning for Financial Trading using Price Trailing.json
# 1426 ./References/Neuroevolution for Deep Reinforcement Learning Problems 2019.json
# 1427 ./References/Reinforcement Learning in Economics and Finance.json
# 1428 ./References/Time Series Modeling with Genetic Programming Prediction of Stock Market Index Using Genetic Algorithm .json
# 1429 ./References/Machine Learning for Irregular Time Series (ML4ITS) - Research.json
# 1430 ./References/Artificial Neural Networks architectures for stock price prediction: comparisons and applications.json
# 1431 ./References/NEURAL ARCHITECTURE SEARCH WITH REINFORCEMENT LEARNING.json
# 1432 ./References/Combinatorial PurgedKFold Cross-Validation for Deep Reinforcement Learning _ by Berend _ Apr, 2022 _ Towards AI.json
# 1433 ./References/Analyzing and Predicting Stock Market Using Data Mining Techniques – A Review .json
# 1434 ./References/The Best Deep Learning Models for Time Series Forecasting _ by Nikos Kafritsas _ Towards Data Science.json
# 1435 ./References/Simple_Trading_strategies.json
# 1436 ./References/Manifold-Learning-Based Feature Extraction for Classification of Hyperspectral Data.json
# 1437 ./References/Machine Learning in Finance Applications of Continuous Depth and Randomized Neural Networks.json
# 1438 ./References/Nature-Inspired Optimization Algorithms.json
# 1439 ./References/Enhancing Time-Series.json
# 1440 ./References/Encyclopedia_of_Chart_Patterns.json
# 1441 ./References/A New Methodology Based on Imbalanced Classification for Predicting Outliers in Electricity Demand Time Series.json
# 1442 ./References/The Great Time Series Classification Bake Off: An Experimental Evaluation of Recently Proposed Algorithms.json
# 1443 ./References/Deep Learning Techniques for Stock Market Prediction in the European Union: A Systematic Review.json
# 1444 ./References/Data-mining-techniques-and-applications.json
# 1445 ./References/A Survey on Stock Market Prediction Using Machine Learning Techniques.json
# 1446 ./References/VWAP Strategies.json
# 1447 ./References/Using Genetic Alglorithms to Find Technical Trading Rules.json
# 1448 ./References/Time Series Simulation by Conditional Generative Adversarial Net.json
# 1449 ./References/einforcement-learning-for-trading-Paper.json
# 1450 ./References/A Survey of Forex and Stock Price Prediction Using Deep Learning.json
# 1451 ./References/New Interpretations of Normalization Methods in Deep Learning.json
# 1452 ./References/Alexandros Iosifidis - Time-series data analysis.json
# pdftotext version 0.86.1
# Copyright 2005-2020 The Poppler Developers - http://poppler.freedesktop.org
# Copyright 1996-2011 Glyph & Cog, LLC
# Usage: pdftotext [options] <PDF-file> [<text-file>]
#   -f <int>             : first page to convert
#   -l <int>             : last page to convert
#   -r <fp>              : resolution, in DPI (default is 72)
#   -x <int>             : x-coordinate of the crop area top left corner
#   -y <int>             : y-coordinate of the crop area top left corner
#   -W <int>             : width of crop area in pixels (default is 0)
#   -H <int>             : height of crop area in pixels (default is 0)
#   -layout              : maintain original physical layout
#   -fixed <fp>          : assume fixed-pitch (or tabular) text
#   -raw                 : keep strings in content stream order
#   -nodiag              : discard diagonal text
#   -htmlmeta            : generate a simple HTML file, including the meta information
#   -enc <string>        : output text encoding name
#   -listenc             : list available encodings
#   -eol <string>        : output end-of-line convention (unix, dos, or mac)
#   -nopgbrk             : don't insert page breaks between pages
#   -bbox                : output bounding box for each word and page size to html.  Sets -htmlmeta
#   -bbox-layout         : like -bbox but with extra layout bounding box data.  Sets -htmlmeta
#   -opw <string>        : owner password (for encrypted files)
#   -upw <string>        : user password (for encrypted files)
#   -q                   : don't print any messages or errors
#   -v                   : print copyright and version info
#   -h                   : print usage information
#   -help                : print usage information
#   --help               : print usage information
#   -?                   : print usage information
# Error processing `The "Liquid Computer": A Nevel Strategy for Real-Time Computing on Time Series.pdf'
#   pdftotext failed with error code 99
#   /var/lib/gems/2.7.0/gems/anystyle-1.3.13/lib/anystyle/utils.rb:68:in `pdf_to_text'
#   /var/lib/gems/2.7.0/gems/anystyle-1.3.13/lib/anystyle/document.rb:32:in `open'
#   ...
# 1453 ./References/The "Liquid Computer": A Nevel Strategy for Real-Time Computing on Time Series.json
# 1454 ./References/Discovering Patterns in Sentimental Analysis.json
# 1455 ./References/Computational Finance.json
# 1456 ./References/Implementation of a Type-2 Fuzzy Logic Based Prediction System for the Nigerian Stock Exchange.json
# 1457 ./References/Stock Market Prediction and Investment using Deep Reinforcement Learning- a Continuous Training Pipeline  .json
# 1458 ./References/Impact of Data Normalization on Deep Neural Network for Time Series Forecasting.json
# 1459 ./References/30 RULES TO MASTER SWING TRADING.json
# 1460 ./References/Using fast adaptive neural network classifier for mutual fund performance evaluation.json
# 1461 ./References/An empirical survey of data augmentation for time series classification with neural networks.json
# 1462 ./References/The Distribution of Stock Return Volatility.json
# 1463 ./References/Predicting break-points in trading strategies with Twitter .json
# 1464 ./References/Evolutionary_Computation_from_Genetic_Algorithms_to_Genetic_Programming Algorithms for Data Science.json
# 1465 ./References/Using Deep Learning to Detect Price Change Indications in Financial Markets.json
# 1466 ./References/Adaptive Quantitative Trading: An Imitative Deep Reinforcement Learning Approach.json
# 1467 ./References/Cost Sensitive Time-series Classification.json
# /bin/bash: -c: line 0: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 1: syntax error: unexpected end of file
# 1468 ./References/Andre Bush -- The Swiss trading champion who earned 4537.json
# 1469 ./References/Stocks & Commodities V17_4 (151-159)_ The Discrete Fourier Transform Illusion by Dennis Meyers, Ph.json
# 1470 ./References/Working Towards Explainable and Data-efficient Machine Learning Models via Symbolic Reasoning.json
# 1471 ./References/A Few Useful Things to Know About Machine Learning.json
# 1472 ./References/4 Ways to Predict Market Performance.json
# 1473 ./References/Introducing Fuzzy Layers for Deep Learning.json
# 1474 ./References/Stock Trend Prediction Algorithm Based on Deep Recurrent Neural Network .json
# 1475 ./References/Multi-Objective reward generalization: Improving performance of Deep Reinforcement Learning for selected applications in stock and cryptocurrency trading.json
# 1476 ./References/Genetic Algorithms: Genesis of Stock Evaluation.json
# 1477 ./References/Survey on the application of deep learning in algorithmic trading.json
# 1478 ./References/HANDBOOK OF GLOBAL OPTIMIZATION.json
# 1479 ./References/Technical Analysis in the Foreign Exchange Market.json
# 1480 ./References/Reinforcement Learning in Financial Markets.json
# 1481 ./References/Imaging time-series to improve classification and imputation.json
# 1482 ./References/STOCK TREND PREDICTION USING NEWS SENTIMENT ANALYSIS .json
# 1483 ./References/Time series momentum.json
# 1484 ./References/TIME SERIES CLASSIFICATION USING IMBALANCED LEARNING FOR 2 REAL-TIME SAFETY ASSESSMENT.json
# 1485 ./References/Deep reinforcement learning stock market trading, utilizing a CNN with candlestick images.json
# 1486 ./References/List of Technical Indicators _ Trading Technologies.json
# 1487 ./References/Applications of artificial neural networks in financial economics: A Survey.json
# 1488 ./References/Multi-agent Deep Reinforcement Learning.json
# 1489 ./References/Neuro-symbolic approaches in artificial intelligence .json
# 1490 ./References/An Efficient and Accurate Rough Set for Feature Selection, Classification and Knowledge Representation.json
# 1491 ./References/Short Book Reviews.json
# 1492 ./References/MULTIVARIATE ANOMALY DETECTION ON STOCK MARKET.json
# 1493 ./References/Nature-Inspired Metaheuristic Techniques for Combinatorial Optimization Problems: Overview and Recent Advances .json
# 1494 ./References/Cost-Aware Pre-Training for Multiclass Cost-Sensitive Deep Learning.json
# 1495 ./References/normalize-time-series-and-forecast-using-evolutionary-neural-network.json
# 1496 ./References/Deep Learning for Limit Order Book Trading and Mid-Price Movement Prediction.json
# 1497 ./References/An_automated_FX_trading_system_using_adaptive_reinforcement.json
# 1498 ./References/Identifying Candlestick Patterns using Deep Learning _ by Shaan Shah _ Towards Data Science.json
# 1499 ./References/A Transformer Self-Attention Model for Time Series Forecasting.json
# 1500 ./References/estimize_signal_strategy.json
# 1501 ./References/Time Series in Finance- the array database approach .json
# 1502 ./References/Neuroevolution strategies for episodic reinforcement learning.json
# 1503 ./References/Evolutionary Design of Convolutional Neural Networks for Human Activity Recognition in Sensor-Rich Environments.json
# 1504 ./References/Fastformer: Additive Attention Can Be All You Need.json
# 1505 ./References/Nonlinear system control using self-evolving neural fuzzy inference networks with reinforcement evolutionary learning.json
# 1506 ./References/An Empirical Analysis of Data Requirements for Financial Forecasting with Neural Networks.json
# 1507 ./References/Multi-Agent Deep Reinforcement Learning in 13 Lines of Code Using PettingZoo _ by J K Terry _ Towards Data Science.json
# 1508 ./References/Rough Set Theory with Applications to Data  Mining.json
# 1509 ./References/Recurrence and Self-Attention vs the Transformer for Time-Series Classification: A Comparative Study.json
# 1510 ./References/Multi-Horizon Forecasting for Limit Order Books: Novel Deep Learning Approaches and Hardware Acceleration using Intelligent Processing Units.json
# 1511 ./References/An overview of time-aware cross-validation techniques _ by Matthias Ramirez (ELCA) _ ELCA IT.json
# 1512 ./References/GA-DRL_Genetic_Algorithm-Based_Function_Optimizer_.json
# 1513 ./References/Attention-based Neural Bag-of-Features Learning.json
# 1514 ./References/Deep Learning With Spiking Neurons: Opportunities and Challenges.json
# 1515 ./References/***Short term stock market price trend prediction using a comprehensive deep learning system.json
# 1516 ./References/Reinforcement Learning with Neuroevolution: Final Report.json
# 1517 ./References/Introduction to Technical Indicators and Oscillators [ChartSchool].json
# 1518 ./References/Surveying stock market forecasting techniques Part II: Soft computing methods.json
# 1519 ./References/FinRL: Deep Reinforcement Learning Framework to Automate Trading in Quantitative Finance.json
# 1520 ./References/A Survey on Modern Deep Neural Network for Traffic Prediction: Trends, Methods and Challenges.json
# 1521 ./References/Time Forecast with TPOT.json
# 1522 ./References/Convolutional Nonlinear Neighbourhood Components Analysis for Time Series Classification.json
# 1523 ./References/On Using Genetic Algorithms to Search Program Spaces.json
# 1524 ./References/Transformers in Time Series- A Survey.json
# 1525 ./References/Optimal Ratio for Data Splitting.json
# 1526 ./References/Forecasting Volatility of Stock Index- Deep Learning Model with Likelihood-Based Loss Function.json
# 1527 ./References/DeMark -- technical analysis_ TD Waldo Patterns _ LiteFinance (ex.json
# 1528 ./References/Hierarchical Adaptive Temporal-Relational Modeling for Stock Trend Prediction.json
# 1529 ./References/Absolute exponential stability of recurrent neural networks with Lipschitz-continuous activation functions and time delays.json
# 1530 ./References/Deep Reinforcement Trading with Predictable Returns.json
# 1531 ./References/Machine Learning for Forecasting Mid Price Movement using Limit Order Book Data.json
# 1532 ./References/Anomaly Detection.json
# 1533 ./References/Parameter tuning in trading algorithms using ASTA.json
# 1534 ./References/Unsupervised Learning of Digit Recognition Using Spike-Timing-Dependent Plasticity.json
# 1535 ./References/Introduction and Trends to Fuzzy Logic and Fuzzy Databases.json
# 1536 ./References/Fidelity Learning Center_ Technical Analysis Indicator Guide-001.json
# 1537 ./References/Spike-timing dependent plasticity.json
# 1538 ./References/Optimization of the Trading Rule in Foreign Exchange using Genetic Algorithm.json
# 1539 ./References/EFFECTIVE AND EFFICIENT COMPUTATION WITH MULTIPLE-TIMESCALE SPIKING RECURRENT NEURAL NETWORKS .json
# 1540 ./References/Unsupervised Learning.json
# 1541 ./References/Neuromorphic Data Augmentation for Training Spiking Neural Networks.json
# 1542 ./References/Generative_Adversarial_Networks_for_Financial_Trade.json
# 1543 ./References/LARG: Loss avoidance technical trading rules using genetic algorithm.json
# 1544 ./References/Meta Optimization and its Application to Portfolio Selection.json
# 1545 ./References/Which Daily Price Is Less Noisy?.json
# 1546 ./References/Cross-ValidationInClassHO.json
# 1547 ./References/Deep learning for Stock Market Prediction.json
# 1548 ./References/Deepbots: A Webots-Based Deep Reinforcement Learning Framework for Robotics.json
# 1549 ./References/A Comprehensive Analysis of Nature‑Inspired Meta‑Heuristic Techniques for Feature Selection Problem.json
# 1550 ./References/Predicting the price movement from candlestick charts: a CNN-based approach.json
# 1551 ./References/Hierarchical Temporal Memory Theory Approach to Stock Market Time Series Forecasting Long-Short-Term Memory.json
# 1552 ./References/FinRL: A Deep Reinforcement Learning Library for Automated Stock Trading in Quantitative Finance .json
# 1553 ./References/Fuzzy adaptive resonance theory: Applications and extensions .json
# 1554 ./References/Review 02 --A review of Reinforcement learning for financial time series prediction and portfolio optimization _ by Nick Smith _ Journal of Quantitative finance _ Medium.json
# 1555 ./References/Trends of Inference Considering Extended Fuzzy Logic.json
# 1556 ./References/A Novel Meta-Heuristic Optimization Algorithm Inspired by the Spread of Viruses.json
# 1557 ./References/Evolutionary algorithm optimization of biological learning parameters in a biomimetic neuroprosthesis.json
# 1558 ./References/Automated Machine Learning: State-of-The-Art and Open Challenges.json
# 1559 ./References/Transformers in Time Series_ A Survey.json
# 1560 ./References/Stock Market Prediction Using Machine Learning Techniques: A Decade Survey on Methodologies, Recent Developments, and Future Directions.json
# 1561 ./References/Technical Indicators and Overlays [ChartSchool].json
# 1562 ./References/Parallel genetic algorithms for stock market trading rules.json
# 1563 ./References/Fast and slow arbitrage: Smart money, dumb money and mispricing in the frequency domain.json
# 1564 ./References/The Bio-Inspired Optimization of Trading Strategies and Its Impact on the Efficient Market Hypothesis and Sustainable Development Strategies.json

# %%
ss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 ss
#
# NameError: name 'ss' is not defined

# %%
import json

# %%
fn = 'ref2.json'
data_df= pd.read_json(fn, orient=str)

# %%
data_df.head()
# Out:
#   citation-number                                             author    date  \
# 0            [1.]  [{'family': 'Suimon', 'given': 'Yoshiyuki'}, {...  [2020]
# 1            [2.]  [{'family': 'Yono', 'given': 'Kyoto'}, {'famil...  [2020]
# 2            [3.]  [{'family': 'Zengeler', 'given': 'Nico'}, {'fa...  [2020]
# 3            [7.]  [{'family': 'Kim', 'given': 'Eun-chong'}, {'fa...  [2019]
# 4            [8.]  [{'family': 'Yue', 'given': 'Xiao-Guang'}, {'f...  [2019]
#
#                                                title volume  pages  \
# 0  [Autoencoder-Based Three-Factor Model for the ...   [13]   [82]
# 1  [Construction of Macroeconomic Uncertainty Ind...   [13]   [79]
# 2  [Contracts for Difference: A Reinforcement Lea...   [13]   [78]
# 3  [Global Asset Allocation Strategy Using a Hidd...   [12]  [168]
# 4  [Social and Financial Inclusion through Nonban...   [12]  [166]
#
#                        doi             type            container-title  \
# 0  [10.3390/jrfm13040082.]  article-journal  [J. Risk Financial Manag]
# 1  [10.3390/jrfm13040079.]  article-journal  [J. Risk Financial Manag]
# 2  [10.3390/jrfm13040078.]  article-journal  [J. Risk Financial Manag]
# 3  [10.3390/jrfm12040168.]  article-journal  [J. Risk Financial Manag]
# 4  [10.3390/jrfm12040166.]  article-journal  [J. Risk Financial Manag]
#
#   location  ...  url publisher genre arxiv editor edition collection-title  \
# 0      NaN  ...  NaN       NaN   NaN   NaN    NaN     NaN              NaN
# 1      NaN  ...  NaN       NaN   NaN   NaN    NaN     NaN              NaN
# 2      NaN  ...  NaN       NaN   NaN   NaN    NaN     NaN              NaN
# 3      NaN  ...  NaN       NaN   NaN   NaN    NaN     NaN              NaN
# 4      NaN  ...  NaN       NaN   NaN   NaN    NaN     NaN              NaN
#
#   issue isbn director
# 0   NaN  NaN      NaN
# 1   NaN  NaN      NaN
# 2   NaN  NaN      NaN
# 3   NaN  NaN      NaN
# 4   NaN  NaN      NaN
#
# [5 rows x 21 columns]

# %%
data_df.to_csv('test.csv')

# %%
fn = 'ref1.json'
import pandas as pd

# read the entire file into a python array
with open(fn, 'rb') as f:
    data = f.readlines()

# remove the trailing "\n" from each line
data = map(lambda x: x.rstrip(), data)

# each element of 'data' is an individual JSON object.
# i want to convert it into an *array* of JSON objects
# which, in and of itself, is one large JSON object
# basically... add square brackets to the beginning
# and end, and have all the individual business JSON objects
# separated by a comma
data_json_str = "[" + ",".join(data) + "]"

# now, load it into pandas
data_df = pd.read_json(data_json_str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 17>()
#       9 data = map(lambda x: x.rstrip(), data)
#      11 # each element of 'data' is an individual JSON object.
#      12 # i want to convert it into an *array* of JSON objects
#      13 # which, in and of itself, is one large JSON object
#      14 # basically... add square brackets to the beginning
#      15 # and end, and have all the individual business JSON objects
#      16 # separated by a comma
# ---> 17 data_json_str = "[" + ",".join(data) + "]"
#      19 # now, load it into pandas
#      20 data_df = pd.read_json(data_json_str)
#
# TypeError: sequence item 0: expected str instance, bytes found

# %%
data
